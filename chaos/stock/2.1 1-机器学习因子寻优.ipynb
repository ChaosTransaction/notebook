# %%
import os, datetime
import pandas as pd
import numpy as np

# %%
os.environ['IGNORE_WARNINGS'] = '0'
os.environ['DB_URL'] = 'mysql+mysqlconnector://read:1234@127.0.0.1:3306/quant'

# %%
from ultron.sentry.api import *
from jdw import EntropyAPI
# Out:
# /work/env/neutron/lib/python3.7/site-packages/Finance_Jindowin-1.2.4-py3.7.egg/jdw/__init__.py:11: UserWarning: if use distributed calculating, please configure MQ_URL
#   warnings.warn('if use distributed calculating, please configure MQ_URL')
# /work/env/neutron/lib/python3.7/site-packages/Finance_Jindowin-1.2.4-py3.7.egg/jdw/__init__.py:15: UserWarning: if use distributed calculating, please configure NTN_URL
#   warnings.warn('if use distributed calculating, please configure NTN_URL')
# /work/env/neutron/lib/python3.7/site-packages/Finance_Jindowin-1.2.4-py3.7.egg/jdw/__init__.py:19: UserWarning: if use memory database, please configure KN_MG
#   warnings.warn('if use memory database, please configure KN_MG')
# /work/env/neutron/lib/python3.7/site-packages/Finance_Jindowin-1.2.4-py3.7.egg/jdw/__init__.py:27: UserWarning: if use trader, please configure ATL_URL
#   warnings.warn('if use trader, please configure ATL_URL')
# /work/env/neutron/lib/python3.7/site-packages/Finance_Jindowin-1.2.4-py3.7.egg/jdw/__init__.py:31: UserWarning: if use trader, please configure IREY_URL
#   warnings.warn('if use trader, please configure IREY_URL')

# %%
begin_date = '2021-01-01'
end_date = '2022-12-31'

universe = 'sh50'
dummy_name = 'dummy120_fst_close'
industry_level = 1
industry_name = 'sw'
thresh = 0.9

# %%
factor_columns = [
    'aiEtopZ180', 'RSI', 'VOL240', 'aiSude', 'aiDaNp60', 'aiDaPE60',
    'hkHoldRatioAll', 'hkHoldRatioB', 'hkHoldVolChgB120', 'lpnpQ', 'CCI10',
    MA(5,'ROC20')
]

# %%
default_models = [
    'BayesianRegression', 'ElasticNetRegression', 'RidgeRegression',
    'RandomForestRegressor', 'XGBRegressor', 'LGBMRegressor'
]

# %%
configure = {
    'generations': 5,
    'n_jobs': 4,
    'population_size': 80,
    'n_splits': 3,
    'slicing': 0.2,
    'tournament_size': 10,
    'mode': 'score',
    'standard_score': 5,
    'convergence': 0.002
}  # 评估函数

# %%
stock_engine = EntropyAPI.StockEvolution(thresh=thresh,
                                         dummy_name=dummy_name,
                                         universe=universe,
                                         horizon=3,
                                         model_sets=default_models,
                                         factor_columns=factor_columns,
                                         industry_name=industry_name,
                                         industry_level=industry_level)

# %%
stock_engine.run(begin_date=begin_date, end_date=end_date, configure=configure)
# Out:
# 2023-03-28 13:55:19,755 - ultron - INFO - start service
# 2023-03-28 13:55:38,036 - ultron - INFO - start create yields data
# 2023-03-28 13:56:43,256 - ultron - INFO - start fetch industry data
# 2023-03-28 13:57:02,656 - ultron - INFO - start industry median data ...
# 2023-03-28 13:57:55,161 - ultron - INFO - start factors normal
# 2023-03-28 13:57:55,430 - ultron - INFO - start corrcoef
# 2023-03-28 13:57:56,373 - ultron - INFO - CCI10,RSI corr:0.6502637259483368
# 2023-03-28 13:57:57,265 - ultron - INFO - CCI10,VOL240 corr:-0.018427317572861687
# 2023-03-28 13:57:58,174 - ultron - INFO - CCI10,\mathrm{MA}(5, ''\text{ROC20}'') corr:0.279637924517912
# 2023-03-28 13:57:59,087 - ultron - INFO - CCI10,aiDaNp60 corr:0.040386594290709794
# 2023-03-28 13:58:00,017 - ultron - INFO - CCI10,aiDaPE60 corr:-0.1603471220593797
# 2023-03-28 13:58:00,929 - ultron - INFO - CCI10,aiEtopZ180 corr:-0.22025373146995134
# 2023-03-28 13:58:01,834 - ultron - INFO - CCI10,aiSude corr:0.011787278531597147
# 2023-03-28 13:58:02,751 - ultron - INFO - CCI10,hkHoldRatioAll corr:-0.006191989889822143
# 2023-03-28 13:58:03,694 - ultron - INFO - CCI10,hkHoldRatioB corr:0.012311550492571013
# 2023-03-28 13:58:04,608 - ultron - INFO - CCI10,hkHoldVolChgB120 corr:0.05813645338570382
# 2023-03-28 13:58:05,531 - ultron - INFO - CCI10,lpnpQ corr:0.032294401029762575
# TS CORR::9.09%
# 2023-03-28 13:58:06,440 - ultron - INFO - RSI,VOL240 corr:-0.03498707930038921
# 2023-03-28 13:58:07,353 - ultron - INFO - RSI,\mathrm{MA}(5, ''\text{ROC20}'') corr:0.5898486113811348
# 2023-03-28 13:58:08,279 - ultron - INFO - RSI,aiDaNp60 corr:0.05158785751977699
# 2023-03-28 13:58:09,195 - ultron - INFO - RSI,aiDaPE60 corr:-0.2412246543632271
# 2023-03-28 13:58:10,099 - ultron - INFO - RSI,aiEtopZ180 corr:-0.29587076363990583
# 2023-03-28 13:58:10,998 - ultron - INFO - RSI,aiSude corr:0.015325953677731655
# 2023-03-28 13:58:11,894 - ultron - INFO - RSI,hkHoldRatioAll corr:-0.005087263363101162
# 2023-03-28 13:58:12,808 - ultron - INFO - RSI,hkHoldRatioB corr:0.01543508825767884
# 2023-03-28 13:58:13,691 - ultron - INFO - RSI,hkHoldVolChgB120 corr:0.06213453359724361
# 2023-03-28 13:58:14,586 - ultron - INFO - RSI,lpnpQ corr:0.04520328670631392
# TS CORR::18.18%
# 2023-03-28 13:58:15,486 - ultron - INFO - VOL240,RSI corr:-0.034987079300389204
# 2023-03-28 13:58:16,362 - ultron - INFO - VOL240,\mathrm{MA}(5, ''\text{ROC20}'') corr:-0.08180491306298324
# 2023-03-28 13:58:17,257 - ultron - INFO - VOL240,aiDaNp60 corr:0.011398053391492205
# 2023-03-28 13:58:18,165 - ultron - INFO - VOL240,aiDaPE60 corr:0.008836149007997418
# 2023-03-28 13:58:19,068 - ultron - INFO - VOL240,aiEtopZ180 corr:-0.008590621680794497
# 2023-03-28 13:58:19,976 - ultron - INFO - VOL240,aiSude corr:0.07177370928580429
# 2023-03-28 13:58:20,898 - ultron - INFO - VOL240,hkHoldRatioAll corr:0.3116818444242715
# 2023-03-28 13:58:21,802 - ultron - INFO - VOL240,hkHoldRatioB corr:0.3883789356714328
# 2023-03-28 13:58:22,728 - ultron - INFO - VOL240,hkHoldVolChgB120 corr:0.02210686334097941
# 2023-03-28 13:58:23,636 - ultron - INFO - VOL240,lpnpQ corr:-0.024764479977028922
# TS CORR::27.27%
# 2023-03-28 13:58:24,546 - ultron - INFO - \mathrm{MA}(5, ''\text{ROC20}''),RSI corr:0.5898486113811348
# 2023-03-28 13:58:25,468 - ultron - INFO - \mathrm{MA}(5, ''\text{ROC20}''),VOL240 corr:-0.08180491306298324
# 2023-03-28 13:58:26,382 - ultron - INFO - \mathrm{MA}(5, ''\text{ROC20}''),aiDaNp60 corr:0.05066394381742654
# 2023-03-28 13:58:27,309 - ultron - INFO - \mathrm{MA}(5, ''\text{ROC20}''),aiDaPE60 corr:-0.39388037098998196
# 2023-03-28 13:58:28,234 - ultron - INFO - \mathrm{MA}(5, ''\text{ROC20}''),aiEtopZ180 corr:-0.3648935317436903
# 2023-03-28 13:58:29,165 - ultron - INFO - \mathrm{MA}(5, ''\text{ROC20}''),aiSude corr:0.028176934042043595
# 2023-03-28 13:58:30,053 - ultron - INFO - \mathrm{MA}(5, ''\text{ROC20}''),hkHoldRatioAll corr:-0.040438686981782775
# 2023-03-28 13:58:30,979 - ultron - INFO - \mathrm{MA}(5, ''\text{ROC20}''),hkHoldRatioB corr:-0.03338431112455676
# 2023-03-28 13:58:31,947 - ultron - INFO - \mathrm{MA}(5, ''\text{ROC20}''),hkHoldVolChgB120 corr:0.0350733597522728
# 2023-03-28 13:58:32,875 - ultron - INFO - \mathrm{MA}(5, ''\text{ROC20}''),lpnpQ corr:0.0558141577967863
# TS CORR::36.36%
# 2023-03-28 13:58:33,758 - ultron - INFO - aiDaNp60,RSI corr:0.05158785751977699
# 2023-03-28 13:58:34,675 - ultron - INFO - aiDaNp60,VOL240 corr:0.011398053391492205
# 2023-03-28 13:58:35,603 - ultron - INFO - aiDaNp60,\mathrm{MA}(5, ''\text{ROC20}'') corr:0.05066394381742654
# 2023-03-28 13:58:36,509 - ultron - INFO - aiDaNp60,aiDaPE60 corr:0.42772639012664293
# 2023-03-28 13:58:37,443 - ultron - INFO - aiDaNp60,aiEtopZ180 corr:0.3603669078754943
# 2023-03-28 13:58:38,371 - ultron - INFO - aiDaNp60,aiSude corr:0.33139342914736314
# 2023-03-28 13:58:39,297 - ultron - INFO - aiDaNp60,hkHoldRatioAll corr:-0.012607433175758404
# 2023-03-28 13:58:40,190 - ultron - INFO - aiDaNp60,hkHoldRatioB corr:0.004220788140337824
# 2023-03-28 13:58:41,106 - ultron - INFO - aiDaNp60,hkHoldVolChgB120 corr:0.020410167768794417
# 2023-03-28 13:58:42,028 - ultron - INFO - aiDaNp60,lpnpQ corr:0.22921854147341
# TS CORR::45.45%
# 2023-03-28 13:58:42,949 - ultron - INFO - aiDaPE60,RSI corr:-0.24122465436322707
# 2023-03-28 13:58:43,864 - ultron - INFO - aiDaPE60,VOL240 corr:0.008836149007997422
# 2023-03-28 13:58:44,890 - ultron - INFO - aiDaPE60,\mathrm{MA}(5, ''\text{ROC20}'') corr:-0.3938803709899819
# 2023-03-28 13:58:45,806 - ultron - INFO - aiDaPE60,aiDaNp60 corr:0.42772639012664293
# 2023-03-28 13:58:46,730 - ultron - INFO - aiDaPE60,aiEtopZ180 corr:0.7561751605624323
# 2023-03-28 13:58:47,620 - ultron - INFO - aiDaPE60,aiSude corr:0.2020992144574083
# 2023-03-28 13:58:48,524 - ultron - INFO - aiDaPE60,hkHoldRatioAll corr:0.06059520137153132
# 2023-03-28 13:58:49,531 - ultron - INFO - aiDaPE60,hkHoldRatioB corr:0.046868320238598764
# 2023-03-28 13:58:50,434 - ultron - INFO - aiDaPE60,hkHoldVolChgB120 corr:-0.01846354772504569
# 2023-03-28 13:58:51,351 - ultron - INFO - aiDaPE60,lpnpQ corr:0.14411721409625494
# TS CORR::54.55%
# 2023-03-28 13:58:52,262 - ultron - INFO - aiEtopZ180,RSI corr:-0.29587076363990583
# 2023-03-28 13:58:53,175 - ultron - INFO - aiEtopZ180,VOL240 corr:-0.008590621680794506
# 2023-03-28 13:58:54,093 - ultron - INFO - aiEtopZ180,\mathrm{MA}(5, ''\text{ROC20}'') corr:-0.3648935317436903
# 2023-03-28 13:58:55,001 - ultron - INFO - aiEtopZ180,aiDaNp60 corr:0.3603669078754943
# 2023-03-28 13:58:55,922 - ultron - INFO - aiEtopZ180,aiDaPE60 corr:0.7561751605624323
# 2023-03-28 13:58:56,907 - ultron - INFO - aiEtopZ180,aiSude corr:0.24485184605794025
# 2023-03-28 13:58:57,819 - ultron - INFO - aiEtopZ180,hkHoldRatioAll corr:0.09620488723467757
# 2023-03-28 13:58:58,751 - ultron - INFO - aiEtopZ180,hkHoldRatioB corr:0.07874802295667375
# 2023-03-28 13:58:59,669 - ultron - INFO - aiEtopZ180,hkHoldVolChgB120 corr:-0.02667444636209793
# 2023-03-28 13:59:00,590 - ultron - INFO - aiEtopZ180,lpnpQ corr:0.1521595361629735
# TS CORR::63.64%
# 2023-03-28 13:59:01,515 - ultron - INFO - aiSude,RSI corr:0.015325953677731655
# 2023-03-28 13:59:02,411 - ultron - INFO - aiSude,VOL240 corr:0.07177370928580429
# 2023-03-28 13:59:03,314 - ultron - INFO - aiSude,\mathrm{MA}(5, ''\text{ROC20}'') corr:0.0281769340420436
# 2023-03-28 13:59:04,235 - ultron - INFO - aiSude,aiDaNp60 corr:0.33139342914736314
# 2023-03-28 13:59:05,145 - ultron - INFO - aiSude,aiDaPE60 corr:0.2020992144574083
# 2023-03-28 13:59:06,041 - ultron - INFO - aiSude,aiEtopZ180 corr:0.24485184605794025
# 2023-03-28 13:59:06,955 - ultron - INFO - aiSude,hkHoldRatioAll corr:0.008328713453799803
# 2023-03-28 13:59:07,873 - ultron - INFO - aiSude,hkHoldRatioB corr:0.04354207264434705
# 2023-03-28 13:59:08,788 - ultron - INFO - aiSude,hkHoldVolChgB120 corr:-0.053722295076665275
# 2023-03-28 13:59:09,712 - ultron - INFO - aiSude,lpnpQ corr:0.3727677172470913
# TS CORR::72.73%
# 2023-03-28 13:59:10,623 - ultron - INFO - hkHoldRatioAll,RSI corr:-0.005087263363101162
# 2023-03-28 13:59:11,524 - ultron - INFO - hkHoldRatioAll,VOL240 corr:0.3116818444242715
# 2023-03-28 13:59:12,490 - ultron - INFO - hkHoldRatioAll,\mathrm{MA}(5, ''\text{ROC20}'') corr:-0.040438686981782775
# 2023-03-28 13:59:13,479 - ultron - INFO - hkHoldRatioAll,aiDaNp60 corr:-0.012607433175758404
# 2023-03-28 13:59:14,409 - ultron - INFO - hkHoldRatioAll,aiDaPE60 corr:0.060595201371531335
# 2023-03-28 13:59:15,317 - ultron - INFO - hkHoldRatioAll,aiEtopZ180 corr:0.09620488723467757
# 2023-03-28 13:59:16,230 - ultron - INFO - hkHoldRatioAll,aiSude corr:0.008328713453799803
# 2023-03-28 13:59:17,137 - ultron - INFO - hkHoldRatioAll,hkHoldRatioB corr:0.8459421971031793
# 2023-03-28 13:59:18,054 - ultron - INFO - hkHoldRatioAll,hkHoldVolChgB120 corr:0.03013818625615482
# 2023-03-28 13:59:18,954 - ultron - INFO - hkHoldRatioAll,lpnpQ corr:-0.05227731207943857
# TS CORR::81.82%
# 2023-03-28 13:59:19,876 - ultron - INFO - hkHoldRatioB,RSI corr:0.015435088257678838
# 2023-03-28 13:59:20,787 - ultron - INFO - hkHoldRatioB,VOL240 corr:0.3883789356714328
# 2023-03-28 13:59:21,702 - ultron - INFO - hkHoldRatioB,\mathrm{MA}(5, ''\text{ROC20}'') corr:-0.03338431112455677
# 2023-03-28 13:59:22,638 - ultron - INFO - hkHoldRatioB,aiDaNp60 corr:0.004220788140337824
# 2023-03-28 13:59:23,558 - ultron - INFO - hkHoldRatioB,aiDaPE60 corr:0.046868320238598764
# 2023-03-28 13:59:24,475 - ultron - INFO - hkHoldRatioB,aiEtopZ180 corr:0.07874802295667375
# 2023-03-28 13:59:25,375 - ultron - INFO - hkHoldRatioB,aiSude corr:0.04354207264434705
# 2023-03-28 13:59:26,293 - ultron - INFO - hkHoldRatioB,hkHoldRatioAll corr:0.8459421971031793
# 2023-03-28 13:59:27,208 - ultron - INFO - hkHoldRatioB,hkHoldVolChgB120 corr:0.18084241759855907
# 2023-03-28 13:59:28,126 - ultron - INFO - hkHoldRatioB,lpnpQ corr:0.014615275240098584
# TS CORR::90.91%
# 2023-03-28 13:59:29,051 - ultron - INFO - hkHoldVolChgB120,RSI corr:0.06213453359724361
# 2023-03-28 13:59:29,970 - ultron - INFO - hkHoldVolChgB120,VOL240 corr:0.02210686334097941
# 2023-03-28 13:59:30,879 - ultron - INFO - hkHoldVolChgB120,\mathrm{MA}(5, ''\text{ROC20}'') corr:0.035073359752272805
# 2023-03-28 13:59:31,798 - ultron - INFO - hkHoldVolChgB120,aiDaNp60 corr:0.02041016776879442
# 2023-03-28 13:59:32,719 - ultron - INFO - hkHoldVolChgB120,aiDaPE60 corr:-0.01846354772504569
# 2023-03-28 13:59:33,637 - ultron - INFO - hkHoldVolChgB120,aiEtopZ180 corr:-0.02667444636209793
# 2023-03-28 13:59:34,559 - ultron - INFO - hkHoldVolChgB120,aiSude corr:-0.05372229507666527
# 2023-03-28 13:59:35,476 - ultron - INFO - hkHoldVolChgB120,hkHoldRatioAll corr:0.030138186256154827
# 2023-03-28 13:59:36,385 - ultron - INFO - hkHoldVolChgB120,hkHoldRatioB corr:0.18084241759855907
# 2023-03-28 13:59:37,305 - ultron - INFO - hkHoldVolChgB120,lpnpQ corr:0.06362351888322815
# 2023-03-28 13:59:37,333 - ultron - INFO - start fetch dummy data
# TS CORR::100.0%
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# 2023-03-28 14:00:15,104 - ultron - INFO - init  :model_name:XGBRegressor        ,params:{'max_depth': 2, 'n_estimators': 80, 'learning_rate': 0.03},
# 2023-03-28 14:00:15,104 - ultron - INFO - start :model_name:XGBRegressor        ,params:{'max_depth': 2, 'n_estimators': 80, 'learning_rate': 0.03},fitness
# 2023-03-28 14:00:15,115 - ultron - INFO - init  :model_name:RandomForestRegressor,params:{'n_estimators': 10, 'max_depth': 9, 'min_samples_split': 40},
# 2023-03-28 14:00:15,116 - ultron - INFO - start :model_name:RandomForestRegressor,params:{'n_estimators': 10, 'max_depth': 9, 'min_samples_split': 40},fitness
# 2023-03-28 14:00:15,130 - ultron - INFO - init  :model_name:RidgeRegression     ,params:{'alpha': 0.95}               ,
# 2023-03-28 14:00:15,130 - ultron - INFO - start :model_name:RidgeRegression     ,params:{'alpha': 0.95}               ,fitness
# 2023-03-28 14:00:15,136 - ultron - INFO - init  :model_name:LGBMRegressor       ,params:{'max_depth': 9, 'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 66, 'min_data_in_leaf': 74, 'lambda_l2': 0.83},
# 2023-03-28 14:00:15,136 - ultron - INFO - start :model_name:LGBMRegressor       ,params:{'max_depth': 9, 'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 66, 'min_data_in_leaf': 74, 'lambda_l2': 0.83},fitness
# 2023-03-28 14:00:15,190 - ultron - INFO - fit   :model_name:XGBRegressor        ,params:{'max_depth': 2, 'n_estimators': 80, 'learning_rate': 0.03},sample weight
# 2023-03-28 14:00:15,203 - ultron - INFO - fit   :model_name:RandomForestRegressor,params:{'n_estimators': 10, 'max_depth': 9, 'min_samples_split': 40},sample weight
# 2023-03-28 14:00:15,224 - ultron - INFO - fit   :model_name:RidgeRegression     ,params:{'alpha': 0.95}               ,sample weight
# 2023-03-28 14:00:15,230 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 9, 'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 66, 'min_data_in_leaf': 74, 'lambda_l2': 0.83},sample weight
# 2023-03-28 14:00:15,242 - ultron - INFO - fit   :model_name:RidgeRegression     ,params:{'alpha': 0.95}               ,sample weight
# 2023-03-28 14:00:15,261 - ultron - INFO - fit   :model_name:RidgeRegression     ,params:{'alpha': 0.95}               ,sample weight
# 2023-03-28 14:00:15,278 - ultron - INFO - finish:model_name:RidgeRegression     ,params:{'alpha': 0.95}               ,fitness cost time:0.14767169952392578
# 2023-03-28 14:00:15,288 - ultron - INFO - init  :model_name:BayesianRegression  ,params:{'n_iter': 310}               ,
# 2023-03-28 14:00:15,289 - ultron - INFO - start :model_name:BayesianRegression  ,params:{'n_iter': 310}               ,fitness
# 2023-03-28 14:00:15,292 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 310}               ,sample weight
# [LightGBM] [Warning] lambda_l2 is set=0.83, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.83
# [LightGBM] [Warning] min_data_in_leaf is set=74, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=74
# 2023-03-28 14:00:15,307 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 310}               ,sample weight
# 2023-03-28 14:00:15,328 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 310}               ,sample weight
# 2023-03-28 14:00:15,351 - ultron - INFO - finish:model_name:BayesianRegression  ,params:{'n_iter': 310}               ,fitness cost time:0.06171441078186035
# 2023-03-28 14:00:15,372 - ultron - INFO - init  :model_name:XGBRegressor        ,params:{'max_depth': 8, 'n_estimators': 90, 'learning_rate': 0.09},
# 2023-03-28 14:00:15,373 - ultron - INFO - start :model_name:XGBRegressor        ,params:{'max_depth': 8, 'n_estimators': 90, 'learning_rate': 0.09},fitness
# 2023-03-28 14:00:15,376 - ultron - INFO - fit   :model_name:XGBRegressor        ,params:{'max_depth': 8, 'n_estimators': 90, 'learning_rate': 0.09},sample weight
# 2023-03-28 14:00:15,558 - ultron - INFO - fit   :model_name:RandomForestRegressor,params:{'n_estimators': 10, 'max_depth': 9, 'min_samples_split': 40},sample weight
# 2023-03-28 14:00:15,670 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 9, 'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 66, 'min_data_in_leaf': 74, 'lambda_l2': 0.83},sample weight
# [LightGBM] [Warning] lambda_l2 is set=0.83, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.83
# [LightGBM] [Warning] min_data_in_leaf is set=74, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=74
# 2023-03-28 14:00:15,775 - ultron - INFO - fit   :model_name:XGBRegressor        ,params:{'max_depth': 2, 'n_estimators': 80, 'learning_rate': 0.03},sample weight
# 2023-03-28 14:00:16,311 - ultron - INFO - fit   :model_name:RandomForestRegressor,params:{'n_estimators': 10, 'max_depth': 9, 'min_samples_split': 40},sample weight
# 2023-03-28 14:00:16,404 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 9, 'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 66, 'min_data_in_leaf': 74, 'lambda_l2': 0.83},sample weight
# [LightGBM] [Warning] lambda_l2 is set=0.83, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.83
# [LightGBM] [Warning] min_data_in_leaf is set=74, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=74
# 2023-03-28 14:00:16,925 - ultron - INFO - fit   :model_name:XGBRegressor        ,params:{'max_depth': 2, 'n_estimators': 80, 'learning_rate': 0.03},sample weight
# 2023-03-28 14:00:17,299 - ultron - INFO - finish:model_name:LGBMRegressor       ,params:{'max_depth': 9, 'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 66, 'min_data_in_leaf': 74, 'lambda_l2': 0.83},fitness cost time:2.1627209186553955
# 2023-03-28 14:00:17,492 - ultron - INFO - finish:model_name:RandomForestRegressor,params:{'n_estimators': 10, 'max_depth': 9, 'min_samples_split': 40},fitness cost time:2.3762857913970947
# [LightGBM] [Warning] lambda_l2 is set=0.83, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.83
# [LightGBM] [Warning] min_data_in_leaf is set=74, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=74
# 2023-03-28 14:00:17,619 - ultron - INFO - fit   :model_name:XGBRegressor        ,params:{'max_depth': 8, 'n_estimators': 90, 'learning_rate': 0.09},sample weight
# 2023-03-28 14:00:18,222 - ultron - INFO - init  :model_name:RandomForestRegressor,params:{'n_estimators': 80, 'max_depth': 16, 'min_samples_split': 90},
# 2023-03-28 14:00:18,222 - ultron - INFO - start :model_name:RandomForestRegressor,params:{'n_estimators': 80, 'max_depth': 16, 'min_samples_split': 90},fitness
# 2023-03-28 14:00:18,225 - ultron - INFO - fit   :model_name:RandomForestRegressor,params:{'n_estimators': 80, 'max_depth': 16, 'min_samples_split': 90},sample weight
# 2023-03-28 14:00:18,626 - ultron - INFO - finish:model_name:XGBRegressor        ,params:{'max_depth': 2, 'n_estimators': 80, 'learning_rate': 0.03},fitness cost time:3.5217978954315186
# 2023-03-28 14:00:19,133 - ultron - INFO - init  :model_name:BayesianRegression  ,params:{'n_iter': 330}               ,
# 2023-03-28 14:00:19,134 - ultron - INFO - start :model_name:BayesianRegression  ,params:{'n_iter': 330}               ,fitness
# 2023-03-28 14:00:19,140 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 330}               ,sample weight
# 2023-03-28 14:00:19,155 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 330}               ,sample weight
# 2023-03-28 14:00:19,175 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 330}               ,sample weight
# 2023-03-28 14:00:19,195 - ultron - INFO - finish:model_name:BayesianRegression  ,params:{'n_iter': 330}               ,fitness cost time:0.060327768325805664
# 2023-03-28 14:00:19,235 - ultron - INFO - init  :model_name:LGBMRegressor       ,params:{'max_depth': 7, 'n_estimators': 60, 'learning_rate': 0.03, 'num_leaves': 20, 'min_data_in_leaf': 23, 'lambda_l2': 0.73},
# 2023-03-28 14:00:19,235 - ultron - INFO - start :model_name:LGBMRegressor       ,params:{'max_depth': 7, 'n_estimators': 60, 'learning_rate': 0.03, 'num_leaves': 20, 'min_data_in_leaf': 23, 'lambda_l2': 0.73},fitness
# 2023-03-28 14:00:19,238 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 7, 'n_estimators': 60, 'learning_rate': 0.03, 'num_leaves': 20, 'min_data_in_leaf': 23, 'lambda_l2': 0.73},sample weight
# [LightGBM] [Warning] lambda_l2 is set=0.73, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.73
# [LightGBM] [Warning] min_data_in_leaf is set=23, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=23
# [LightGBM] [Warning] lambda_l2 is set=0.73, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.73
# [LightGBM] [Warning] min_data_in_leaf is set=23, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=23
# 2023-03-28 14:00:19,432 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 7, 'n_estimators': 60, 'learning_rate': 0.03, 'num_leaves': 20, 'min_data_in_leaf': 23, 'lambda_l2': 0.73},sample weight
# 2023-03-28 14:00:19,680 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 7, 'n_estimators': 60, 'learning_rate': 0.03, 'num_leaves': 20, 'min_data_in_leaf': 23, 'lambda_l2': 0.73},sample weight
# [LightGBM] [Warning] lambda_l2 is set=0.73, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.73
# [LightGBM] [Warning] min_data_in_leaf is set=23, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=23
# 2023-03-28 14:00:19,983 - ultron - INFO - finish:model_name:LGBMRegressor       ,params:{'max_depth': 7, 'n_estimators': 60, 'learning_rate': 0.03, 'num_leaves': 20, 'min_data_in_leaf': 23, 'lambda_l2': 0.73},fitness cost time:0.7483761310577393
# [LightGBM] [Warning] lambda_l2 is set=0.73, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.73
# [LightGBM] [Warning] min_data_in_leaf is set=23, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=23
# 2023-03-28 14:00:20,293 - ultron - INFO - init  :model_name:RidgeRegression     ,params:{'alpha': 0.75}               ,
# 2023-03-28 14:00:20,293 - ultron - INFO - start :model_name:RidgeRegression     ,params:{'alpha': 0.75}               ,fitness
# 2023-03-28 14:00:20,296 - ultron - INFO - fit   :model_name:RidgeRegression     ,params:{'alpha': 0.75}               ,sample weight
# 2023-03-28 14:00:20,308 - ultron - INFO - fit   :model_name:RidgeRegression     ,params:{'alpha': 0.75}               ,sample weight
# 2023-03-28 14:00:20,324 - ultron - INFO - fit   :model_name:RidgeRegression     ,params:{'alpha': 0.75}               ,sample weight
# 2023-03-28 14:00:20,339 - ultron - INFO - finish:model_name:RidgeRegression     ,params:{'alpha': 0.75}               ,fitness cost time:0.045380353927612305
# 2023-03-28 14:00:20,349 - ultron - INFO - init  :model_name:BayesianRegression  ,params:{'n_iter': 310}               ,
# 2023-03-28 14:00:20,349 - ultron - INFO - start :model_name:BayesianRegression  ,params:{'n_iter': 310}               ,fitness
# 2023-03-28 14:00:20,353 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 310}               ,sample weight
# 2023-03-28 14:00:20,366 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 310}               ,sample weight
# 2023-03-28 14:00:20,385 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 310}               ,sample weight
# 2023-03-28 14:00:20,405 - ultron - INFO - finish:model_name:BayesianRegression  ,params:{'n_iter': 310}               ,fitness cost time:0.05545806884765625
# 2023-03-28 14:00:20,425 - ultron - INFO - init  :model_name:XGBRegressor        ,params:{'max_depth': 5, 'n_estimators': 140, 'learning_rate': 0.03},
# 2023-03-28 14:00:20,426 - ultron - INFO - start :model_name:XGBRegressor        ,params:{'max_depth': 5, 'n_estimators': 140, 'learning_rate': 0.03},fitness
# 2023-03-28 14:00:20,429 - ultron - INFO - fit   :model_name:XGBRegressor        ,params:{'max_depth': 5, 'n_estimators': 140, 'learning_rate': 0.03},sample weight
# 2023-03-28 14:00:20,945 - ultron - INFO - init  :model_name:BayesianRegression  ,params:{'n_iter': 260}               ,
# 2023-03-28 14:00:20,945 - ultron - INFO - start :model_name:BayesianRegression  ,params:{'n_iter': 260}               ,fitness
# 2023-03-28 14:00:20,951 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 260}               ,sample weight
# 2023-03-28 14:00:20,981 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 260}               ,sample weight
# 2023-03-28 14:00:21,003 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 260}               ,sample weight
# 2023-03-28 14:00:21,026 - ultron - INFO - finish:model_name:BayesianRegression  ,params:{'n_iter': 260}               ,fitness cost time:0.08086705207824707
# 2023-03-28 14:00:21,048 - ultron - INFO - init  :model_name:RidgeRegression     ,params:{'alpha': 0.95}               ,
# 2023-03-28 14:00:21,048 - ultron - INFO - start :model_name:RidgeRegression     ,params:{'alpha': 0.95}               ,fitness
# 2023-03-28 14:00:21,052 - ultron - INFO - fit   :model_name:RidgeRegression     ,params:{'alpha': 0.95}               ,sample weight
# 2023-03-28 14:00:21,064 - ultron - INFO - fit   :model_name:RidgeRegression     ,params:{'alpha': 0.95}               ,sample weight
# 2023-03-28 14:00:21,080 - ultron - INFO - fit   :model_name:RidgeRegression     ,params:{'alpha': 0.95}               ,sample weight
# 2023-03-28 14:00:21,095 - ultron - INFO - finish:model_name:RidgeRegression     ,params:{'alpha': 0.95}               ,fitness cost time:0.04690098762512207
# 2023-03-28 14:00:21,107 - ultron - INFO - init  :model_name:RidgeRegression     ,params:{'alpha': 0.9}                ,
# 2023-03-28 14:00:21,107 - ultron - INFO - start :model_name:RidgeRegression     ,params:{'alpha': 0.9}                ,fitness
# 2023-03-28 14:00:21,110 - ultron - INFO - fit   :model_name:RidgeRegression     ,params:{'alpha': 0.9}                ,sample weight
# 2023-03-28 14:00:21,122 - ultron - INFO - fit   :model_name:RidgeRegression     ,params:{'alpha': 0.9}                ,sample weight
# 2023-03-28 14:00:21,138 - ultron - INFO - fit   :model_name:RidgeRegression     ,params:{'alpha': 0.9}                ,sample weight
# 2023-03-28 14:00:21,153 - ultron - INFO - finish:model_name:RidgeRegression     ,params:{'alpha': 0.9}                ,fitness cost time:0.04627060890197754
# 2023-03-28 14:00:21,165 - ultron - INFO - init  :model_name:XGBRegressor        ,params:{'max_depth': 5, 'n_estimators': 130, 'learning_rate': 0.03},
# 2023-03-28 14:00:21,166 - ultron - INFO - start :model_name:XGBRegressor        ,params:{'max_depth': 5, 'n_estimators': 130, 'learning_rate': 0.03},fitness
# 2023-03-28 14:00:21,169 - ultron - INFO - fit   :model_name:XGBRegressor        ,params:{'max_depth': 5, 'n_estimators': 130, 'learning_rate': 0.03},sample weight
# 2023-03-28 14:00:21,627 - ultron - INFO - fit   :model_name:RandomForestRegressor,params:{'n_estimators': 80, 'max_depth': 16, 'min_samples_split': 90},sample weight
# 2023-03-28 14:00:22,332 - ultron - INFO - fit   :model_name:XGBRegressor        ,params:{'max_depth': 8, 'n_estimators': 90, 'learning_rate': 0.09},sample weight
# 2023-03-28 14:00:22,712 - ultron - INFO - fit   :model_name:XGBRegressor        ,params:{'max_depth': 5, 'n_estimators': 140, 'learning_rate': 0.03},sample weight
# 2023-03-28 14:00:23,290 - ultron - INFO - fit   :model_name:XGBRegressor        ,params:{'max_depth': 5, 'n_estimators': 130, 'learning_rate': 0.03},sample weight
# 2023-03-28 14:00:27,433 - ultron - INFO - fit   :model_name:XGBRegressor        ,params:{'max_depth': 5, 'n_estimators': 140, 'learning_rate': 0.03},sample weight
# 2023-03-28 14:00:27,670 - ultron - INFO - fit   :model_name:XGBRegressor        ,params:{'max_depth': 5, 'n_estimators': 130, 'learning_rate': 0.03},sample weight
# 2023-03-28 14:00:29,516 - ultron - INFO - finish:model_name:XGBRegressor        ,params:{'max_depth': 8, 'n_estimators': 90, 'learning_rate': 0.09},fitness cost time:14.1428542137146
# 2023-03-28 14:00:29,798 - ultron - INFO - fit   :model_name:RandomForestRegressor,params:{'n_estimators': 80, 'max_depth': 16, 'min_samples_split': 90},sample weight
# 2023-03-28 14:00:34,223 - ultron - INFO - finish:model_name:XGBRegressor        ,params:{'max_depth': 5, 'n_estimators': 130, 'learning_rate': 0.03},fitness cost time:13.057215929031372
# 2023-03-28 14:00:34,544 - ultron - INFO - finish:model_name:XGBRegressor        ,params:{'max_depth': 5, 'n_estimators': 140, 'learning_rate': 0.03},fitness cost time:14.117625951766968
# 2023-03-28 14:00:40,079 - ultron - INFO - init  :model_name:RandomForestRegressor,params:{'n_estimators': 10, 'max_depth': 42, 'min_samples_split': 74},
# 2023-03-28 14:00:40,080 - ultron - INFO - start :model_name:RandomForestRegressor,params:{'n_estimators': 10, 'max_depth': 42, 'min_samples_split': 74},fitness
# 2023-03-28 14:00:40,084 - ultron - INFO - fit   :model_name:RandomForestRegressor,params:{'n_estimators': 10, 'max_depth': 42, 'min_samples_split': 74},sample weight
# 2023-03-28 14:00:40,538 - ultron - INFO - fit   :model_name:RandomForestRegressor,params:{'n_estimators': 10, 'max_depth': 42, 'min_samples_split': 74},sample weight
# 2023-03-28 14:00:41,724 - ultron - INFO - fit   :model_name:RandomForestRegressor,params:{'n_estimators': 10, 'max_depth': 42, 'min_samples_split': 74},sample weight
# 2023-03-28 14:00:43,161 - ultron - INFO - finish:model_name:RandomForestRegressor,params:{'n_estimators': 80, 'max_depth': 16, 'min_samples_split': 90},fitness cost time:24.93907904624939
# 2023-03-28 14:00:43,200 - ultron - INFO - init  :model_name:LGBMRegressor       ,params:{'max_depth': 9, 'n_estimators': 100, 'learning_rate': 0.07, 'num_leaves': 69, 'min_data_in_leaf': 84, 'lambda_l2': 0.01},
# 2023-03-28 14:00:43,200 - ultron - INFO - start :model_name:LGBMRegressor       ,params:{'max_depth': 9, 'n_estimators': 100, 'learning_rate': 0.07, 'num_leaves': 69, 'min_data_in_leaf': 84, 'lambda_l2': 0.01},fitness
# 2023-03-28 14:00:43,204 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 9, 'n_estimators': 100, 'learning_rate': 0.07, 'num_leaves': 69, 'min_data_in_leaf': 84, 'lambda_l2': 0.01},sample weight
# [LightGBM] [Warning] lambda_l2 is set=0.01, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.01
# [LightGBM] [Warning] min_data_in_leaf is set=84, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=84
# 2023-03-28 14:00:43,527 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 9, 'n_estimators': 100, 'learning_rate': 0.07, 'num_leaves': 69, 'min_data_in_leaf': 84, 'lambda_l2': 0.01},sample weight
# [LightGBM] [Warning] lambda_l2 is set=0.01, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.01
# [LightGBM] [Warning] min_data_in_leaf is set=84, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=84
# 2023-03-28 14:00:43,738 - ultron - INFO - finish:model_name:RandomForestRegressor,params:{'n_estimators': 10, 'max_depth': 42, 'min_samples_split': 74},fitness cost time:3.6576173305511475
# 2023-03-28 14:00:43,996 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 9, 'n_estimators': 100, 'learning_rate': 0.07, 'num_leaves': 69, 'min_data_in_leaf': 84, 'lambda_l2': 0.01},sample weight
# 2023-03-28 14:00:44,158 - ultron - INFO - init  :model_name:LGBMRegressor       ,params:{'max_depth': 6, 'n_estimators': 130, 'learning_rate': 0.07, 'num_leaves': 72, 'min_data_in_leaf': 64, 'lambda_l2': 0.05},
# 2023-03-28 14:00:44,158 - ultron - INFO - start :model_name:LGBMRegressor       ,params:{'max_depth': 6, 'n_estimators': 130, 'learning_rate': 0.07, 'num_leaves': 72, 'min_data_in_leaf': 64, 'lambda_l2': 0.05},fitness
# 2023-03-28 14:00:44,162 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 6, 'n_estimators': 130, 'learning_rate': 0.07, 'num_leaves': 72, 'min_data_in_leaf': 64, 'lambda_l2': 0.05},sample weight
# [LightGBM] [Warning] lambda_l2 is set=0.01, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.01
# [LightGBM] [Warning] min_data_in_leaf is set=84, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=84
# 2023-03-28 14:00:44,492 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 6, 'n_estimators': 130, 'learning_rate': 0.07, 'num_leaves': 72, 'min_data_in_leaf': 64, 'lambda_l2': 0.05},sample weight
# 2023-03-28 14:00:44,617 - ultron - INFO - finish:model_name:LGBMRegressor       ,params:{'max_depth': 9, 'n_estimators': 100, 'learning_rate': 0.07, 'num_leaves': 69, 'min_data_in_leaf': 84, 'lambda_l2': 0.01},fitness cost time:1.4167180061340332
# [LightGBM] [Warning] lambda_l2 is set=0.05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.05
# [LightGBM] [Warning] min_data_in_leaf is set=64, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=64
# [LightGBM] [Warning] lambda_l2 is set=0.01, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.01
# [LightGBM] [Warning] min_data_in_leaf is set=84, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=84
# 2023-03-28 14:00:44,921 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 6, 'n_estimators': 130, 'learning_rate': 0.07, 'num_leaves': 72, 'min_data_in_leaf': 64, 'lambda_l2': 0.05},sample weight
# [LightGBM] [Warning] lambda_l2 is set=0.05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.05
# [LightGBM] [Warning] min_data_in_leaf is set=64, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=64
# 2023-03-28 14:00:45,347 - ultron - INFO - init  :model_name:BayesianRegression  ,params:{'n_iter': 260}               ,
# 2023-03-28 14:00:45,348 - ultron - INFO - start :model_name:BayesianRegression  ,params:{'n_iter': 260}               ,fitness
# 2023-03-28 14:00:45,351 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 260}               ,sample weight
# 2023-03-28 14:00:45,365 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 260}               ,sample weight
# 2023-03-28 14:00:45,382 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 260}               ,sample weight
# 2023-03-28 14:00:45,399 - ultron - INFO - finish:model_name:BayesianRegression  ,params:{'n_iter': 260}               ,fitness cost time:0.050942182540893555
# 2023-03-28 14:00:45,417 - ultron - INFO - init  :model_name:BayesianRegression  ,params:{'n_iter': 280}               ,
# 2023-03-28 14:00:45,417 - ultron - INFO - start :model_name:BayesianRegression  ,params:{'n_iter': 280}               ,fitness
# 2023-03-28 14:00:45,420 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 280}               ,sample weight
# 2023-03-28 14:00:45,433 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 280}               ,sample weight
# 2023-03-28 14:00:45,451 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 280}               ,sample weight
# 2023-03-28 14:00:45,469 - ultron - INFO - finish:model_name:BayesianRegression  ,params:{'n_iter': 280}               ,fitness cost time:0.0521543025970459
# 2023-03-28 14:00:45,480 - ultron - INFO - finish:model_name:LGBMRegressor       ,params:{'max_depth': 6, 'n_estimators': 130, 'learning_rate': 0.07, 'num_leaves': 72, 'min_data_in_leaf': 64, 'lambda_l2': 0.05},fitness cost time:1.3217260837554932
# 2023-03-28 14:00:45,488 - ultron - INFO - init  :model_name:XGBRegressor        ,params:{'max_depth': 7, 'n_estimators': 120, 'learning_rate': 0.07},
# 2023-03-28 14:00:45,489 - ultron - INFO - start :model_name:XGBRegressor        ,params:{'max_depth': 7, 'n_estimators': 120, 'learning_rate': 0.07},fitness
# 2023-03-28 14:00:45,492 - ultron - INFO - fit   :model_name:XGBRegressor        ,params:{'max_depth': 7, 'n_estimators': 120, 'learning_rate': 0.07},sample weight
# [LightGBM] [Warning] lambda_l2 is set=0.05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.05
# [LightGBM] [Warning] min_data_in_leaf is set=64, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=64
# 2023-03-28 14:00:46,095 - ultron - INFO - init  :model_name:BayesianRegression  ,params:{'n_iter': 250}               ,
# 2023-03-28 14:00:46,096 - ultron - INFO - start :model_name:BayesianRegression  ,params:{'n_iter': 250}               ,fitness
# 2023-03-28 14:00:46,099 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 250}               ,sample weight
# 2023-03-28 14:00:46,113 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 250}               ,sample weight
# 2023-03-28 14:00:46,129 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 250}               ,sample weight
# 2023-03-28 14:00:46,145 - ultron - INFO - finish:model_name:BayesianRegression  ,params:{'n_iter': 250}               ,fitness cost time:0.04927682876586914
# 2023-03-28 14:00:46,161 - ultron - INFO - init  :model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.05},
# 2023-03-28 14:00:46,162 - ultron - INFO - start :model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.05},fitness
# 2023-03-28 14:00:46,165 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.05},sample weight
# 2023-03-28 14:00:46,176 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.05},sample weight
# 2023-03-28 14:00:46,189 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.05},sample weight
# 2023-03-28 14:00:46,201 - ultron - INFO - finish:model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.05},fitness cost time:0.038931846618652344
# 2023-03-28 14:00:46,219 - ultron - INFO - init  :model_name:RandomForestRegressor,params:{'n_estimators': 60, 'max_depth': 6, 'min_samples_split': 90},
# 2023-03-28 14:00:46,220 - ultron - INFO - start :model_name:RandomForestRegressor,params:{'n_estimators': 60, 'max_depth': 6, 'min_samples_split': 90},fitness
# 2023-03-28 14:00:46,223 - ultron - INFO - fit   :model_name:RandomForestRegressor,params:{'n_estimators': 60, 'max_depth': 6, 'min_samples_split': 90},sample weight
# 2023-03-28 14:00:47,067 - ultron - INFO - init  :model_name:LGBMRegressor       ,params:{'max_depth': 9, 'n_estimators': 100, 'learning_rate': 0.02, 'num_leaves': 23, 'min_data_in_leaf': 54, 'lambda_l2': 0.22},
# 2023-03-28 14:00:47,067 - ultron - INFO - start :model_name:LGBMRegressor       ,params:{'max_depth': 9, 'n_estimators': 100, 'learning_rate': 0.02, 'num_leaves': 23, 'min_data_in_leaf': 54, 'lambda_l2': 0.22},fitness
# 2023-03-28 14:00:47,071 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 9, 'n_estimators': 100, 'learning_rate': 0.02, 'num_leaves': 23, 'min_data_in_leaf': 54, 'lambda_l2': 0.22},sample weight
# [LightGBM] [Warning] lambda_l2 is set=0.22, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.22
# [LightGBM] [Warning] min_data_in_leaf is set=54, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=54
# 2023-03-28 14:00:47,401 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 9, 'n_estimators': 100, 'learning_rate': 0.02, 'num_leaves': 23, 'min_data_in_leaf': 54, 'lambda_l2': 0.22},sample weight
# [LightGBM] [Warning] lambda_l2 is set=0.22, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.22
# [LightGBM] [Warning] min_data_in_leaf is set=54, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=54
# 2023-03-28 14:00:47,758 - ultron - INFO - fit   :model_name:RandomForestRegressor,params:{'n_estimators': 60, 'max_depth': 6, 'min_samples_split': 90},sample weight
# 2023-03-28 14:00:47,801 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 9, 'n_estimators': 100, 'learning_rate': 0.02, 'num_leaves': 23, 'min_data_in_leaf': 54, 'lambda_l2': 0.22},sample weight
# [LightGBM] [Warning] lambda_l2 is set=0.22, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.22
# [LightGBM] [Warning] min_data_in_leaf is set=54, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=54
# 2023-03-28 14:00:48,188 - ultron - INFO - fit   :model_name:XGBRegressor        ,params:{'max_depth': 7, 'n_estimators': 120, 'learning_rate': 0.07},sample weight
# 2023-03-28 14:00:48,284 - ultron - INFO - finish:model_name:LGBMRegressor       ,params:{'max_depth': 9, 'n_estimators': 100, 'learning_rate': 0.02, 'num_leaves': 23, 'min_data_in_leaf': 54, 'lambda_l2': 0.22},fitness cost time:1.2165358066558838
# [LightGBM] [Warning] lambda_l2 is set=0.22, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.22
# [LightGBM] [Warning] min_data_in_leaf is set=54, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=54
# 2023-03-28 14:00:48,811 - ultron - INFO - init  :model_name:LGBMRegressor       ,params:{'max_depth': 6, 'n_estimators': 60, 'learning_rate': 0.07, 'num_leaves': 66, 'min_data_in_leaf': 96, 'lambda_l2': 0.32},
# 2023-03-28 14:00:48,812 - ultron - INFO - start :model_name:LGBMRegressor       ,params:{'max_depth': 6, 'n_estimators': 60, 'learning_rate': 0.07, 'num_leaves': 66, 'min_data_in_leaf': 96, 'lambda_l2': 0.32},fitness
# 2023-03-28 14:00:48,815 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 6, 'n_estimators': 60, 'learning_rate': 0.07, 'num_leaves': 66, 'min_data_in_leaf': 96, 'lambda_l2': 0.32},sample weight
# 2023-03-28 14:00:48,976 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 6, 'n_estimators': 60, 'learning_rate': 0.07, 'num_leaves': 66, 'min_data_in_leaf': 96, 'lambda_l2': 0.32},sample weight
# [LightGBM] [Warning] lambda_l2 is set=0.32, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.32
# [LightGBM] [Warning] min_data_in_leaf is set=96, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=96
# 2023-03-28 14:00:49,204 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 6, 'n_estimators': 60, 'learning_rate': 0.07, 'num_leaves': 66, 'min_data_in_leaf': 96, 'lambda_l2': 0.32},sample weight
# [LightGBM] [Warning] lambda_l2 is set=0.32, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.32
# [LightGBM] [Warning] min_data_in_leaf is set=96, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=96
# 2023-03-28 14:00:49,492 - ultron - INFO - finish:model_name:LGBMRegressor       ,params:{'max_depth': 6, 'n_estimators': 60, 'learning_rate': 0.07, 'num_leaves': 66, 'min_data_in_leaf': 96, 'lambda_l2': 0.32},fitness cost time:0.6802489757537842
# [LightGBM] [Warning] lambda_l2 is set=0.32, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.32
# [LightGBM] [Warning] min_data_in_leaf is set=96, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=96
# 2023-03-28 14:00:49,827 - ultron - INFO - init  :model_name:XGBRegressor        ,params:{'max_depth': 7, 'n_estimators': 140, 'learning_rate': 0.05},
# 2023-03-28 14:00:49,827 - ultron - INFO - start :model_name:XGBRegressor        ,params:{'max_depth': 7, 'n_estimators': 140, 'learning_rate': 0.05},fitness
# 2023-03-28 14:00:49,830 - ultron - INFO - fit   :model_name:XGBRegressor        ,params:{'max_depth': 7, 'n_estimators': 140, 'learning_rate': 0.05},sample weight
# 2023-03-28 14:00:50,942 - ultron - INFO - fit   :model_name:RandomForestRegressor,params:{'n_estimators': 60, 'max_depth': 6, 'min_samples_split': 90},sample weight
# 2023-03-28 14:00:52,877 - ultron - INFO - fit   :model_name:XGBRegressor        ,params:{'max_depth': 7, 'n_estimators': 140, 'learning_rate': 0.05},sample weight
# 2023-03-28 14:00:53,732 - ultron - INFO - fit   :model_name:XGBRegressor        ,params:{'max_depth': 7, 'n_estimators': 120, 'learning_rate': 0.07},sample weight
# 2023-03-28 14:00:55,899 - ultron - INFO - finish:model_name:RandomForestRegressor,params:{'n_estimators': 60, 'max_depth': 6, 'min_samples_split': 90},fitness cost time:9.679785966873169
# 2023-03-28 14:00:59,320 - ultron - INFO - fit   :model_name:XGBRegressor        ,params:{'max_depth': 7, 'n_estimators': 140, 'learning_rate': 0.05},sample weight
# 2023-03-28 14:01:02,287 - ultron - INFO - finish:model_name:XGBRegressor        ,params:{'max_depth': 7, 'n_estimators': 120, 'learning_rate': 0.07},fitness cost time:16.798177480697632
# 2023-03-28 14:01:02,648 - ultron - INFO - init  :model_name:BayesianRegression  ,params:{'n_iter': 250}               ,
# 2023-03-28 14:01:02,648 - ultron - INFO - start :model_name:BayesianRegression  ,params:{'n_iter': 250}               ,fitness
# 2023-03-28 14:01:02,653 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 250}               ,sample weight
# 2023-03-28 14:01:02,669 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 250}               ,sample weight
# 2023-03-28 14:01:02,687 - ultron - INFO - fit   :model_name:BayesianRegression  ,params:{'n_iter': 250}               ,sample weight
# 2023-03-28 14:01:02,703 - ultron - INFO - init  :model_name:RandomForestRegressor,params:{'n_estimators': 30, 'max_depth': 42, 'min_samples_split': 84},
# 2023-03-28 14:01:02,704 - ultron - INFO - start :model_name:RandomForestRegressor,params:{'n_estimators': 30, 'max_depth': 42, 'min_samples_split': 84},fitness
# 2023-03-28 14:01:02,706 - ultron - INFO - finish:model_name:BayesianRegression  ,params:{'n_iter': 250}               ,fitness cost time:0.05772113800048828
# 2023-03-28 14:01:02,708 - ultron - INFO - fit   :model_name:RandomForestRegressor,params:{'n_estimators': 30, 'max_depth': 42, 'min_samples_split': 84},sample weight
# 2023-03-28 14:01:02,744 - ultron - INFO - init  :model_name:LGBMRegressor       ,params:{'max_depth': 6, 'n_estimators': 60, 'learning_rate': 0.09, 'num_leaves': 35, 'min_data_in_leaf': 48, 'lambda_l2': 0.79},
# 2023-03-28 14:01:02,745 - ultron - INFO - start :model_name:LGBMRegressor       ,params:{'max_depth': 6, 'n_estimators': 60, 'learning_rate': 0.09, 'num_leaves': 35, 'min_data_in_leaf': 48, 'lambda_l2': 0.79},fitness
# 2023-03-28 14:01:02,748 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 6, 'n_estimators': 60, 'learning_rate': 0.09, 'num_leaves': 35, 'min_data_in_leaf': 48, 'lambda_l2': 0.79},sample weight
# 2023-03-28 14:01:02,933 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 6, 'n_estimators': 60, 'learning_rate': 0.09, 'num_leaves': 35, 'min_data_in_leaf': 48, 'lambda_l2': 0.79},sample weight
# [LightGBM] [Warning] lambda_l2 is set=0.79, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.79
# [LightGBM] [Warning] min_data_in_leaf is set=48, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=48
# 2023-03-28 14:01:03,177 - ultron - INFO - fit   :model_name:LGBMRegressor       ,params:{'max_depth': 6, 'n_estimators': 60, 'learning_rate': 0.09, 'num_leaves': 35, 'min_data_in_leaf': 48, 'lambda_l2': 0.79},sample weight
# [LightGBM] [Warning] lambda_l2 is set=0.79, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.79
# [LightGBM] [Warning] min_data_in_leaf is set=48, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=48
# 2023-03-28 14:01:03,481 - ultron - INFO - finish:model_name:LGBMRegressor       ,params:{'max_depth': 6, 'n_estimators': 60, 'learning_rate': 0.09, 'num_leaves': 35, 'min_data_in_leaf': 48, 'lambda_l2': 0.79},fitness cost time:0.7359154224395752
# [LightGBM] [Warning] lambda_l2 is set=0.79, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.79
# [LightGBM] [Warning] min_data_in_leaf is set=48, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=48
# 2023-03-28 14:01:03,825 - ultron - INFO - init  :model_name:RidgeRegression     ,params:{'alpha': 0.35}               ,
# 2023-03-28 14:01:03,825 - ultron - INFO - start :model_name:RidgeRegression     ,params:{'alpha': 0.35}               ,fitness
# 2023-03-28 14:01:03,828 - ultron - INFO - fit   :model_name:RidgeRegression     ,params:{'alpha': 0.35}               ,sample weight
# 2023-03-28 14:01:03,839 - ultron - INFO - fit   :model_name:RidgeRegression     ,params:{'alpha': 0.35}               ,sample weight
# 2023-03-28 14:01:03,853 - ultron - INFO - fit   :model_name:RidgeRegression     ,params:{'alpha': 0.35}               ,sample weight
# 2023-03-28 14:01:03,867 - ultron - INFO - finish:model_name:RidgeRegression     ,params:{'alpha': 0.35}               ,fitness cost time:0.0416569709777832
# 2023-03-28 14:01:03,876 - ultron - INFO - init  :model_name:RidgeRegression     ,params:{'alpha': 0.55}               ,
# 2023-03-28 14:01:03,876 - ultron - INFO - start :model_name:RidgeRegression     ,params:{'alpha': 0.55}               ,fitness
# 2023-03-28 14:01:03,879 - ultron - INFO - fit   :model_name:RidgeRegression     ,params:{'alpha': 0.55}               ,sample weight
# 2023-03-28 14:01:03,890 - ultron - INFO - fit   :model_name:RidgeRegression     ,params:{'alpha': 0.55}               ,sample weight
# 2023-03-28 14:01:03,903 - ultron - INFO - fit   :model_name:RidgeRegression     ,params:{'alpha': 0.55}               ,sample weight
# ...
# 2023-03-28 14:06:29,951 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.06},sample weight
# 2023-03-28 14:06:29,964 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.06},sample weight
# 2023-03-28 14:06:29,980 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.06},sample weight
# 2023-03-28 14:06:29,993 - ultron - INFO - finish:model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.06},fitness cost time:0.04593515396118164
# 2023-03-28 14:06:30,048 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.8, 'alpha': 0.07},
# 2023-03-28 14:06:30,049 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.35, 'alpha': 0.03},
# 2023-03-28 14:06:30,049 - ultron - INFO - start :model_name:ElasticNetRegression,params:{'l1_ratio': 0.35, 'alpha': 0.03},fitness
# 2023-03-28 14:06:30,053 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.35, 'alpha': 0.03},sample weight
# 2023-03-28 14:06:30,066 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.35, 'alpha': 0.03},sample weight
# 2023-03-28 14:06:30,083 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.35, 'alpha': 0.03},sample weight
# 2023-03-28 14:06:30,098 - ultron - INFO - finish:model_name:ElasticNetRegression,params:{'l1_ratio': 0.35, 'alpha': 0.03},fitness cost time:0.04870152473449707
# 2023-03-28 14:06:30,154 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.03},
# 2023-03-28 14:06:30,155 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.03},
# 2023-03-28 14:06:30,155 - ultron - INFO - start :model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.03},fitness
# 2023-03-28 14:06:30,158 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.03},sample weight
# 2023-03-28 14:06:30,170 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.03},sample weight
# 2023-03-28 14:06:30,183 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.03},sample weight
# 2023-03-28 14:06:30,195 - ultron - INFO - finish:model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.03},fitness cost time:0.039762020111083984
# 2023-03-28 14:06:30,249 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.02},
# 2023-03-28 14:06:30,251 - ultron - INFO - init  :model_name:ElasticNetRegression,params:{'l1_ratio': 0.35, 'alpha': 0.01},
# 2023-03-28 14:06:30,252 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.35, 'alpha': 0.01},
# 2023-03-28 14:06:30,252 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.35, 'alpha': 0.01},
# 2023-03-28 14:06:30,252 - ultron - INFO - start :model_name:ElasticNetRegression,params:{'l1_ratio': 0.35, 'alpha': 0.01},fitness
# 2023-03-28 14:06:30,255 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.35, 'alpha': 0.01},sample weight
# 2023-03-28 14:06:30,267 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.35, 'alpha': 0.01},sample weight
# 2023-03-28 14:06:30,283 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.35, 'alpha': 0.01},sample weight
# 2023-03-28 14:06:30,296 - ultron - INFO - finish:model_name:ElasticNetRegression,params:{'l1_ratio': 0.35, 'alpha': 0.01},fitness cost time:0.043290138244628906
# 2023-03-28 14:06:30,352 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.06},
# 2023-03-28 14:06:30,352 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.06},
# 2023-03-28 14:06:30,353 - ultron - INFO - start :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.06},fitness
# 2023-03-28 14:06:30,356 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.06},sample weight
# 2023-03-28 14:06:30,367 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.06},sample weight
# 2023-03-28 14:06:30,380 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.06},sample weight
# 2023-03-28 14:06:30,391 - ultron - INFO - finish:model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.06},fitness cost time:0.03859281539916992
# 2023-03-28 14:06:30,445 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.06},
# 2023-03-28 14:06:30,445 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.06},
# 2023-03-28 14:06:30,445 - ultron - INFO - start :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.06},fitness
# 2023-03-28 14:06:30,448 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.06},sample weight
# 2023-03-28 14:06:30,459 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.06},sample weight
# 2023-03-28 14:06:30,472 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.06},sample weight
# 2023-03-28 14:06:30,484 - ultron - INFO - finish:model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.06},fitness cost time:0.038347721099853516
# 2023-03-28 14:06:30,537 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.06},
# 2023-03-28 14:06:30,540 - ultron - INFO - init  :model_name:ElasticNetRegression,params:{'l1_ratio': 0.65, 'alpha': 0.08},
# 2023-03-28 14:06:30,540 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.65, 'alpha': 0.08},
# 2023-03-28 14:06:30,564 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.65, 'alpha': 0.06},
# 2023-03-28 14:06:30,564 - ultron - INFO - start :model_name:ElasticNetRegression,params:{'l1_ratio': 0.65, 'alpha': 0.06},fitness
# 2023-03-28 14:06:30,567 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.65, 'alpha': 0.06},sample weight
# 2023-03-28 14:06:30,579 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.65, 'alpha': 0.06},sample weight
# 2023-03-28 14:06:30,592 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.65, 'alpha': 0.06},sample weight
# 2023-03-28 14:06:30,603 - ultron - INFO - finish:model_name:ElasticNetRegression,params:{'l1_ratio': 0.65, 'alpha': 0.06},fitness cost time:0.038918495178222656
# 2023-03-28 14:06:30,657 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.04},
# 2023-03-28 14:06:30,660 - ultron - INFO - init  :model_name:ElasticNetRegression,params:{'l1_ratio': 0.65, 'alpha': 0.01},
# 2023-03-28 14:06:30,660 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.01},
# 2023-03-28 14:06:30,660 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.01},
# 2023-03-28 14:06:30,661 - ultron - INFO - start :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.01},fitness
# 2023-03-28 14:06:30,664 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.01},sample weight
# 2023-03-28 14:06:30,676 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.01},sample weight
# 2023-03-28 14:06:30,690 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.01},sample weight
# 2023-03-28 14:06:30,702 - ultron - INFO - finish:model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.01},fitness cost time:0.041826725006103516
# 2023-03-28 14:06:30,757 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.0},
# 2023-03-28 14:06:30,760 - ultron - INFO - init  :model_name:ElasticNetRegression,params:{'l1_ratio': 0.45, 'alpha': 0.0},
# 2023-03-28 14:06:30,761 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.0},
# 2023-03-28 14:06:30,761 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.0},
# 2023-03-28 14:06:30,761 - ultron - INFO - start :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.0},fitness
# 2023-03-28 14:06:30,764 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.0},sample weight
# 2023-03-28 14:06:30,850 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.0},sample weight
# 2023-03-28 14:06:31,018 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.0},sample weight
# 2023-03-28 14:06:31,237 - ultron - INFO - finish:model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.0},fitness cost time:0.4760782718658447
# 2023-03-28 14:06:31,514 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.04},
# 2023-03-28 14:06:31,515 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.07},
# 2023-03-28 14:06:31,515 - ultron - INFO - start :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.07},fitness
# 2023-03-28 14:06:31,518 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.07},sample weight
# 2023-03-28 14:06:31,529 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.07},sample weight
# 2023-03-28 14:06:31,542 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.07},sample weight
# 2023-03-28 14:06:31,553 - ultron - INFO - finish:model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.07},fitness cost time:0.03831601142883301
# 2023-03-28 14:06:31,607 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.07},
# 2023-03-28 14:06:31,607 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.05},
# 2023-03-28 14:06:31,608 - ultron - INFO - start :model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.05},fitness
# 2023-03-28 14:06:31,611 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.05},sample weight
# 2023-03-28 14:06:31,622 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.05},sample weight
# 2023-03-28 14:06:31,635 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.05},sample weight
# 2023-03-28 14:06:31,646 - ultron - INFO - finish:model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.05},fitness cost time:0.03830862045288086
# 2023-03-28 14:06:31,699 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.05},
# 2023-03-28 14:06:31,702 - ultron - INFO - init  :model_name:ElasticNetRegression,params:{'l1_ratio': 0.1, 'alpha': 0.0},
# 2023-03-28 14:06:31,703 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.1, 'alpha': 0.0},
# 2023-03-28 14:06:31,703 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.05, 'alpha': 0.07},
# 2023-03-28 14:06:31,703 - ultron - INFO - start :model_name:ElasticNetRegression,params:{'l1_ratio': 0.05, 'alpha': 0.07},fitness
# 2023-03-28 14:06:31,706 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.05, 'alpha': 0.07},sample weight
# 2023-03-28 14:06:31,718 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.05, 'alpha': 0.07},sample weight
# 2023-03-28 14:06:31,733 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.05, 'alpha': 0.07},sample weight
# 2023-03-28 14:06:31,745 - ultron - INFO - finish:model_name:ElasticNetRegression,params:{'l1_ratio': 0.05, 'alpha': 0.07},fitness cost time:0.041814565658569336
# 2023-03-28 14:06:31,801 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.65, 'alpha': 0.04},
# 2023-03-28 14:06:31,804 - ultron - INFO - init  :model_name:ElasticNetRegression,params:{'l1_ratio': 0.4, 'alpha': 0.01},
# 2023-03-28 14:06:31,805 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.4, 'alpha': 0.01},
# 2023-03-28 14:06:31,805 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.4, 'alpha': 0.01},
# 2023-03-28 14:06:31,805 - ultron - INFO - start :model_name:ElasticNetRegression,params:{'l1_ratio': 0.4, 'alpha': 0.01},fitness
# 2023-03-28 14:06:31,808 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.4, 'alpha': 0.01},sample weight
# 2023-03-28 14:06:31,820 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.4, 'alpha': 0.01},sample weight
# 2023-03-28 14:06:31,835 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.4, 'alpha': 0.01},sample weight
# 2023-03-28 14:06:31,848 - ultron - INFO - finish:model_name:ElasticNetRegression,params:{'l1_ratio': 0.4, 'alpha': 0.01},fitness cost time:0.04258871078491211
# 2023-03-28 14:06:31,904 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.95, 'alpha': 0.07},
# 2023-03-28 14:06:31,907 - ultron - INFO - init  :model_name:ElasticNetRegression,params:{'l1_ratio': 0.3, 'alpha': 0.04},
# 2023-03-28 14:06:31,907 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.3, 'alpha': 0.04},
# 2023-03-28 14:06:31,907 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.5, 'alpha': 0.01},
# 2023-03-28 14:06:31,908 - ultron - INFO - start :model_name:ElasticNetRegression,params:{'l1_ratio': 0.5, 'alpha': 0.01},fitness
# 2023-03-28 14:06:31,911 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.5, 'alpha': 0.01},sample weight
# 2023-03-28 14:06:31,923 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.5, 'alpha': 0.01},sample weight
# 2023-03-28 14:06:31,937 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.5, 'alpha': 0.01},sample weight
# 2023-03-28 14:06:31,950 - ultron - INFO - finish:model_name:ElasticNetRegression,params:{'l1_ratio': 0.5, 'alpha': 0.01},fitness cost time:0.042496681213378906
# 2023-03-28 14:06:32,006 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.9, 'alpha': 0.07},
# 2023-03-28 14:06:32,009 - ultron - INFO - init  :model_name:ElasticNetRegression,params:{'l1_ratio': 0.5, 'alpha': 0.06},
# 2023-03-28 14:06:32,009 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.5, 'alpha': 0.06},
# 2023-03-28 14:06:32,033 - ultron - INFO - reset :model_name:ElasticNetRegression,params:{'l1_ratio': 0.5, 'alpha': 0.08},
# 2023-03-28 14:06:32,033 - ultron - INFO - start :model_name:ElasticNetRegression,params:{'l1_ratio': 0.5, 'alpha': 0.08},fitness
# 2023-03-28 14:06:32,036 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.5, 'alpha': 0.08},sample weight
# 2023-03-28 14:06:32,047 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.5, 'alpha': 0.08},sample weight
# 2023-03-28 14:06:32,061 - ultron - INFO - fit   :model_name:ElasticNetRegression,params:{'l1_ratio': 0.5, 'alpha': 0.08},sample weight
# 2023-03-28 14:06:32,072 - ultron - INFO - finish:model_name:ElasticNetRegression,params:{'l1_ratio': 0.5, 'alpha': 0.08},fitness cost time:0.03864121437072754
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   21.5s finished
# ExpendTime:21.632195,Generation:4,Tournament:10, Fitness Mean:0.001091,Fitness Max:0.001178,Fitness Min:0.000942
# d_value:0.000067,convergence:0.002000,con_time:2

# %%
results = stock_engine.best_programs()

# %%
results
# Out:
#                                      name                       model_params  \
# 9     BayesianRegression_1679983245692489                    {'n_iter': 260}
# 5     BayesianRegression_1679983287473308                    {'n_iter': 300}
# 6     BayesianRegression_1679983274630194                    {'n_iter': 330}
# 7     BayesianRegression_1679983280834383                    {'n_iter': 340}
# 8     BayesianRegression_1679983245831101                    {'n_iter': 280}
# 4   ElasticNetRegression_1679983477702691  {'l1_ratio': 0.25, 'alpha': 0.04}
# 3   ElasticNetRegression_1679983343462381   {'l1_ratio': 0.3, 'alpha': 0.06}
# 16  ElasticNetRegression_1679983499165478   {'l1_ratio': 0.4, 'alpha': 0.06}
# 2   ElasticNetRegression_1679983279793065   {'l1_ratio': 0.4, 'alpha': 0.07}
# 15  ElasticNetRegression_1679983497728436  {'l1_ratio': 0.75, 'alpha': 0.04}
# 14  ElasticNetRegression_1679983499203872   {'l1_ratio': 0.5, 'alpha': 0.06}
# 13  ElasticNetRegression_1679983500066347  {'l1_ratio': 0.85, 'alpha': 0.04}
# 12  ElasticNetRegression_1679983499411271   {'l1_ratio': 0.9, 'alpha': 0.04}
# 22  ElasticNetRegression_1679983532338218  {'l1_ratio': 0.75, 'alpha': 0.05}
# 21  ElasticNetRegression_1679983521248302  {'l1_ratio': 0.95, 'alpha': 0.04}
# 1   ElasticNetRegression_1679983246317683   {'l1_ratio': 0.9, 'alpha': 0.05}
# 20  ElasticNetRegression_1679983521606705  {'l1_ratio': 0.75, 'alpha': 0.06}
# 26  ElasticNetRegression_1679983544442927  {'l1_ratio': 0.95, 'alpha': 0.05}
# 25  ElasticNetRegression_1679983559480931   {'l1_ratio': 0.7, 'alpha': 0.07}
# 24  ElasticNetRegression_1679983552787649   {'l1_ratio': 0.9, 'alpha': 0.06}
# 0   ElasticNetRegression_1679983279695813   {'l1_ratio': 0.8, 'alpha': 0.07}
# 11  ElasticNetRegression_1679983496705746  {'l1_ratio': 0.95, 'alpha': 0.06}
# 19  ElasticNetRegression_1679983521209630  {'l1_ratio': 0.75, 'alpha': 0.08}
# 10  ElasticNetRegression_1679983498777642   {'l1_ratio': 0.9, 'alpha': 0.07}
# 28  ElasticNetRegression_1679983587130896   {'l1_ratio': 0.8, 'alpha': 0.08}
# 18  ElasticNetRegression_1679983532557609  {'l1_ratio': 0.95, 'alpha': 0.07}
# 17  ElasticNetRegression_1679983534399583  {'l1_ratio': 0.95, 'alpha': 0.08}
# 23  ElasticNetRegression_1679983543266468  {'l1_ratio': 0.85, 'alpha': 0.08}
# 27  ElasticNetRegression_1679983579353659   {'l1_ratio': 0.9, 'alpha': 0.08}
#
#               model_name   fitness  gen  \
# 9     BayesianRegression -0.010600    0
# 5     BayesianRegression -0.010600    0
# 6     BayesianRegression -0.010600    0
# 7     BayesianRegression -0.010600    0
# 8     BayesianRegression -0.010600    0
# 4   ElasticNetRegression -0.005195    0
# 3   ElasticNetRegression -0.002216    0
# 16  ElasticNetRegression -0.000991    1
# 2   ElasticNetRegression -0.000410    0
# 15  ElasticNetRegression -0.000365    1
# 14  ElasticNetRegression -0.000253    1
# 13  ElasticNetRegression -0.000010    1
# 12  ElasticNetRegression  0.000152    1
# 22  ElasticNetRegression  0.000294    2
# 21  ElasticNetRegression  0.000301    2
# 1   ElasticNetRegression  0.000717    0
# 20  ElasticNetRegression  0.000731    2
# 26  ElasticNetRegression  0.000791    3
# 25  ElasticNetRegression  0.000847    3
# 24  ElasticNetRegression  0.000942    3
# 0   ElasticNetRegression  0.000994    0
# 11  ElasticNetRegression  0.001010    1
# 19  ElasticNetRegression  0.001073    2
# 10  ElasticNetRegression  0.001115    1
# 28  ElasticNetRegression  0.001128    4
# 18  ElasticNetRegression  0.001153    2
# 17  ElasticNetRegression  0.001158    2
# 23  ElasticNetRegression  0.001163    3
# 27  ElasticNetRegression  0.001178    4
#
#                                                  desc  \
# 9   {"model_name": "ultron.optimize.model.linearmo...
# 5   {"model_name": "ultron.optimize.model.linearmo...
# 6   {"model_name": "ultron.optimize.model.linearmo...
# 7   {"model_name": "ultron.optimize.model.linearmo...
# 8   {"model_name": "ultron.optimize.model.linearmo...
# 4   {"model_name": "ultron.optimize.model.linearmo...
# 3   {"model_name": "ultron.optimize.model.linearmo...
# 16  {"model_name": "ultron.optimize.model.linearmo...
# 2   {"model_name": "ultron.optimize.model.linearmo...
# 15  {"model_name": "ultron.optimize.model.linearmo...
# 14  {"model_name": "ultron.optimize.model.linearmo...
# 13  {"model_name": "ultron.optimize.model.linearmo...
# 12  {"model_name": "ultron.optimize.model.linearmo...
# 22  {"model_name": "ultron.optimize.model.linearmo...
# 21  {"model_name": "ultron.optimize.model.linearmo...
# 1   {"model_name": "ultron.optimize.model.linearmo...
# 20  {"model_name": "ultron.optimize.model.linearmo...
# 26  {"model_name": "ultron.optimize.model.linearmo...
# 25  {"model_name": "ultron.optimize.model.linearmo...
# 24  {"model_name": "ultron.optimize.model.linearmo...
# 0   {"model_name": "ultron.optimize.model.linearmo...
# 11  {"model_name": "ultron.optimize.model.linearmo...
# 19  {"model_name": "ultron.optimize.model.linearmo...
# 10  {"model_name": "ultron.optimize.model.linearmo...
# 28  {"model_name": "ultron.optimize.model.linearmo...
# 18  {"model_name": "ultron.optimize.model.linearmo...
# 17  {"model_name": "ultron.optimize.model.linearmo...
# 23  {"model_name": "ultron.optimize.model.linearmo...
# 27  {"model_name": "ultron.optimize.model.linearmo...
#
#     train_short_returns_mean  train_short_returns_std  train_short_sharp  \
# 9                  -0.258311                 0.117232          -2.203423
# 5                  -0.258311                 0.117232          -2.203423
# 6                  -0.258311                 0.117232          -2.203423
# 7                  -0.258311                 0.117232          -2.203423
# 8                  -0.258311                 0.117232          -2.203423
# 4                  -0.193197                 0.126467          -1.527644
# 3                  -0.138734                 0.136037          -1.019823
# 16                 -0.084321                 0.141126          -0.597486
# 2                  -0.133563                 0.138151          -0.966794
# 15                 -0.133563                 0.138151          -0.966794
# 14                 -0.133563                 0.138151          -0.966794
# 13                 -0.133563                 0.138151          -0.966794
# 12                 -0.133563                 0.138151          -0.966794
# 22                 -0.133563                 0.138151          -0.966794
# 21                 -0.133563                 0.138151          -0.966794
# 1                   0.000000                 0.000000                NaN
# 20                  0.000000                 0.000000                NaN
# 26                  0.000000                 0.000000                NaN
# 25                  0.000000                 0.000000                NaN
# 24                  0.000000                 0.000000                NaN
# 0                   0.000000                 0.000000                NaN
# 11                  0.000000                 0.000000                NaN
# 19                  0.000000                 0.000000                NaN
# 10                  0.000000                 0.000000                NaN
# 28                  0.000000                 0.000000                NaN
# 18                  0.000000                 0.000000                NaN
# 17                  0.000000                 0.000000                NaN
# 23                  0.000000                 0.000000                NaN
# 27                  0.000000                 0.000000                NaN
#
#     train_short_turnover  ...  test_both_returns_mean  test_both_returns_std  \
# 9               0.089477  ...                0.380940               0.137121
# 5               0.089477  ...                0.380940               0.137121
# 6               0.089477  ...                0.380940               0.137121
# 7               0.089477  ...                0.380940               0.137121
# 8               0.089477  ...                0.380940               0.137121
# 4               0.058333  ...                0.287684               0.150799
# 3               0.055940  ...                0.227077               0.149964
# 16              0.056346  ...                0.155616               0.146776
# 2               0.060631  ...                0.147149               0.155738
# 15              0.060631  ...                0.147149               0.155738
# 14              0.060631  ...                0.147149               0.155738
# 13              0.060631  ...                0.147149               0.155738
# 12              0.060631  ...                0.147149               0.155738
# 22              0.060631  ...                0.147149               0.155738
# 21              0.060631  ...                0.147149               0.155738
# 1                    NaN  ...                0.000000               0.000000
# 20                   NaN  ...                0.000000               0.000000
# 26                   NaN  ...                0.000000               0.000000
# 25                   NaN  ...                0.000000               0.000000
# 24                   NaN  ...                0.000000               0.000000
# 0                    NaN  ...                0.000000               0.000000
# 11                   NaN  ...                0.000000               0.000000
# 19                   NaN  ...                0.000000               0.000000
# 10                   NaN  ...                0.000000               0.000000
# 28                   NaN  ...                0.000000               0.000000
# 18                   NaN  ...                0.000000               0.000000
# 17                   NaN  ...                0.000000               0.000000
# 23                   NaN  ...                0.000000               0.000000
# 27                   NaN  ...                0.000000               0.000000
#
#     test_both_sharp  test_both_turnover  test_both_maxdd  \
# 9          2.778124            0.184351         0.033273
# 5          2.778124            0.184351         0.033273
# 6          2.778124            0.184351         0.033273
# 7          2.778124            0.184351         0.033273
# 8          2.778124            0.184351         0.033273
# 4          1.907736            0.126033         0.041777
# 3          1.514215            0.127642         0.050919
# 16         1.060231            0.132962         0.067515
# 2          0.944852            0.146263         0.074212
# 15         0.944852            0.146263         0.074212
# 14         0.944852            0.146263         0.074212
# 13         0.944852            0.146263         0.074212
# 12         0.944852            0.146263         0.074212
# 22         0.944852            0.146263         0.074212
# 21         0.944852            0.146263         0.074212
# 1               NaN                 NaN         0.000000
# 20              NaN                 NaN         0.000000
# 26              NaN                 NaN         0.000000
# 25              NaN                 NaN         0.000000
# 24              NaN                 NaN         0.000000
# 0               NaN                 NaN         0.000000
# 11              NaN                 NaN         0.000000
# 19              NaN                 NaN         0.000000
# 10              NaN                 NaN         0.000000
# 28              NaN                 NaN         0.000000
# 18              NaN                 NaN         0.000000
# 17              NaN                 NaN         0.000000
# 23              NaN                 NaN         0.000000
# 27              NaN                 NaN         0.000000
#
#     test_both_returns_mdd  test_both_win_rate  test_both_ic  test_both_ir  \
# 9               11.449018            0.582418      0.033165      0.168506
# 5               11.449018            0.582418      0.033165      0.168506
# 6               11.449018            0.582418      0.033165      0.168506
# 7               11.449018            0.582418      0.033165      0.168506
# 8               11.449018            0.582418      0.033165      0.168506
# 4                6.886256            0.549451      0.026419      0.128565
# 3                4.459556            0.505495      0.020604      0.103169
# 16               2.304926            0.483516      0.014856      0.075769
# 2                1.982828            0.483516      0.015769      0.079386
# 15               1.982828            0.483516      0.015769      0.079386
# 14               1.982828            0.483516      0.015769      0.079386
# 13               1.982828            0.483516      0.015769      0.079386
# 12               1.982828            0.483516      0.015769      0.079386
# 22               1.982828            0.483516      0.015769      0.079386
# 21               1.982828            0.483516      0.015769      0.079386
# 1                     NaN            0.000000           NaN           NaN
# 20                    NaN            0.000000           NaN           NaN
# 26                    NaN            0.000000           NaN           NaN
# 25                    NaN            0.000000           NaN           NaN
# 24                    NaN            0.000000           NaN           NaN
# 0                     NaN            0.000000           NaN           NaN
# 11                    NaN            0.000000           NaN           NaN
# 19                    NaN            0.000000           NaN           NaN
# 10                    NaN            0.000000           NaN           NaN
# 28                    NaN            0.000000           NaN           NaN
# 18                    NaN            0.000000           NaN           NaN
# 17                    NaN            0.000000           NaN           NaN
# 23                    NaN            0.000000           NaN           NaN
# 27                    NaN            0.000000           NaN           NaN
#
#     test_both_fitness
# 9            3.993529
# 5            3.993529
# 6            3.993529
# 7            3.993529
# 8            3.993529
# 4            2.882271
# 3            2.019659
# 16           1.147001
# 2            0.947711
# 15           0.947711
# 14           0.947711
# 13           0.947711
# 12           0.947711
# 22           0.947711
# 21           0.947711
# 1                 NaN
# 20                NaN
# 26                NaN
# 25                NaN
# 24                NaN
# 0                 NaN
# 11                NaN
# 19                NaN
# 10                NaN
# 28                NaN
# 18                NaN
# 17                NaN
# 23                NaN
# 27                NaN
#
# [29 rows x 67 columns]
