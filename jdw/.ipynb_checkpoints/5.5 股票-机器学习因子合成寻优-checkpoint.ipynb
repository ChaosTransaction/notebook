# %%
import os

# %%
os.environ['IGNORE_WARNINGS'] = '0'
os.environ['DB_URL'] = 'mysql+mysqlconnector://ultron:123456@127.0.0.1/ultron'

# %%
from jdw import EntropyAPI
# Out:
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.0.3-py3.6.egg/jdw/__init__.py:11: UserWarning: if use distributed calculating, please configure MQ_URL
#   warnings.warn('if use distributed calculating, please configure MQ_URL')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.0.3-py3.6.egg/jdw/__init__.py:15: UserWarning: if use distributed calculating, please configure NTN_URL
#   warnings.warn('if use distributed calculating, please configure NTN_URL')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.0.3-py3.6.egg/jdw/__init__.py:19: UserWarning: if use memory database, please configure KN_MG
#   warnings.warn('if use memory database, please configure KN_MG')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.0.3-py3.6.egg/jdw/__init__.py:27: UserWarning: if use trader, please configure ATL_URL
#   warnings.warn('if use trader, please configure ATL_URL')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.0.3-py3.6.egg/jdw/__init__.py:31: UserWarning: if use trader, please configure IREY_URL
#   warnings.warn('if use trader, please configure IREY_URL')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/aliyunsdkcore/auth/algorithm/sha_hmac256.py:20: CryptographyDeprecationWarning: Python 3.6 is no longer supported by the Python core team. Therefore, support for it is deprecated in cryptography and will be removed in a future release.
#   from cryptography.hazmat.backends import default_backend
# /home/kerry/ultron/2023-01-25.log

# %%
begin_date = '2021-01-01'
end_date = '2021-06-01'

offset = 0
horizon = 1
universe = 'sh50'
industry_level = 1
industry_name = 'sw'
thresh = 0.98

#### 配置参数
configure = {'generations':5, 'n_jobs':1, 'population_size':10, 'n_splits':3,'tournament_size':5,
                'mode':'score', 'standard_score':5, 'convergence':0.002} # 评估函数

# %%
factor_columns = [
    'aiEtopZ180', 'RSI', 'VOL240', 'aiSude', 'aiDaNp60', 'aiDaPE60',
    'hkHoldRatioAll', 'hkHoldRatioB', 'hkHoldVolChgB120', 'lpnpQ', 'CCI10',
    'ROC20'
]

# %%
gentic = EntropyAPI.StockEvolution(thresh=thresh,
                                             universe=universe,
                                             offset=offset,
                                             horizon=horizon,
                                             factor_columns=factor_columns,
                                             industry_name=industry_name,
                                             industry_level=industry_level,
                                             is_loop=False,
                                             callback_save=None)

# %%
gentic.run(begin_date=begin_date,
                   end_date=end_date,
                   configure=configure)
# Out:
# 2023-01-25 22:03:31,775 - ultron - INFO - start service
# 2023-01-25 22:03:48,154 - ultron - INFO - start create yields data
# 2023-01-25 22:03:53,374 - ultron - INFO - start fetch industry data
# 2023-01-25 22:04:01,307 - ultron - INFO - start industry median data ...
# 2023-01-25 22:04:01,519 - ultron - INFO - start corrcoef
# 2023-01-25 22:04:01,528 - ultron - INFO - aiEtopZ180,RSI corr:-0.24656906870585443
# 2023-01-25 22:04:01,653 - ultron - INFO - hkHoldVolChgB120,lpnpQ corr:0.065086047133065
# 2023-01-25 22:04:01,655 - ultron - INFO - hkHoldVolChgB120,CCI10 corr:0.06416029944400134
# 2023-01-25 22:04:01,656 - ultron - INFO - hkHoldVolChgB120,ROC20 corr:0.10881439592845915
# 2023-01-25 22:04:01,657 - ultron - INFO - lpnpQ,RSI corr:0.16308082666657597
# 2023-01-25 22:04:01,659 - ultron - INFO - lpnpQ,VOL240 corr:0.05305025895183806
# 2023-01-25 22:04:01,660 - ultron - INFO - lpnpQ,aiSude corr:0.158120202815485
# 2023-01-25 22:04:01,662 - ultron - INFO - lpnpQ,aiDaNp60 corr:-0.05775288286305085
# 2023-01-25 22:04:01,663 - ultron - INFO - lpnpQ,aiDaPE60 corr:0.14498106996786364
# 2023-01-25 22:04:01,664 - ultron - INFO - lpnpQ,hkHoldRatioAll corr:-0.080209012965429
# 2023-01-25 22:04:01,666 - ultron - INFO - lpnpQ,hkHoldRatioB corr:0.002042887200235095
# 2023-01-25 22:04:01,667 - ultron - INFO - lpnpQ,hkHoldVolChgB120 corr:0.065086047133065
# 2023-01-25 22:04:01,669 - ultron - INFO - lpnpQ,CCI10 corr:0.103546952730663
# 2023-01-25 22:04:01,670 - ultron - INFO - lpnpQ,ROC20 corr:0.15306345845259234
# 2023-01-25 22:04:01,671 - ultron - INFO - CCI10,RSI corr:0.6797661210377952
# 2023-01-25 22:04:01,673 - ultron - INFO - CCI10,VOL240 corr:-0.0717157585628756
# 2023-01-25 22:04:01,674 - ultron - INFO - CCI10,aiSude corr:-0.021511388027670296
# 2023-01-25 22:04:01,676 - ultron - INFO - CCI10,aiDaNp60 corr:0.0010333614305671566
# 2023-01-25 22:04:01,677 - ultron - INFO - CCI10,aiDaPE60 corr:-0.009229288910490296
# 2023-01-25 22:04:01,678 - ultron - INFO - CCI10,hkHoldRatioAll corr:0.008050768886479369
# 2023-01-25 22:04:01,680 - ultron - INFO - CCI10,hkHoldRatioB corr:0.0211059256306764
# 2023-01-25 22:04:01,681 - ultron - INFO - CCI10,hkHoldVolChgB120 corr:0.06416029944400134
# 2023-01-25 22:04:01,683 - ultron - INFO - CCI10,lpnpQ corr:0.103546952730663
# 2023-01-25 22:04:01,684 - ultron - INFO - CCI10,ROC20 corr:0.4181914183092971
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# CS CORR::9.09%
# CS CORR::18.18%
# CS CORR::27.27%
# CS CORR::36.36%
# CS CORR::45.45%
# CS CORR::54.55%
# CS CORR::63.64%
# CS CORR::72.73%
# CS CORR::81.82%
# CS CORR::90.91%
# CS CORR::100.0%
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   16.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ExpendTime:16.092950,Generation:0,Tournament:5, Fitness Mean:-0.052892,Fitness Max:-0.021033,Fitness Min:-0.153592
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    9.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ExpendTime:9.297599,Generation:1,Tournament:5, Fitness Mean:-0.021197,Fitness Max:-0.020562,Fitness Min:-0.022082
# d_value:0.031695,convergence:0.002000,con_time:0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    6.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ExpendTime:6.005325,Generation:2,Tournament:5, Fitness Mean:-0.020908,Fitness Max:-0.020562,Fitness Min:-0.021543
# d_value:0.000289,convergence:0.002000,con_time:0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    5.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ExpendTime:5.937686,Generation:3,Tournament:5, Fitness Mean:-0.020826,Fitness Max:-0.020562,Fitness Min:-0.021135
# d_value:0.000082,convergence:0.002000,con_time:1
# ExpendTime:5.655802,Generation:4,Tournament:5, Fitness Mean:-0.020680,Fitness Max:-0.020403,Fitness Min:-0.021033
# d_value:0.000147,convergence:0.002000,con_time:2
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    5.7s finished

# %%
gentic.best_programs()
# Out:
#                                           name  \
# 4   GradientBoostingRegressor_1674655452788435
# 3       RandomForestRegressor_1674655446530646
# 2       RandomForestRegressor_1674655442821359
# 1         ExtraTreesRegressor_1674655445521827
# 8         ExtraTreesRegressor_1674655465532284
# 7         ExtraTreesRegressor_1674655458615731
# 10        ExtraTreesRegressor_1674655476976439
# 0         ExtraTreesRegressor_1674655451713813
# 6         ExtraTreesRegressor_1674655465336472
# 9         ExtraTreesRegressor_1674655469652755
# 5         ExtraTreesRegressor_1674655462580279
# 11        ExtraTreesRegressor_1674655481432681
#
#                                          model_params  \
# 4   {'n_estimators': 130, 'learning_rate': 0.3, 'l...
# 3   {'n_estimators': 120, 'max_depth': 3, 'max_fea...
# 2   {'n_estimators': 160, 'max_depth': 3, 'max_fea...
# 1   {'n_estimators': 120, 'max_depth': 3, 'max_fea...
# 8   {'n_estimators': 130, 'max_depth': 3, 'max_fea...
# 7   {'n_estimators': 110, 'max_depth': 3, 'max_fea...
# 10  {'n_estimators': 120, 'max_depth': 3, 'max_fea...
# 0   {'n_estimators': 130, 'max_depth': 3, 'max_fea...
# 6   {'n_estimators': 140, 'max_depth': 3, 'max_fea...
# 9   {'n_estimators': 160, 'max_depth': 3, 'max_fea...
# 5   {'n_estimators': 120, 'max_depth': 3, 'max_fea...
# 11  {'n_estimators': 140, 'max_depth': 3, 'max_fea...
#
#                    model_name   fitness  gen  \
# 4   GradientBoostingRegressor -0.153592    0
# 3       RandomForestRegressor -0.034064    0
# 2       RandomForestRegressor -0.033444    0
# 1         ExtraTreesRegressor -0.022326    0
# 8         ExtraTreesRegressor -0.022082    1
# 7         ExtraTreesRegressor -0.021543    1
# 10        ExtraTreesRegressor -0.021135    3
# 0         ExtraTreesRegressor -0.021033    0
# 6         ExtraTreesRegressor -0.020765    1
# 9         ExtraTreesRegressor -0.020636    2
# 5         ExtraTreesRegressor -0.020562    1
# 11        ExtraTreesRegressor -0.020403    4
#
#                                                  desc
# 4   {"model_name": "ultron.optimize.model.treemode...
# 3   {"model_name": "ultron.optimize.model.treemode...
# 2   {"model_name": "ultron.optimize.model.treemode...
# 1   {"model_name": "ultron.optimize.model.treemode...
# 8   {"model_name": "ultron.optimize.model.treemode...
# 7   {"model_name": "ultron.optimize.model.treemode...
# 10  {"model_name": "ultron.optimize.model.treemode...
# 0   {"model_name": "ultron.optimize.model.treemode...
# 6   {"model_name": "ultron.optimize.model.treemode...
# 9   {"model_name": "ultron.optimize.model.treemode...
# 5   {"model_name": "ultron.optimize.model.treemode...
# 11  {"model_name": "ultron.optimize.model.treemode...
