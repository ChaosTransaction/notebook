# %%
import os

# %%
os.environ['IGNORE_WARNINGS'] = '0'
os.environ['DB_URL'] = 'mysql+mysqlconnector://ultron:123456@127.0.0.1/ultron'

# %%
from jdw import EntropyAPI
# Out:
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.1.1.1-py3.6.egg/jdw/__init__.py:11: UserWarning: if use distributed calculating, please configure MQ_URL
#   warnings.warn('if use distributed calculating, please configure MQ_URL')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.1.1.1-py3.6.egg/jdw/__init__.py:15: UserWarning: if use distributed calculating, please configure NTN_URL
#   warnings.warn('if use distributed calculating, please configure NTN_URL')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.1.1.1-py3.6.egg/jdw/__init__.py:19: UserWarning: if use memory database, please configure KN_MG
#   warnings.warn('if use memory database, please configure KN_MG')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.1.1.1-py3.6.egg/jdw/__init__.py:27: UserWarning: if use trader, please configure ATL_URL
#   warnings.warn('if use trader, please configure ATL_URL')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.1.1.1-py3.6.egg/jdw/__init__.py:31: UserWarning: if use trader, please configure IREY_URL
#   warnings.warn('if use trader, please configure IREY_URL')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/aliyunsdkcore/auth/algorithm/sha_hmac256.py:20: CryptographyDeprecationWarning: Python 3.6 is no longer supported by the Python core team. Therefore, support for it is deprecated in cryptography and will be removed in a future release.
#   from cryptography.hazmat.backends import default_backend

# %% [markdown]
# #### 设置参数

# %%
#### 基础因子
factor_columns = [
    'aiEtopZ180', 'RSI', 'VOL240', 'aiSude', 'aiDaNp60', 'aiDaPE60',
    'hkHoldRatioAll', 'hkHoldRatioB', 'hkHoldVolChgB120', 'lpnpQ', 'CCI10',
    'ROC20'
]

#### 运算符
operators_sets = [
    'AVG', 'DIFF', 'LOG', 'SQRT', 'ABS', 'ACOSH', 'ASINH', 'CEIL', 'FLOOR',
    'ROUND', 'RETURNSimple', 'RETURNLog', 'ADDED', 'SUBBED', 'MUL', 'DIV',
    'MINIMUM', 'MAXIMUM', 'CSMean', 'CSRes', 'EMA', 'MA', 'MADecay', 'MMAX',
    'MMIN', 'MRANK', 'MQUANTILE', 'MSUM', 'MVARIANCE', 'MSTD', 'MNPOSITIVE',
    'MAPOSITIVE', 'RSI', 'MARETURNLog', 'DELTA', 'SHIFT', 'MCORR'
]

#### 配置参数
configure = {'evaluate': 'long_evaluate', 'method': 'fitness', 'generations':3} # 评估函数

offset = 0
horizon = 1
universe = 'sh50'
industry_level = 1
industry_name = 'sw'
begin_date = '2021-01-01'
end_date = '2021-08-10'

# %%
#### 回调函数
def callback_save(gen, rootid, best_programs, custom_params):
    print(best_programs)

# %%
### 若设置callback_save回调 保存每一代最优因子回调函数。 如果不设置默认为None，通过阻塞方式即run函数返回所有进化代数最优因子。
gentic = EntropyAPI.StockGeneticist(offset=0,
                                    horizon=1,
                                    factor_columns=factor_columns,
                                    universe=universe,
                                    industry_name=industry_name,
                                    industry_level=industry_level,
                                    operators=operators_sets,
                                    callback_save=None)

# %%
evolution_sets = gentic.run(begin_date=begin_date,
                   end_date=end_date,
                   configure=configure)
# Out:
# 2023-02-24 11:16:33,857 - ultron - INFO - start fetch industry data
# 2023-02-24 11:16:53,287 - ultron - INFO - start industry median data ...
# 2023-02-24 11:16:53,497 - ultron - INFO - start create yields data
# 2023-02-24 11:17:00,682 - ultron - INFO - start factors normal
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:    6.3s remaining:    6.3s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    7.4s finished
# 2023-02-24 11:17:08,227 - ultron - INFO - ExpendTime:7.428455,Generation:0,Tournament:20, Fitness Mean:28.348011,Fitness Max:116.700778,Fitness Min:8.764208

# %%
for program in evolution_sets.values():
    print("eval:{0},metrics:{1}\n".format(program.transform(), program._retain_data))
# Out:
# eval:DELTA(10,MMIN(2,DELTA(16,'VOL240'))),metrics:long_evaluate:
# returns_mean:6.761159390824578
# returns_std:5.701547581206336
# sharp:1.1858463504033494
# turnover:0.12378063478887483
# maxdd:4.012391106080555
# returns_mdd:1.6850698778038906
# win_rate:0.4178082191780822
# ic:-0.005918398622464702
# ir:-0.02550434964932856
# fitness:8.764207588875266
# category:long
# short_evaluate:
# returns_mean:4.433552918356173
# returns_std:7.2098281768006816
# sharp:0.6149318415967489
# turnover:0.12903994724196932
# maxdd:5.358735604053889
# returns_mdd:0.8273505628831894
# win_rate:0.3835616438356164
# ic:0.05712866872219597
# ir:0.22925094705123755
# fitness:3.6044652385519416
# category:short
# both_evaluate:
# returns_mean:2.3276064724683976
# returns_std:10.089902206873647
# sharp:0.23068672270012075
# turnover:0.2528205820308441
# maxdd:8.123024775315674
# returns_mdd:0.2865443029967791
# win_rate:0.410958904109589
# ic:-0.017902558845629846
# ir:-0.09106081936034832
# fitness:0.6999566821214661
# category:both,hold:1,freq:252,direction:1
#
# eval:DELTA(10,'hkHoldRatioAll'),metrics:long_evaluate:
# returns_mean:9.013611429911533
# returns_std:7.009034827161401
# sharp:1.2859989502380555
# turnover:0.18901941194192443
# maxdd:6.357140203727617
# returns_mdd:1.417872052692223
# win_rate:0.4178082191780822
# ic:0.041781797647826024
# ir:0.1544567066027354
# fitness:8.880487887138138
# category:long
# short_evaluate:
# returns_mean:8.573391986647579
# returns_std:5.940328153612235
# sharp:1.4432522522235094
# turnover:0.1777718206950302
# maxdd:3.966538330134121
# returns_mdd:2.1614292547017153
# win_rate:0.5068493150684932
# ic:0.00654523977999927
# ir:0.029942489580260693
# fitness:10.022755222088493
# category:short
# both_evaluate:
# returns_mean:0.44021944326395757
# returns_std:10.022346927242806
# sharp:0.04392378815657941
# turnover:0.3667912326369547
# maxdd:13.677672869464361
# returns_mdd:0.03218525895927479
# win_rate:0.4520547945205479
# ic:-0.01661743875763092
# ir:-0.09408476242786384
# fitness:0.04811992317179578
# category:both,hold:1,freq:252,direction:1
#
# eval:EMA(20,MVARIANCE(10,'hkHoldVolChgB120')),metrics:long_evaluate:
# returns_mean:3.909466657872268
# returns_std:4.478340113743546
# sharp:0.8729722527939612
# turnover:0.036912906215487276
# maxdd:3.446396159271759
# returns_mdd:1.1343636880962513
# win_rate:0.5273972602739726
# ic:0.01315797317320073
# ir:0.07499015876912003
# fitness:8.984006906712878
# category:long
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# both_evaluate:
# returns_mean:3.909466657872268
# returns_std:4.478340113743546
# sharp:0.8729722527939612
# turnover:0.036912906215487276
# maxdd:3.446396159271759
# returns_mdd:1.1343636880962513
# win_rate:0.5273972602739726
# ic:0.01315797317320073
# ir:0.07499015876912003
# fitness:8.984006906712878
# category:both,hold:1,freq:252,direction:1
#
# eval:MCORR(4,EMA(4,DELTA(8,'hkHoldRatioAll')),EMA(20,DIFF('CCI10'))),metrics:long_evaluate:
# returns_mean:5.321322755046953
# returns_std:2.2899560100901675
# sharp:2.323766365641856
# turnover:0.3536953625602301
# maxdd:1.1149123060290012
# returns_mdd:4.772862158101011
# win_rate:0.547945205479452
# ic:0.004050979549102088
# ir:0.019782727690513778
# fitness:9.013377883121615
# category:long
# short_evaluate:
# returns_mean:-6.217536898327118
# returns_std:2.917217083702277
# sharp:-2.1313247248766154
# turnover:0.39722102571131673
# maxdd:4.297987812990868
# returns_mdd:-1.4466157580843584
# win_rate:0.4041095890410959
# ic:0.007980405680043129
# ir:0.032745868659909305
# fitness:-8.432234863913552
# category:short
# both_evaluate:
# returns_mean:11.538859653374072
# returns_std:4.669353780761089
# sharp:2.471189846637253
# turnover:0.7509163882715468
# maxdd:1.9944747348202247
# returns_mdd:5.785412796624945
# win_rate:0.547945205479452
# ic:0.021193352226122262
# ir:0.1491888966871878
# fitness:9.687054991280993
# category:both,hold:1,freq:252,direction:1
#
# eval:EMA(20,MRANK(8,SHIFT(18,'hkHoldVolChgB120'))),metrics:long_evaluate:
# returns_mean:1.5035307509817675
# returns_std:0.8268194564454208
# sharp:1.8184511010972044
# turnover:0.04067686935267871
# maxdd:0.45029705145324117
# returns_mdd:3.33897534112078
# win_rate:0.4931506849315068
# ic:0.02606233250497416
# ir:0.17142052795818669
# fitness:11.05564345839862
# category:long
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# both_evaluate:
# returns_mean:1.5035307509817675
# returns_std:0.8268194564454208
# sharp:1.8184511010972044
# turnover:0.04067686935267871
# maxdd:0.45029705145324117
# returns_mdd:3.33897534112078
# win_rate:0.4931506849315068
# ic:0.02606233250497416
# ir:0.17142052795818669
# fitness:11.05564345839862
# category:both,hold:1,freq:252,direction:1
#
# eval:RSI(10,MAPOSITIVE(6,MAPOSITIVE(20,'RSI'))),metrics:long_evaluate:
# returns_mean:3.3475760758366495
# returns_std:2.1508578610566254
# sharp:1.5563911202352196
# turnover:0.06379480073009168
# maxdd:1.9198226413990742
# returns_mdd:1.743690278283778
# win_rate:0.5273972602739726
# ic:0.023581733195852755
# ir:0.12337107760802607
# fitness:11.274345237487147
# category:long
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# both_evaluate:
# returns_mean:3.3475760758366495
# returns_std:2.1508578610566254
# sharp:1.5563911202352196
# turnover:0.06379480073009168
# maxdd:1.9198226413990742
# returns_mdd:1.743690278283778
# win_rate:0.5273972602739726
# ic:0.023581733195852755
# ir:0.12337107760802607
# fitness:11.274345237487147
# category:both,hold:1,freq:252,direction:1
#
# eval:MVARIANCE(4,DELTA(10,'RSI')),metrics:long_evaluate:
# returns_mean:6.758900767387084
# returns_std:2.7825554125258263
# sharp:2.4290264757932656
# turnover:0.287340360852759
# maxdd:1.7068450955057077
# returns_mdd:3.959879420331663
# win_rate:0.5136986301369864
# ic:0.030528202587428246
# ir:0.20132461597020432
# fitness:11.780723616035008
# category:long
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# both_evaluate:
# returns_mean:6.758900767387084
# returns_std:2.7825554125258263
# sharp:2.4290264757932656
# turnover:0.287340360852759
# maxdd:1.7068450955057077
# returns_mdd:3.959879420331663
# win_rate:0.5136986301369864
# ic:0.030528202587428246
# ir:0.20132461597020432
# fitness:11.780723616035008
# category:both,hold:1,freq:252,direction:1
#
# eval:DELTA(2,MA(16,'CCI10')),metrics:long_evaluate:
# returns_mean:9.228323153604487
# returns_std:4.6690172074828595
# sharp:1.9765022794978349
# turnover:0.2536358499766253
# maxdd:4.082711782658403
# returns_mdd:2.2603415682690167
# win_rate:0.5547945205479452
# ic:-0.005128500059098987
# ir:-0.021359620644308446
# fitness:11.92211748695835
# category:long
# short_evaluate:
# returns_mean:-13.84134574221481
# returns_std:4.35721984121389
# sharp:-3.176646174997383
# turnover:0.25926709809261633
# maxdd:9.061852252988402
# returns_mdd:-1.5274300833640533
# win_rate:0.4383561643835616
# ic:-0.01645141415425339
# ir:-0.07197983613612115
# fitness:-23.210489493542195
# category:short
# both_evaluate:
# returns_mean:23.069668895819298
# returns_std:7.9404153019292885
# sharp:2.9053478966287876
# turnover:0.5129029480692416
# maxdd:5.5402500510959305
# returns_mdd:4.164012216606691
# win_rate:0.5547945205479452
# ic:0.03296536100013179
# ir:0.16150388839723628
# fitness:19.485036642799027
# category:both,hold:1,freq:252,direction:-1
#
# eval:MMIN(16,MCORR(12,EMA(4,'VOL240'),MCORR(16,'aiSude','VOL240'))),metrics:long_evaluate:
# returns_mean:1.4985532997570936
# returns_std:0.8581448076259078
# sharp:1.7462708932573998
# turnover:0.02577482061994793
# maxdd:0.780150531888103
# returns_mdd:1.9208514748177228
# win_rate:0.5616438356164384
# ic:0.0012718330224263075
# ir:0.007981973706683902
# fitness:13.315267222967497
# category:long
# short_evaluate:
# returns_mean:-4.371013991639002
# returns_std:13.32902253035642
# sharp:-0.3279320731647169
# turnover:0.211662554994863
# maxdd:12.75290436020197
# returns_mdd:-0.34274655154473194
# win_rate:0.2876712328767123
# ic:-0.046508655202695946
# ir:-0.06617427614432247
# fitness:-1.4902288808581476
# category:short
# both_evaluate:
# returns_mean:5.869567291396097
# returns_std:13.691108109739782
# sharp:0.4287138224568191
# turnover:0.18488667230574152
# maxdd:9.197431509003907
# returns_mdd:0.638174612732917
# win_rate:0.5684931506849316
# ic:0.006023734933862861
# ir:0.04268204744952956
# fitness:2.415559425932545
# category:both,hold:1,freq:252,direction:-1
#
# eval:DELTA(10,'aiDaPE60'),metrics:long_evaluate:
# returns_mean:12.161047290435572
# returns_std:6.563986197281383
# sharp:1.8526923922345133
# turnover:0.23478590984026765
# maxdd:6.21419273391638
# returns_mdd:1.9569794197180135
# win_rate:0.5684931506849316
# ic:0.06938170297926712
# ir:0.2370545116509401
# fitness:13.333764849171843
# category:long
# short_evaluate:
# returns_mean:5.423341909783687
# returns_std:5.9758089192397055
# sharp:0.9075494185101374
# turnover:0.23669452042820893
# maxdd:3.5444091119895376
# returns_mdd:1.5301117163474034
# win_rate:0.5342465753424658
# ic:0.022632076888927904
# ir:0.08884674079033945
# fitness:4.344198620804501
# category:short
# both_evaluate:
# returns_mean:6.737705380651885
# returns_std:10.143813607314643
# sharp:0.6642181768593782
# turnover:0.4714804302684767
# maxdd:7.152734950396368
# returns_mdd:0.9419761010826377
# win_rate:0.4657534246575342
# ic:0.012894056959267899
# ir:0.0639117531221574
# fitness:2.5109318698721017
# category:both,hold:1,freq:252,direction:1
#
# eval:DELTA(20,MA(14,EMA(4,'aiDaNp60'))),metrics:long_evaluate:
# returns_mean:7.29673300304076
# returns_std:5.21033910123578
# sharp:1.4004334192586683
# turnover:0.059871837622471336
# maxdd:5.135356417593907
# returns_mdd:1.4208815142882592
# win_rate:0.4520547945205479
# ic:0.01074474081805384
# ir:0.04464975010139887
# fitness:15.460210385698444
# category:long
# short_evaluate:
# returns_mean:-0.0917117040122746
# returns_std:4.885501569522574
# sharp:-0.018772218718422592
# turnover:0.05357100665246464
# maxdd:3.273220949257311
# returns_mdd:-0.028018794158421796
# win_rate:0.410958904109589
# ic:0.010006704545829394
# ir:0.03859307575854759
# fitness:-0.024561963596093427
# category:short
# both_evaluate:
# returns_mean:7.388444707053039
# returns_std:8.391023934718703
# sharp:0.8805176536897491
# turnover:0.11344284427493598
# maxdd:9.286720090168014
# returns_mdd:0.7955924842480493
# win_rate:0.4520547945205479
# ic:0.011666581435238608
# ir:0.06199731609973247
# fitness:7.106013497141904
# category:both,hold:1,freq:252,direction:1
#
# eval:EMA(2,MADecay(2,'CCI10')),metrics:long_evaluate:
# returns_mean:9.863040210868492
# returns_std:3.867924176802262
# sharp:2.549956969172696
# turnover:0.1959345088851708
# maxdd:1.9868995905916211
# returns_mdd:4.964035554474932
# win_rate:0.5958904109589042
# ic:0.028481201930089555
# ir:0.13121029176981353
# fitness:18.091842039346794
# category:long
# short_evaluate:
# returns_mean:-6.8023784597155394
# returns_std:5.36476090740611
# sharp:-1.2679742074478628
# turnover:0.2025644949642025
# maxdd:6.866249400826253
# returns_mdd:-0.9906978413712983
# win_rate:0.4589041095890411
# ic:-0.0114431775809148
# ir:-0.04625311777024085
# fitness:-7.3478308827967815
# category:short
# both_evaluate:
# returns_mean:16.665418670584028
# returns_std:8.483559705870729
# sharp:1.9644370109225908
# turnover:0.39849900384937337
# maxdd:5.720251999784768
# returns_mdd:2.9134063798607275
# win_rate:0.5753424657534246
# ic:0.0329301062977448
# ir:0.14906829465616908
# fitness:12.703769407688654
# category:both,hold:1,freq:252,direction:-1
#
# eval:DELTA(2,RSI(2,'aiDaNp60')),metrics:long_evaluate:
# returns_mean:17.625372430152826
# returns_std:4.5565114898032935
# sharp:3.8681724976652525
# turnover:0.6405599861213559
# maxdd:2.562053462000408
# returns_mdd:6.879392913366934
# win_rate:0.541095890410959
# ic:-0.00219053298074436
# ir:-0.006937640011469754
# fitness:20.290608950998234
# category:long
# short_evaluate:
# returns_mean:-2.244974079775396
# returns_std:4.656926695535716
# sharp:-0.4820720244378128
# turnover:0.6476207576135755
# maxdd:4.222411333016746
# returns_mdd:-0.531680573662029
# win_rate:0.4246575342465753
# ic:-0.004226340252769144
# ir:-0.01446683578886763
# fitness:-0.8975470309326518
# category:short
# both_evaluate:
# returns_mean:19.870346509928225
# returns_std:7.305950180271997
# sharp:2.7197484269169303
# turnover:1.2881807437349313
# maxdd:5.226903625366781
# returns_mdd:3.8015521107936805
# win_rate:0.5547945205479452
# ic:0.009068098462646099
# ir:0.0481713085540215
# fitness:10.681765834189891
# category:both,hold:1,freq:252,direction:1
#
# eval:MVARIANCE(14,'aiEtopZ180'),metrics:long_evaluate:
# returns_mean:11.564008371094168
# returns_std:4.137946171348278
# sharp:2.794625133397092
# turnover:0.0900653000017865
# maxdd:2.519903492590288
# returns_mdd:4.5890679564109655
# win_rate:0.5616438356164384
# ic:0.02941951311641984
# ir:0.13799468479513516
# fitness:31.666423035507787
# category:long
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# both_evaluate:
# returns_mean:11.564008371094168
# returns_std:4.137946171348278
# sharp:2.794625133397092
# turnover:0.0900653000017865
# maxdd:2.519903492590288
# returns_mdd:4.5890679564109655
# win_rate:0.5616438356164384
# ic:0.02941951311641984
# ir:0.13799468479513516
# fitness:31.666423035507787
# category:both,hold:1,freq:252,direction:1
#
# eval:SHIFT(12,MMAX(8,'lpnpQ')),metrics:long_evaluate:
# returns_mean:6.081994851957665
# returns_std:3.0608006473710363
# sharp:1.9870601037612738
# turnover:0.020950596479861208
# maxdd:2.9693219487141933
# returns_mdd:2.0482773363768634
# win_rate:0.5068493150684932
# ic:0.0041495247896649315
# ir:0.020191984133244915
# fitness:33.85601447322465
# category:long
# short_evaluate:
# returns_mean:-5.849648343772958
# returns_std:3.390964862197368
# sharp:-1.7250689940745498
# turnover:0.02985517720043264
# maxdd:5.944342116684911
# returns_mdd:-0.9840699322055907
# win_rate:0.4246575342465753
# ic:-0.030081587691154432
# ir:-0.14489129699739384
# fitness:-24.146907708301335
# category:short
# both_evaluate:
# returns_mean:11.931643195730622
# returns_std:5.315886366815192
# sharp:2.2445256298582255
# turnover:0.05080577368029385
# maxdd:3.317028454978157
# returns_mdd:3.5970879833194536
# win_rate:0.5
# ic:0.016814005738061823
# ir:0.12124722466899301
# fitness:34.39680965648224
# category:both,hold:1,freq:252,direction:1
#
# eval:EMA(6,ASINH('hkHoldVolChgB120')),metrics:long_evaluate:
# returns_mean:14.964515471369
# returns_std:6.122735475239802
# sharp:2.444089824210951
# turnover:0.060913471630540124
# maxdd:3.5461922530060166
# returns_mdd:4.2198827372328624
# win_rate:0.5616438356164384
# ic:0.050121342825425505
# ir:0.17708046524978505
# fitness:38.30820622906525
# category:long
# short_evaluate:
# returns_mean:-4.859849731614184
# returns_std:2.669549758214858
# sharp:-1.820475425363111
# turnover:0.04137785538708136
# maxdd:3.615548109847305
# returns_mdd:-1.3441529704383963
# win_rate:0.4726027397260274
# ic:-0.009199971990403712
# ir:-0.05558506926389012
# fitness:-19.729326159399744
# category:short
# both_evaluate:
# returns_mean:19.82436520298318
# returns_std:7.930633598133486
# sharp:2.4997202250837742
# turnover:0.10229132701762149
# maxdd:5.043289352290803
# returns_mdd:3.930840334191493
# win_rate:0.5616438356164384
# ic:0.026007587338469803
# ir:0.13958293701460073
# fitness:34.79939090470384
# category:both,hold:1,freq:252,direction:1
#
# eval:EMA(6,MMAX(6,'hkHoldVolChgB120')),metrics:long_evaluate:
# returns_mean:14.131691191364533
# returns_std:5.648912508223653
# sharp:2.501665793334859
# turnover:0.04331436517498003
# maxdd:3.1917424465630817
# returns_mdd:4.427578799969202
# win_rate:0.5616438356164384
# ic:0.030892299854107044
# ir:0.13098261084278842
# fitness:45.18667470488539
# category:long
# short_evaluate:
# returns_mean:-4.236523085426348
# returns_std:3.232588961272988
# sharp:-1.3105665880137176
# turnover:0.03970951597491231
# maxdd:4.644716690584979
# returns_mdd:-0.9121165762411181
# win_rate:0.5
# ic:0.0014537560147266902
# ir:0.007964120582119318
# fitness:-13.536817804053019
# category:short
# both_evaluate:
# returns_mean:18.368214276790876
# returns_std:7.953098949621768
# sharp:2.3095669239302534
# turnover:0.08302388114989234
# maxdd:5.379557415007804
# returns_mdd:3.4144471114942507
# win_rate:0.541095890410959
# ic:0.023898692830452296
# ir:0.12385481671872524
# fitness:34.35282871272682
# category:both,hold:1,freq:252,direction:1
#
# eval:EMA(20,MMAX(12,'lpnpQ')),metrics:long_evaluate:
# returns_mean:6.592291252999949
# returns_std:2.794357897083971
# sharp:2.359143494066841
# turnover:0.014274009416243415
# maxdd:1.7495228785621304
# returns_mdd:3.7680508976355402
# win_rate:0.5753424657534246
# ic:0.006115033451613976
# ir:0.029724724028510757
# fitness:50.6990196193116
# category:long
# short_evaluate:
# returns_mean:-11.440417819553982
# returns_std:3.9335440490554356
# sharp:-2.908424992037696
# turnover:0.019832442815182396
# maxdd:8.330366012434986
# returns_mdd:-1.3733391549034615
# win_rate:0.4246575342465753
# ic:-0.032731848113231425
# ir:-0.14667961061725457
# fitness:-69.85390760106574
# category:short
# both_evaluate:
# returns_mean:18.032709072553928
# returns_std:5.417949414594753
# sharp:3.3283273232448076
# turnover:0.03410645223142581
# maxdd:3.046089829377781
# returns_mdd:5.919953147355945
# win_rate:0.547945205479452
# ic:0.02350609299932592
# ir:0.17673850869124727
# fitness:76.53115103562929
# category:both,hold:1,freq:252,direction:1
#
# eval:SHIFT(12,EMA(16,'aiEtopZ180')),metrics:long_evaluate:
# returns_mean:13.947656241193073
# returns_std:3.510330586167139
# sharp:3.9733170135472182
# turnover:0.028192529726819043
# maxdd:1.0780940794645515
# returns_mdd:12.937327555050063
# win_rate:0.5205479452054794
# ic:0.05371869863937747
# ir:0.2323789883756297
# fitness:88.37650261020119
# category:long
# short_evaluate:
# returns_mean:-7.7458073030297765
# returns_std:3.7995658947819257
# sharp:-2.0386032292971574
# turnover:0.025204469028644545
# maxdd:7.2290702158861695
# returns_mdd:-1.0714804354795249
# win_rate:0.4315068493150685
# ic:-0.016725569782309387
# ir:-0.0618291150534103
# fitness:-35.73775570195093
# category:short
# both_evaluate:
# returns_mean:21.69346354422285
# returns_std:6.623562650847134
# sharp:3.2751956443634334
# turnover:0.05339699875546359
# maxdd:4.8357264710214025
# returns_mdd:4.486081599987759
# win_rate:0.5136986301369864
# ic:0.041865143688069484
# ir:0.24052530851253373
# fitness:66.01509796318373
# category:both,hold:1,freq:252,direction:1
#
# eval:EMA(6,EMA(10,'aiEtopZ180')),metrics:long_evaluate:
# returns_mean:18.236971277365367
# returns_std:4.000858149712305
# sharp:4.558264900913009
# turnover:0.027823024293460834
# maxdd:1.2186320452637935
# returns_mdd:14.965117114918527
# win_rate:0.5616438356164384
# ic:0.05192656149897511
# ir:0.21605690553481613
# fitness:116.70077762214885
# category:long
# short_evaluate:
# returns_mean:-8.740434035596158
# returns_std:4.246874835699432
# sharp:-2.058086092418748
# turnover:0.023685807976169943
# maxdd:7.273032761337008
# returns_mdd:-1.2017592003792095
# win_rate:0.4589041095890411
# ic:0.02100811609634833
# ir:0.08144785578359566
# fitness:-39.53538165619682
# category:short
# both_evaluate:
# returns_mean:26.977405312961515
# returns_std:7.673175100662061
# sharp:3.5158073364745497
# turnover:0.05150883226963078
# maxdd:4.2174333951152825
# returns_mdd:6.396640512262102
# win_rate:0.547945205479452
# ic:0.04248639459291074
# ir:0.21404251590713588
# fitness:80.46079222045918
# category:both,hold:1,freq:252,direction:1
