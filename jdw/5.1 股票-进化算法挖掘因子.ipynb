# %%
import os

# %%
os.environ['IGNORE_WARNINGS'] = '0'
os.environ['DB_URL'] = 'mysql+mysqlconnector://ultron:1234567@127.0.0.1/ultron'

# %%
from jdw import EntropyAPI
# Out:
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.0.3-py3.6.egg/jdw/__init__.py:11: UserWarning: if use distributed calculating, please configure MQ_URL
#   warnings.warn('if use distributed calculating, please configure MQ_URL')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.0.3-py3.6.egg/jdw/__init__.py:15: UserWarning: if use distributed calculating, please configure NTN_URL
#   warnings.warn('if use distributed calculating, please configure NTN_URL')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.0.3-py3.6.egg/jdw/__init__.py:19: UserWarning: if use memory database, please configure KN_MG
#   warnings.warn('if use memory database, please configure KN_MG')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.0.3-py3.6.egg/jdw/__init__.py:27: UserWarning: if use trader, please configure ATL_URL
#   warnings.warn('if use trader, please configure ATL_URL')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.0.3-py3.6.egg/jdw/__init__.py:31: UserWarning: if use trader, please configure IREY_URL
#   warnings.warn('if use trader, please configure IREY_URL')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/aliyunsdkcore/auth/algorithm/sha_hmac256.py:20: CryptographyDeprecationWarning: Python 3.6 is no longer supported by the Python core team. Therefore, support for it is deprecated in cryptography and will be removed in a future release.
#   from cryptography.hazmat.backends import default_backend
# /home/kerry/ultron/2023-01-25.log

# %% [markdown]
# #### 设置参数

# %%
#### 基础因子
factor_columns = [
    'aiEtopZ180', 'RSI', 'VOL240', 'aiSude', 'aiDaNp60', 'aiDaPE60',
    'hkHoldRatioAll', 'hkHoldRatioB', 'hkHoldVolChgB120', 'lpnpQ', 'CCI10',
    'ROC20'
]

#### 运算符
operators_sets = [
    'AVG', 'DIFF', 'LOG', 'SQRT', 'ABS', 'ACOSH', 'ASINH', 'CEIL', 'FLOOR',
    'ROUND', 'RETURNSimple', 'RETURNLog', 'ADDED', 'SUBBED', 'MUL', 'DIV',
    'MINIMUM', 'MAXIMUM', 'CSMean', 'CSRes', 'EMA', 'MA', 'MADecay', 'MMAX',
    'MMIN', 'MRANK', 'MQUANTILE', 'MSUM', 'MVARIANCE', 'MSTD', 'MNPOSITIVE',
    'MAPOSITIVE', 'RSI', 'MARETURNLog', 'DELTA', 'SHIFT', 'MCORR'
]

#### 配置参数
configure = {'evaluate': 'long_evaluate', 'method': 'fitness', 'generations':3} # 评估函数

offset = 0
horizon = 1
universe = 'sh50'
industry_level = 1
industry_name = 'sw'
begin_date = '2021-01-01'
end_date = '2021-08-10'

# %%
#### 回调函数
def callback_save(gen, rootid, best_programs, custom_params):
    print(best_programs)

# %%
### 若设置callback_save回调 保存每一代最优因子回调函数。 如果不设置默认为None，通过阻塞方式即run函数返回所有进化代数最优因子。
gentic = EntropyAPI.StockGeneticist(offset=0,
                                    horizon=1,
                                    factor_columns=factor_columns,
                                    universe=universe,
                                    industry_name=industry_name,
                                    industry_level=industry_level,
                                    operators=operators_sets,
                                    callback_save=None)

# %%
evolution_sets = gentic.run(begin_date=begin_date,
                   end_date=end_date,
                   configure=configure)
# Out:
# 2023-01-25 07:42:13,653 - ultron - INFO - start fetch industry data
# 2023-01-25 07:42:22,837 - ultron - INFO - start industry median data ...
# 2023-01-25 07:42:23,047 - ultron - INFO - start create yields data
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:    8.4s remaining:    8.4s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    9.7s finished
# 2023-01-25 07:42:42,879 - ultron - INFO - name:ultron_1674603756345495,method:gen,gen:0,formual:EMA(4,MARETURNLog(20,'hkHoldVolChgB120')),fitness:-3.828497,identification:1fff3ae2aec91d46f9d5c5bbdc67fa29
# 2023-01-25 07:42:42,881 - ultron - INFO - name:ultron_1674603760003097,method:gen,gen:0,formual:MADecay(20,MSUM(10,'lpnpQ')),fitness:-3.183883,identification:d655343b57008b47b50075b32e9741a2
# 2023-01-25 07:42:42,882 - ultron - INFO - name:ultron_1674603759923661,method:gen,gen:0,formual:EMA(6,'lpnpQ'),fitness:-2.156490,identification:7d76a1cd067278ce950ebddac22d466c
# 2023-01-25 07:42:42,883 - ultron - INFO - name:ultron_1674603760367239,method:gen,gen:0,formual:DELTA(12,MVARIANCE(10,RSI(14,'CCI10'))),fitness:-1.854495,identification:e019c0e3faaf348ee61900e53b048af2
# 2023-01-25 07:42:42,886 - ultron - INFO - name:ultron_1674603762571687,method:gen,gen:0,formual:MARETURNLog(4,SHIFT(4,'hkHoldRatioAll')),fitness:-1.835428,identification:016c281f4bff17924f14aed95b5f0975
# 2023-01-25 07:42:42,886 - ultron - INFO - name:ultron_1674603760148839,method:gen,gen:0,formual:DELTA(12,MMIN(2,MADecay(18,'hkHoldRatioAll'))),fitness:-1.334781,identification:a4721c36b45dbce58b42ee399a367fb8
# 2023-01-25 07:42:42,887 - ultron - INFO - name:ultron_1674603758312621,method:gen,gen:0,formual:MARETURNLog(6,'hkHoldRatioAll'),fitness:-1.161557,identification:f00fe208d49f4e5189495ca11a11c1e1
# 2023-01-25 07:42:42,891 - ultron - INFO - name:ultron_1674603758915335,method:gen,gen:0,formual:DELTA(16,'RSI'),fitness:-0.865316,identification:f5e4d9be3e7361cb2eed82b5599017ff
# 2023-01-25 07:42:42,891 - ultron - INFO - name:ultron_1674603758511871,method:gen,gen:0,formual:DELTA(16,'hkHoldRatioB'),fitness:-0.707802,identification:5dae879fb0efc5f3a9dbff1249c59cfb
# 2023-01-25 07:42:42,892 - ultron - INFO - name:ultron_1674603760895883,method:gen,gen:0,formual:SHIFT(18,'hkHoldVolChgB120'),fitness:-0.273588,identification:b16ee99634d9e3f73db15b82a8fac05c
# 2023-01-25 07:42:42,892 - ultron - INFO - name:ultron_1674603756562103,method:gen,gen:0,formual:FLOOR(MVARIANCE(16,MMIN(6,'CCI10'))),fitness:0.566205,identification:f9881c80592d47b80ec4f2cefcce4fd0
# 2023-01-25 07:42:42,893 - ultron - INFO - name:ultron_1674603758038437,method:gen,gen:0,formual:EMA(6,'hkHoldVolChgB120'),fitness:0.856230,identification:d025d319854029d1a5454e8a25b075b6
# 2023-01-25 07:42:42,893 - ultron - INFO - ExpendTime:9.711149,Generation:0,Tournament:12, Fitness Mean:-1.314950,Fitness Max:0.856230,Fitness Min:-3.828497
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:    8.8s remaining:    8.8s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    9.3s finished
# 2023-01-25 07:42:52,219 - ultron - INFO - name:ultron_1674603756345495,method:gen,gen:0,formual:EMA(4,MARETURNLog(20,'hkHoldVolChgB120')),fitness:-3.828497,identification:1fff3ae2aec91d46f9d5c5bbdc67fa29
# 2023-01-25 07:42:52,221 - ultron - INFO - name:ultron_1674603760003097,method:gen,gen:0,formual:MADecay(20,MSUM(10,'lpnpQ')),fitness:-3.183883,identification:d655343b57008b47b50075b32e9741a2
# 2023-01-25 07:42:52,222 - ultron - INFO - name:ultron_1674603765378270,method:Point Mutation,gen:1,formual:SHIFT(18,EMA(6,'lpnpQ')),fitness:-2.658251,identification:0334b6264fef92250dd41d9712579be8
# 2023-01-25 07:42:52,224 - ultron - INFO - name:ultron_1674603766025778,method:Point Mutation,gen:1,formual:SHIFT(18,'lpnpQ'),fitness:-2.542916,identification:f0a87f785236d25071aa5ab67226a72c
# 2023-01-25 07:42:52,227 - ultron - INFO - name:ultron_1674603759923661,method:gen,gen:0,formual:EMA(6,'lpnpQ'),fitness:-2.156490,identification:7d76a1cd067278ce950ebddac22d466c
# 2023-01-25 07:42:52,227 - ultron - INFO - name:ultron_1674603760367239,method:gen,gen:0,formual:DELTA(12,MVARIANCE(10,RSI(14,'CCI10'))),fitness:-1.854495,identification:e019c0e3faaf348ee61900e53b048af2
# 2023-01-25 07:42:52,228 - ultron - INFO - name:ultron_1674603762571687,method:gen,gen:0,formual:MARETURNLog(4,SHIFT(4,'hkHoldRatioAll')),fitness:-1.835428,identification:016c281f4bff17924f14aed95b5f0975
# 2023-01-25 07:42:52,229 - ultron - INFO - name:ultron_1674603760148839,method:gen,gen:0,formual:DELTA(12,MMIN(2,MADecay(18,'hkHoldRatioAll'))),fitness:-1.334781,identification:a4721c36b45dbce58b42ee399a367fb8
# 2023-01-25 07:42:52,231 - ultron - INFO - name:ultron_1674603758312621,method:gen,gen:0,formual:MARETURNLog(6,'hkHoldRatioAll'),fitness:-1.161557,identification:f00fe208d49f4e5189495ca11a11c1e1
# 2023-01-25 07:42:52,232 - ultron - INFO - name:ultron_1674603758915335,method:gen,gen:0,formual:DELTA(16,'RSI'),fitness:-0.865316,identification:f5e4d9be3e7361cb2eed82b5599017ff
# 2023-01-25 07:42:52,233 - ultron - INFO - name:ultron_1674603758511871,method:gen,gen:0,formual:DELTA(16,'hkHoldRatioB'),fitness:-0.707802,identification:5dae879fb0efc5f3a9dbff1249c59cfb
# 2023-01-25 07:42:52,233 - ultron - INFO - name:ultron_1674603760895883,method:gen,gen:0,formual:SHIFT(18,'hkHoldVolChgB120'),fitness:-0.273588,identification:b16ee99634d9e3f73db15b82a8fac05c
# 2023-01-25 07:42:52,234 - ultron - INFO - name:ultron_1674603771740263,method:Point Mutation,gen:1,formual:DELTA(16,'hkHoldVolChgB120'),fitness:-0.108234,identification:fb516788ec0e1dba4a8193148e07017e
# 2023-01-25 07:42:52,235 - ultron - INFO - name:ultron_1674603769411978,method:Point Mutation,gen:1,formual:DELTA(12,'hkHoldVolChgB120'),fitness:-0.062619,identification:50c1eae9922caaae7565e14b422cfc68
# 2023-01-25 07:42:52,235 - ultron - INFO - name:ultron_1674603768790235,method:Hoist Mutation,gen:1,formual:SHIFT(4,'hkHoldVolChgB120'),fitness:0.547558,identification:5d68d63d1de032990478983907390e74
# 2023-01-25 07:42:52,239 - ultron - INFO - name:ultron_1674603756562103,method:gen,gen:0,formual:FLOOR(MVARIANCE(16,MMIN(6,'CCI10'))),fitness:0.566205,identification:f9881c80592d47b80ec4f2cefcce4fd0
# 2023-01-25 07:42:52,240 - ultron - INFO - name:ultron_1674603758038437,method:gen,gen:0,formual:EMA(6,'hkHoldVolChgB120'),fitness:0.856230,identification:d025d319854029d1a5454e8a25b075b6
# 2023-01-25 07:42:52,240 - ultron - INFO - ExpendTime:9.346252,Generation:1,Tournament:17, Fitness Mean:-1.211992,Fitness Max:0.856230,Fitness Min:-3.828497
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:   10.8s remaining:   10.8s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   11.9s finished
# 2023-01-25 07:43:04,133 - ultron - INFO - name:ultron_1674603776241732,method:Hoist Mutation,gen:2,formual:EMA(6,EMA(6,'lpnpQ')),fitness:-2.490287,identification:9f9f3388894b4a1cd76aac28e4654205
# 2023-01-25 07:43:04,135 - ultron - INFO - name:ultron_1674603759923661,method:gen,gen:0,formual:EMA(6,'lpnpQ'),fitness:-2.156490,identification:7d76a1cd067278ce950ebddac22d466c
# 2023-01-25 07:43:04,136 - ultron - INFO - name:ultron_1674603760367239,method:gen,gen:0,formual:DELTA(12,MVARIANCE(10,RSI(14,'CCI10'))),fitness:-1.854495,identification:e019c0e3faaf348ee61900e53b048af2
# 2023-01-25 07:43:04,138 - ultron - INFO - name:ultron_1674603762571687,method:gen,gen:0,formual:MARETURNLog(4,SHIFT(4,'hkHoldRatioAll')),fitness:-1.835428,identification:016c281f4bff17924f14aed95b5f0975
# 2023-01-25 07:43:04,139 - ultron - INFO - name:ultron_1674603783779854,method:Point Mutation,gen:2,formual:FLOOR(FLOOR(DELTA(12,'CCI10'))),fitness:-1.485401,identification:32284068869123358e1191c5a02ad008
# 2023-01-25 07:43:04,140 - ultron - INFO - name:ultron_1674603760148839,method:gen,gen:0,formual:DELTA(12,MMIN(2,MADecay(18,'hkHoldRatioAll'))),fitness:-1.334781,identification:a4721c36b45dbce58b42ee399a367fb8
# 2023-01-25 07:43:04,143 - ultron - INFO - name:ultron_1674603758312621,method:gen,gen:0,formual:MARETURNLog(6,'hkHoldRatioAll'),fitness:-1.161557,identification:f00fe208d49f4e5189495ca11a11c1e1
# 2023-01-25 07:43:04,144 - ultron - INFO - name:ultron_1674603758915335,method:gen,gen:0,formual:DELTA(16,'RSI'),fitness:-0.865316,identification:f5e4d9be3e7361cb2eed82b5599017ff
# 2023-01-25 07:43:04,145 - ultron - INFO - name:ultron_1674603758511871,method:gen,gen:0,formual:DELTA(16,'hkHoldRatioB'),fitness:-0.707802,identification:5dae879fb0efc5f3a9dbff1249c59cfb
# 2023-01-25 07:43:04,145 - ultron - INFO - name:ultron_1674603780787583,method:Point Mutation,gen:2,formual:EMA(4,MARETURNLog(4,'hkHoldVolChgB120')),fitness:-0.332343,identification:a035a7cef7a6829b8dd8e153f0895670
# 2023-01-25 07:43:04,146 - ultron - INFO - name:ultron_1674603760895883,method:gen,gen:0,formual:SHIFT(18,'hkHoldVolChgB120'),fitness:-0.273588,identification:b16ee99634d9e3f73db15b82a8fac05c
# 2023-01-25 07:43:04,147 - ultron - INFO - name:ultron_1674603771740263,method:Point Mutation,gen:1,formual:DELTA(16,'hkHoldVolChgB120'),fitness:-0.108234,identification:fb516788ec0e1dba4a8193148e07017e
# 2023-01-25 07:43:04,151 - ultron - INFO - name:ultron_1674603769411978,method:Point Mutation,gen:1,formual:DELTA(12,'hkHoldVolChgB120'),fitness:-0.062619,identification:50c1eae9922caaae7565e14b422cfc68
# 2023-01-25 07:43:04,152 - ultron - INFO - name:ultron_1674603775185784,method:Crossover,gen:2,formual:DELTA(12,EMA(6,EMA(6,EMA(6,'hkHoldVolChgB120')))),fitness:-0.013285,identification:25ca6694903f800d6608d2618018978c
# 2023-01-25 07:43:04,153 - ultron - INFO - name:ultron_1674603773154756,method:Crossover,gen:2,formual:MVARIANCE(4,EMA(6,'RSI')),fitness:0.207927,identification:1f3373827209d68f5dff8a9fb1957ac1
# 2023-01-25 07:43:04,153 - ultron - INFO - name:ultron_1674603778026109,method:Point Mutation,gen:2,formual:MADecay(20,'hkHoldVolChgB120'),fitness:0.515127,identification:7fbccb0ff4fbc226e04f5b23e47cd800
# 2023-01-25 07:43:04,154 - ultron - INFO - name:ultron_1674603768790235,method:Hoist Mutation,gen:1,formual:SHIFT(4,'hkHoldVolChgB120'),fitness:0.547558,identification:5d68d63d1de032990478983907390e74
# 2023-01-25 07:43:04,154 - ultron - INFO - name:ultron_1674603756562103,method:gen,gen:0,formual:FLOOR(MVARIANCE(16,MMIN(6,'CCI10'))),fitness:0.566205,identification:f9881c80592d47b80ec4f2cefcce4fd0
# 2023-01-25 07:43:04,155 - ultron - INFO - name:ultron_1674603758038437,method:gen,gen:0,formual:EMA(6,'hkHoldVolChgB120'),fitness:0.856230,identification:d025d319854029d1a5454e8a25b075b6
# 2023-01-25 07:43:04,155 - ultron - INFO - name:ultron_1674603774911836,method:Crossover,gen:2,formual:EMA(6,MMIN(6,'hkHoldVolChgB120')),fitness:1.528178,identification:126eadc02963b6546a5d9d2a07492ef9
# 2023-01-25 07:43:04,156 - ultron - INFO - ExpendTime:11.914875,Generation:2,Tournament:20, Fitness Mean:-0.523020,Fitness Max:1.528178,Fitness Min:-2.490287

# %%
for program in evolution_sets.values():
    print("eval:{0},metrics:{1}\n".format(program.transform(), program._retain_data))
# Out:
# eval:EMA(4,MARETURNLog(20,'hkHoldVolChgB120')),metrics:long_evaluate:
# returns_mean:-0.45413174255289107
# returns_std:0.23343202605478958
# sharp:-1.9454560294408805
# turnover:0.11726490492515818
# maxdd:0.33660219768180877
# returns_mdd:-1.3491645202571831
# win_rate:0.363013698630137
# ic:-0.02381242283440163
# ir:-0.12010102342232572
# fitness:-3.828497087559427
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.49182755894776753
# returns_std:0.23947716439181865
# sharp:-2.0537555645308534
# turnover:0.13535728407250666
# maxdd:0.4472360098389379
# returns_mdd:-1.0997047378293359
# win_rate:0.4041095890410959
# ic:-0.016196733929149866
# ir:-0.07600247270087172
# fitness:-3.9148431578202674
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.03769581639487651
# returns_std:0.16345116956372216
# sharp:0.23062432955048773
# turnover:0.25262218899766486
# maxdd:0.13911915084844037
# returns_mdd:0.27096065613528075
# win_rate:0.4452054794520548
# ic:-0.004584246829840413
# ir:-0.030424551686897037
# fitness:0.08908733156148876
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MADecay(20,MSUM(10,'lpnpQ')),metrics:long_evaluate:
# returns_mean:-0.21292295436882988
# returns_std:0.2543569413540082
# sharp:-0.8371029830575315
# turnover:0.014718589413312666
# maxdd:0.28890176630775366
# returns_mdd:-0.737008143252447
# win_rate:0.4794520547945205
# ic:0.009540079723676417
# ir:0.04973714543953704
# fitness:-3.1838825307177037
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.8417176446996376
# returns_std:0.2576603504827665
# sharp:-3.2667721018098033
# turnover:0.017217932423793433
# maxdd:0.6503112654509816
# returns_mdd:-1.2943304067105748
# win_rate:0.410958904109589
# ic:-0.003475630433608886
# ir:-0.012896659178052793
# fitness:-22.840812789668092
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.6287946903308077
# returns_std:0.18955947108360227
# sharp:3.317136763129538
# turnover:0.03193652183710611
# maxdd:0.12122978701160014
# returns_mdd:5.186800256199741
# win_rate:0.547945205479452
# ic:0.02407604137545429
# ir:0.18213269990301942
# fitness:14.718854169388193
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:EMA(6,'lpnpQ'),metrics:long_evaluate:
# returns_mean:-0.16728244299094405
# returns_std:0.24646833229454282
# sharp:-0.6787177948322894
# turnover:0.016570432572979136
# maxdd:0.24569104640674902
# returns_mdd:-0.6808650353257191
# win_rate:0.4931506849315068
# ic:-0.0032920974166708228
# ir:-0.017596984970732
# fitness:-2.1564902255491876
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.8896505635779657
# returns_std:0.25159895130863513
# sharp:-3.5359867716087416
# turnover:0.01842450581542609
# maxdd:0.6758346396339482
# returns_mdd:-1.3163731353868255
# win_rate:0.410958904109589
# ic:-0.0034552969442111755
# ir:-0.013369222510097522
# fitness:-24.570977641122475
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.7223681205870215
# returns_std:0.18982164795338877
# sharp:3.8055096896240252
# turnover:0.03499493838840522
# maxdd:0.1170075949424198
# returns_mdd:6.173685741874308
# win_rate:0.5958904109589042
# ic:0.034623822131592354
# ir:0.2610892746259805
# fitness:17.289781353721065
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:DELTA(12,MVARIANCE(10,RSI(14,'CCI10'))),metrics:long_evaluate:
# returns_mean:-0.3776495172827022
# returns_std:0.26792345183087485
# sharp:-1.409542593983491
# turnover:0.21816953548284498
# maxdd:0.353381930664412
# returns_mdd:-1.0686724037436306
# win_rate:0.410958904109589
# ic:-0.005849325008071677
# ir:-0.024806773235603326
# fitness:-1.854494789846717
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.9245667349393545
# returns_std:0.29760675850776985
# sharp:-3.1066725082966022
# turnover:0.20408647284920892
# maxdd:0.5902234747363495
# returns_mdd:-1.566468930013932
# win_rate:0.3835616438356164
# ic:-0.008631760333461535
# ir:-0.039654543347451554
# fitness:-6.61237531907645
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.546917217656652
# returns_std:0.2529365529255267
# sharp:2.162270384928047
# turnover:0.42225600833205384
# maxdd:0.21391661972366435
# returns_mdd:2.55668408730072
# win_rate:0.4726027397260274
# ic:-0.009092978806429406
# ir:-0.0510715258630247
# fitness:2.4608371758035745
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MARETURNLog(4,SHIFT(4,'hkHoldRatioAll')),metrics:long_evaluate:
# returns_mean:-0.47869585827963895
# returns_std:0.3136248568954393
# sharp:-1.5263326479228443
# turnover:0.331042328417133
# maxdd:0.423876987040196
# returns_mdd:-1.1293273117331197
# win_rate:0.4178082191780822
# ic:-0.027618797546521818
# ir:-0.12467240225559627
# fitness:-1.835427628321915
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.68653334467797
# returns_std:0.28757368675555545
# sharp:-2.387330191519017
# turnover:0.31449127126492227
# maxdd:0.5040451110438663
# returns_mdd:-1.362047423208162
# win_rate:0.3767123287671233
# ic:0.023151963188823774
# ir:0.11632635970703695
# fitness:-3.5272724815635765
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.20783748639833102
# returns_std:0.27716491972269736
# sharp:0.7498693795963493
# turnover:0.6455335996820553
# maxdd:0.12867211962829908
# returns_mdd:1.6152487966990867
# win_rate:0.4657534246575342
# ic:-0.0153274324216709
# ir:-0.08973110658110174
# fitness:0.42548880171771947
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:DELTA(12,MMIN(2,MADecay(18,'hkHoldRatioAll'))),metrics:long_evaluate:
# returns_mean:-0.22151260371656364
# returns_std:0.2983149226070258
# sharp:-0.742546171611955
# turnover:0.06855282669453121
# maxdd:0.23213147095486725
# returns_mdd:-0.9542549435687322
# win_rate:0.4246575342465753
# ic:0.022544137877037993
# ir:0.08590113454424778
# fitness:-1.3347809529132015
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.670887300572961
# returns_std:0.3272495921591633
# sharp:-2.050078339736062
# turnover:0.06759290464645054
# maxdd:0.4781367290975647
# returns_mdd:-1.4031285608181445
# win_rate:0.4041095890410959
# ic:-0.02506689599725199
# ir:-0.10706166078302129
# fitness:-6.458693684375219
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.44937469685639725
# returns_std:0.26510326861108807
# sharp:1.6950930073806036
# turnover:0.13614573134098173
# maxdd:0.20193035927658495
# returns_mdd:2.2253944303683757
# win_rate:0.4726027397260274
# ic:0.007840802958571804
# ir:0.05161353497931719
# fitness:3.0796107369032066
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MARETURNLog(6,'hkHoldRatioAll'),metrics:long_evaluate:
# returns_mean:-0.3165207550384292
# returns_std:0.29940230536724316
# sharp:-1.0571754103569402
# turnover:0.2621892640832676
# maxdd:0.3334509882807014
# returns_mdd:-0.9492272212790078
# win_rate:0.3972602739726027
# ic:0.008478704750234644
# ir:0.0360378137574839
# fitness:-1.1615574569207605
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.7135592030841004
# returns_std:0.27792251496811365
# sharp:-2.567475338102664
# turnover:0.2509381233720986
# maxdd:0.42725964110831205
# returns_mdd:-1.670083327395789
# win_rate:0.4315068493150685
# ic:0.01495978488605675
# ir:0.06979624670338593
# fitness:-4.329502190005887
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.397038448045671
# returns_std:0.27337065740625377
# sharp:1.4523813631381646
# turnover:0.5131273874553662
# maxdd:0.22152120189044244
# returns_mdd:1.7923270759520074
# win_rate:0.4931506849315068
# ic:-0.01565344400872507
# ir:-0.08723229009051392
# fitness:1.277568961765117
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:DELTA(16,'RSI'),metrics:long_evaluate:
# returns_mean:-0.23635591992058702
# returns_std:0.27367017708571106
# sharp:-0.8636524536123
# turnover:0.2354481913783665
# maxdd:0.3239324279554803
# returns_mdd:-0.7296457517771906
# win_rate:0.4246575342465753
# ic:0.02485783839141151
# ir:0.10963072172756673
# fitness:-0.8653156811460135
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.4584427002545968
# returns_std:0.28035999705995684
# sharp:-1.63519298424217
# turnover:0.2684682741288957
# maxdd:0.44284607307207763
# returns_mdd:-1.035219070758206
# win_rate:0.3698630136986301
# ic:-0.013820523455159656
# ir:-0.044964746739309495
# fitness:-2.136805833363084
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.2220867803340099
# returns_std:0.25759699400673297
# sharp:0.8621481830188014
# turnover:0.503916465507262
# maxdd:0.1910544902728369
# returns_mdd:1.1624263843098221
# win_rate:0.4863013698630137
# ic:0.018769385695193038
# ir:0.09333208764316231
# fitness:0.5723530436969001
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:DELTA(16,'hkHoldRatioB'),metrics:long_evaluate:
# returns_mean:-0.22049564062665758
# returns_std:0.344308407262302
# sharp:-0.6404015585326064
# turnover:0.18050156523167385
# maxdd:0.2819680201770685
# returns_mdd:-0.7819881151351565
# win_rate:0.4315068493150685
# ic:0.0015349812460801729
# ir:0.005762811413205487
# fitness:-0.7078021831065147
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.4890962495101295
# returns_std:0.290891779481152
# sharp:-1.6813684126189612
# turnover:0.18504325973632324
# maxdd:0.4178185864447062
# returns_mdd:-1.1705947637991354
# win_rate:0.4246575342465753
# ic:-0.022097215196723054
# ir:-0.0894108037280509
# fitness:-2.733527298070175
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.26860060888347176
# returns_std:0.24962664338849078
# sharp:1.0760093763927756
# turnover:0.365544824967997
# maxdd:0.15704707889047767
# returns_mdd:1.7103190379668882
# win_rate:0.4589041095890411
# ic:0.012262635374277641
# ir:0.07675746245462121
# fitness:0.9223573911129921
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:SHIFT(18,'hkHoldVolChgB120'),metrics:long_evaluate:
# returns_mean:-0.09201687365792455
# returns_std:0.2712401478515119
# sharp:-0.3392450357618091
# turnover:0.14148219570714943
# maxdd:0.25200055832292784
# returns_mdd:-0.3651455150349663
# win_rate:0.4315068493150685
# ic:-0.015994316591878607
# ir:-0.06721815995442852
# fitness:-0.2735875577130798
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.48260170571965993
# returns_std:0.24666130801257116
# sharp:-1.9565359058870473
# turnover:0.11657399442149607
# maxdd:0.3844904498570879
# returns_mdd:-1.255172152907931
# win_rate:0.410958904109589
# ic:-0.02384247348583107
# ir:-0.1203834795728287
# fitness:-3.9809012966164508
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.3905848320617353
# returns_std:0.2089785619349972
# sharp:1.8690186612693158
# turnover:0.2580561901286455
# maxdd:0.13397650492994037
# returns_mdd:2.915323341700709
# win_rate:0.4931506849315068
# ic:0.0104625269852149
# ir:0.06428925610527282
# fitness:2.2993981838244557
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:FLOOR(MVARIANCE(16,MMIN(6,'CCI10'))),metrics:long_evaluate:
# returns_mean:0.09873531759916998
# returns_std:0.0707391220526465
# sharp:1.3957667940194076
# turnover:0.6
# maxdd:0.0035810326451008348
# returns_mdd:27.571744629094212
# win_rate:0.0136986301369863
# ic:nan
# ir:nan
# fitness:0.5662047397821042
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.2543827241461935
# returns_std:0.2481199359510022
# sharp:-1.0252409713519677
# turnover:0.06749327491567718
# maxdd:0.2895429724536917
# returns_mdd:-0.8785663903028363
# win_rate:0.4589041095890411
# ic:0.02422929703727934
# ir:0.1413114628996683
# fitness:-1.990396088561513
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.35311804174536354
# returns_std:0.2520149616949233
# sharp:1.4011788798985298
# turnover:0.08804122012115663
# maxdd:0.1196302942880655
# returns_mdd:2.951744320674058
# win_rate:0.547945205479452
# ic:-0.02479390782618848
# ir:-0.1442005700607697
# fitness:2.80614759527127
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:EMA(6,'hkHoldVolChgB120'),metrics:long_evaluate:
# returns_mean:0.17241474510888916
# returns_std:0.34090335930509913
# sharp:0.5057584221532493
# turnover:0.06015611729501215
# maxdd:0.21626280667436595
# returns_mdd:0.7972464047805489
# win_rate:0.5273972602739726
# ic:0.04945215062919633
# ir:0.2513677327797546
# fitness:0.8562299740003797
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.5942098950802904
# returns_std:0.2558714213899303
# sharp:-2.3222988009073346
# turnover:0.05226052072476023
# maxdd:0.47485367660187894
# returns_mdd:-1.2513536787427693
# win_rate:0.4657534246575342
# ic:-0.004860489613366202
# ir:-0.026027133224236026
# fitness:-7.8307105523480685
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.7666246401891796
# returns_std:0.2771845377431478
# sharp:2.7657554293290705
# turnover:0.11241663801977236
# maxdd:0.11897506736780328
# returns_mdd:6.443573911323892
# win_rate:0.5684931506849316
# ic:0.025975435682827192
# ir:0.13971935800390614
# fitness:7.222538475344375
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:SHIFT(18,EMA(6,'lpnpQ')),metrics:long_evaluate:
# returns_mean:-0.1959955194088027
# returns_std:0.23899623674613632
# sharp:-0.8200778475729334
# turnover:0.018653674191209176
# maxdd:0.2962208016048904
# returns_mdd:-0.6616534637234165
# win_rate:0.4452054794520548
# ic:0.003994608716521459
# ir:0.019966553259836487
# fitness:-2.6582508335251975
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.7296491756588092
# returns_std:0.24793233199319845
# sharp:-2.9429367674355023
# turnover:0.021374767657303513
# maxdd:0.5887350656993963
# returns_mdd:-1.2393506318364305
# win_rate:0.3493150684931507
# ic:-0.011035464317307625
# ir:-0.0400410057969806
# fitness:-17.194409973825966
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.5336536562500066
# returns_std:0.16914718198545986
# sharp:3.1549662843090123
# turnover:0.040028441848512696
# maxdd:0.12337348248440044
# returns_mdd:4.32551343695338
# win_rate:0.5
# ic:0.02155158009522404
# ir:0.15909443932949013
# fitness:11.519672292675256
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:SHIFT(18,'lpnpQ'),metrics:long_evaluate:
# returns_mean:-0.1944464906508474
# returns_std:0.23747767095534184
# sharp:-0.8187990469529806
# turnover:0.020160013459859245
# maxdd:0.29974586262947395
# returns_mdd:-0.64870450235775
# win_rate:0.4315068493150685
# ic:0.010867825023696313
# ir:0.05690838269192323
# fitness:-2.542915765582514
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.6662972325299953
# returns_std:0.24633068163631347
# sharp:-2.7048893304883843
# turnover:0.021500160874708244
# maxdd:0.5520311593892848
# returns_mdd:-1.2069920713662678
# win_rate:0.3561643835616438
# ic:-0.008738240568528536
# ir:-0.03167731995256253
# fitness:-15.057839050421363
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.4718507418791478
# returns_std:0.1733018851184205
# sharp:2.72270980524374
# turnover:0.04166017433456749
# maxdd:0.12337348864869646
# returns_mdd:3.8245716081088807
# win_rate:0.4931506849315068
# ic:0.02391829422273551
# ir:0.1734139116294155
# fitness:9.163114954526117
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:DELTA(16,'hkHoldVolChgB120'),metrics:long_evaluate:
# returns_mean:-0.0645937417047539
# returns_std:0.3122276041847144
# sharp:-0.20688030410834568
# turnover:0.23599331674277998
# maxdd:0.2315091981430249
# returns_mdd:-0.2790115564429898
# win_rate:0.4589041095890411
# ic:0.01517290701140574
# ir:0.0744572522053199
# fitness:-0.10823420092627518
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.5070887580661918
# returns_std:0.2531050075001281
# sharp:-2.003471851760717
# turnover:0.23992191644249566
# maxdd:0.3965549839428392
# returns_mdd:-1.2787350521341205
# win_rate:0.4041095890410959
# ic:-0.0019502510728162657
# ir:-0.009281918104114962
# fitness:-2.912663244929605
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.4424950163614379
# returns_std:0.25317918432684094
# sharp:1.7477543327187604
# turnover:0.47591523318527557
# maxdd:0.12948722675222474
# returns_mdd:3.417286997799073
# win_rate:0.4794520547945205
# ic:0.008976831564887917
# ir:0.05348570169801589
# fitness:1.6852711116459391
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:DELTA(12,'hkHoldVolChgB120'),metrics:long_evaluate:
# returns_mean:-0.045054614403671145
# returns_std:0.29994435034942485
# sharp:-0.15020991177591467
# turnover:0.2592502893933577
# maxdd:0.23460043657217342
# returns_mdd:-0.19204829736030932
# win_rate:0.4863013698630137
# ic:0.030184851988406727
# ir:0.13986096217786595
# fitness:-0.06261935712976498
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.9364652749020902
# returns_std:0.284464815152149
# sharp:-3.292024971176881
# turnover:0.26075550405235265
# maxdd:0.5603518301303053
# returns_mdd:-1.671209451897967
# win_rate:0.363013698630137
# ic:-0.007808531649883405
# ir:-0.03876741599616635
# fitness:-6.238672927375015
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.891410660498419
# returns_std:0.2634609621436809
# sharp:3.383463922872489
# turnover:0.5200057934457104
# maxdd:0.17146931645556024
# returns_mdd:5.198659905601515
# win_rate:0.541095890410959
# ic:0.03362391386066943
# ir:0.21466523705208396
# fitness:4.429924971461415
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:SHIFT(4,'hkHoldVolChgB120'),metrics:long_evaluate:
# returns_mean:0.16623218976890733
# returns_std:0.3333745405298563
# sharp:0.49863492726439895
# turnover:0.13785440326054976
# maxdd:0.22698173617010053
# returns_mdd:0.7323593191847498
# win_rate:0.5
# ic:0.014436938342603135
# ir:0.06373667152341969
# fitness:0.5475577589459831
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.6866697671665742
# returns_std:0.2545051611574895
# sharp:-2.698058318517393
# turnover:0.1156822288403029
# maxdd:0.506319979049092
# returns_mdd:-1.3561972578214139
# win_rate:0.4520547945205479
# ic:0.003168462695918705
# ir:0.01595430453767812
# fitness:-6.573428936245897
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.8529019569354817
# returns_std:0.2796753626509715
# sharp:3.049614198587396
# turnover:0.25353663210085264
# maxdd:0.12307532243329478
# returns_mdd:6.929918525281487
# win_rate:0.5342465753424658
# ic:0.02703718328623365
# ir:0.14779169693081315
# fitness:5.5933770728492584
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:EMA(6,EMA(6,'lpnpQ')),metrics:long_evaluate:
# returns_mean:-0.18102083075077263
# returns_std:0.248264779893198
# sharp:-0.7291442258891764
# turnover:0.015518746791451318
# maxdd:0.2619202922642591
# returns_mdd:-0.6911294622721915
# win_rate:0.4931506849315068
# ic:-0.002931783562927348
# ir:-0.01562096573414006
# fitness:-2.4902869586051097
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.9027771234746018
# returns_std:0.25353293801945687
# sharp:-3.5607883162120735
# turnover:0.017486790927358897
# maxdd:0.6847918733816879
# returns_mdd:-1.3183233600837634
# win_rate:0.4178082191780822
# ic:0.006421115198126614
# ir:0.02463840231577408
# fitness:-25.584761341513907
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.7217562927238294
# returns_std:0.1887310490953837
# sharp:3.824258362274336
# turnover:0.03300553771881022
# maxdd:0.11842619055402354
# returns_mdd:6.094566491983708
# win_rate:0.6027397260273972
# ic:0.031199329046687166
# ir:0.2335959105957904
# fitness:17.8833595491394
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:FLOOR(FLOOR(DELTA(12,'CCI10'))),metrics:long_evaluate:
# returns_mean:-0.3941734139023322
# returns_std:0.29376227683916867
# sharp:-1.3418108619785019
# turnover:0.32164929578407064
# maxdd:0.4508738130190824
# returns_mdd:-0.8742433082616167
# win_rate:0.4383561643835616
# ic:0.028729776498114763
# ir:0.12140327326469551
# fitness:-1.4854008397615655
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-1.2355362249871686
# returns_std:0.31608630983393743
# sharp:-3.9088571271444295
# turnover:0.3641469305555086
# maxdd:0.779055279490835
# returns_mdd:-1.5859416623101183
# win_rate:0.3767123287671233
# ic:-0.04916182445563362
# ir:-0.1761974433047502
# fitness:-7.200111328489436
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.8413628110848367
# returns_std:0.3088277675036672
# sharp:2.7243755245384333
# turnover:0.6857962263395793
# maxdd:0.3296798664175117
# returns_mdd:2.552060033958282
# win_rate:0.636986301369863
# ic:0.033469639437711536
# ir:0.1615154783449204
# fitness:3.0175958961531855
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:EMA(4,MARETURNLog(4,'hkHoldVolChgB120')),metrics:long_evaluate:
# returns_mean:-0.12684841755001544
# returns_std:0.26976435399329163
# sharp:-0.4702193439284786
# turnover:0.25392983039452577
# maxdd:0.31733447033879997
# returns_mdd:-0.399730976009592
# win_rate:0.4863013698630137
# ic:0.017502903875622776
# ir:0.07956145105115499
# fitness:-0.3323427099087989
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.143597133404759
# returns_std:0.27947225396825054
# sharp:-0.5138153479131147
# turnover:0.2351400186488069
# maxdd:0.33045611873071346
# returns_mdd:-0.43454221382348
# win_rate:0.4589041095890411
# ic:0.027561756471353727
# ir:0.13241686682195328
# fitness:-0.401528784113373
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.016748715854743725
# returns_std:0.22150284306523974
# sharp:0.07561399945467376
# turnover:0.48906984904333267
# maxdd:0.3414336163631494
# returns_mdd:0.049054091489719516
# win_rate:0.4931506849315068
# ic:0.0047631912061565345
# ir:0.03007431742236658
# fitness:0.013992893296583018
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:DELTA(12,EMA(6,EMA(6,EMA(6,'hkHoldVolChgB120')))),metrics:long_evaluate:
# returns_mean:-0.01194342004824285
# returns_std:0.3455266097482616
# sharp:-0.034565847350930226
# turnover:0.08085220944128307
# maxdd:0.2487684021105283
# returns_mdd:-0.04801019722326457
# win_rate:0.4452054794520548
# ic:0.012986025813763298
# ir:0.057456945482689044
# fitness:-0.013285124076036428
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.6261099398415895
# returns_std:0.25785747149257193
# sharp:-2.4281240959101926
# turnover:0.08565293171687526
# maxdd:0.41675314338440683
# returns_mdd:-1.5023520512815307
# win_rate:0.4178082191780822
# ic:-0.008280188081804035
# ir:-0.03692981114677504
# fitness:-6.564853845581333
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.6141665197933465
# returns_std:0.2855011263824995
# sharp:2.1511877293629946
# turnover:0.1665051411581583
# maxdd:0.1382847949046852
# returns_mdd:4.441316344408434
# win_rate:0.5205479452054794
# ic:0.013322261476688468
# ir:0.07704214874460692
# fitness:4.131498097233857
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MVARIANCE(4,EMA(6,'RSI')),metrics:long_evaluate:
# returns_mean:0.09199114714189752
# returns_std:0.26555905745920866
# sharp:0.3464056094416131
# turnover:0.255325689554961
# maxdd:0.21139872649819097
# returns_mdd:0.4351546892723818
# win_rate:0.547945205479452
# ic:0.04108592741336071
# ir:0.2464985128022399
# fitness:0.20792689901119346
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.09199114714189752
# returns_std:0.26555905745920866
# sharp:0.3464056094416131
# turnover:0.255325689554961
# maxdd:0.21139872649819097
# returns_mdd:0.4351546892723818
# win_rate:0.547945205479452
# ic:0.04108592741336071
# ir:0.2464985128022399
# fitness:0.20792689901119346
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MADecay(20,'hkHoldVolChgB120'),metrics:long_evaluate:
# returns_mean:0.10429360932405751
# returns_std:0.33910719616243523
# sharp:0.3075535125892757
# turnover:0.03717670177611142
# maxdd:0.21752316000989685
# returns_mdd:0.47945979324368204
# win_rate:0.5068493150684932
# ic:0.035462273492620676
# ir:0.1600907076787543
# fitness:0.5151267600798985
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.5775841282464643
# returns_std:0.2571893276885178
# sharp:-2.245754648676468
# turnover:0.032838798150602394
# maxdd:0.4559812158477863
# returns_mdd:-1.2666840391058367
# win_rate:0.4863013698630137
# ic:-0.003792306876170216
# ir:-0.019218180747071795
# fitness:-9.418382096916417
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.6818777375705218
# returns_std:0.27801003325101403
# sharp:2.452709096850679
# turnover:0.07001549992671381
# maxdd:0.14073871125023335
# returns_mdd:4.844990632024075
# win_rate:0.547945205479452
# ic:0.019719782515600914
# ir:0.10394754023078026
# fitness:7.65424220407774
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:EMA(6,MMIN(6,'hkHoldVolChgB120')),metrics:long_evaluate:
# returns_mean:0.2597475914217423
# returns_std:0.3796329579217911
# sharp:0.6842071690605256
# turnover:0.05206898712696709
# maxdd:0.25707308309631616
# returns_mdd:1.01040368868344
# win_rate:0.5136986301369864
# ic:0.017423628652577766
# ir:0.06631146927906965
# fitness:1.5281775669544477
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.5847369135765405
# returns_std:0.2533974061110259
# sharp:-2.307588394651279
# turnover:0.03463367874782099
# maxdd:0.4715710279139873
# returns_mdd:-1.2399763322253847
# win_rate:0.4726027397260274
# ic:-0.0015337142788718703
# ir:-0.008619762942347002
# fitness:-9.481767230583168
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.8444845049982825
# returns_std:0.3134917053472136
# sharp:2.6938017516698185
# turnover:0.08670266587478807
# maxdd:0.17291593867004962
# returns_mdd:4.883786373271754
# win_rate:0.5136986301369864
# ic:0.02149057814084837
# ir:0.12113115130846573
# fitness:8.40708131684545
# category:both
# freq:252
# hold:1,hold:1,freq:252
