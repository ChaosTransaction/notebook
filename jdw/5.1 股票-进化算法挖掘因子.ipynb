# %%
import os

# %%
os.environ['IGNORE_WARNINGS'] = '0'
os.environ['DB_URL'] = 'mysql+mysqlconnector://ultron:123456@127.0.0.1/ultron'

# %%
from jdw import EntropyAPI
# Out:
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.0.3-py3.6.egg/jdw/__init__.py:11: UserWarning: if use distributed calculating, please configure MQ_URL
#   warnings.warn('if use distributed calculating, please configure MQ_URL')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.0.3-py3.6.egg/jdw/__init__.py:15: UserWarning: if use distributed calculating, please configure NTN_URL
#   warnings.warn('if use distributed calculating, please configure NTN_URL')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.0.3-py3.6.egg/jdw/__init__.py:19: UserWarning: if use memory database, please configure KN_MG
#   warnings.warn('if use memory database, please configure KN_MG')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.0.3-py3.6.egg/jdw/__init__.py:27: UserWarning: if use trader, please configure ATL_URL
#   warnings.warn('if use trader, please configure ATL_URL')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.0.3-py3.6.egg/jdw/__init__.py:31: UserWarning: if use trader, please configure IREY_URL
#   warnings.warn('if use trader, please configure IREY_URL')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/aliyunsdkcore/auth/algorithm/sha_hmac256.py:20: CryptographyDeprecationWarning: Python 3.6 is no longer supported by the Python core team. Therefore, support for it is deprecated in cryptography and will be removed in a future release.
#   from cryptography.hazmat.backends import default_backend
# /home/kerry/ultron/2023-01-25.log

# %% [markdown]
# #### 设置参数

# %%
#### 基础因子
factor_columns = [
    'aiEtopZ180', 'RSI', 'VOL240', 'aiSude', 'aiDaNp60', 'aiDaPE60',
    'hkHoldRatioAll', 'hkHoldRatioB', 'hkHoldVolChgB120', 'lpnpQ', 'CCI10',
    'ROC20'
]

#### 运算符
operators_sets = [
    'AVG', 'DIFF', 'LOG', 'SQRT', 'ABS', 'ACOSH', 'ASINH', 'CEIL', 'FLOOR',
    'ROUND', 'RETURNSimple', 'RETURNLog', 'ADDED', 'SUBBED', 'MUL', 'DIV',
    'MINIMUM', 'MAXIMUM', 'CSMean', 'CSRes', 'EMA', 'MA', 'MADecay', 'MMAX',
    'MMIN', 'MRANK', 'MQUANTILE', 'MSUM', 'MVARIANCE', 'MSTD', 'MNPOSITIVE',
    'MAPOSITIVE', 'RSI', 'MARETURNLog', 'DELTA', 'SHIFT', 'MCORR'
]

#### 配置参数
configure = {'evaluate': 'long_evaluate', 'method': 'fitness', 'generations':3} # 评估函数

offset = 0
horizon = 1
universe = 'sh50'
industry_level = 1
industry_name = 'sw'
begin_date = '2021-01-01'
end_date = '2021-08-10'

# %%
#### 回调函数
def callback_save(gen, rootid, best_programs, custom_params):
    print(best_programs)

# %%
### 若设置callback_save回调 保存每一代最优因子回调函数。 如果不设置默认为None，通过阻塞方式即run函数返回所有进化代数最优因子。
gentic = EntropyAPI.StockGeneticist(offset=0,
                                    horizon=1,
                                    factor_columns=factor_columns,
                                    universe=universe,
                                    industry_name=industry_name,
                                    industry_level=industry_level,
                                    operators=operators_sets,
                                    callback_save=None)

# %%
evolution_sets = gentic.run(begin_date=begin_date,
                   end_date=end_date,
                   configure=configure)
# Out:
# 2023-01-25 22:05:44,363 - ultron - INFO - start fetch industry data
# 2023-01-25 22:05:53,630 - ultron - INFO - start industry median data ...
# 2023-01-25 22:05:53,856 - ultron - INFO - start create yields data
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:    5.2s remaining:    5.2s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    6.3s finished
# 2023-01-25 22:06:04,176 - ultron - INFO - ExpendTime:6.355702,Generation:0,Tournament:12, Fitness Mean:-0.468731,Fitness Max:4.658200,Fitness Min:-4.274860
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:    5.5s remaining:    5.5s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    6.1s finished
# 2023-01-25 22:06:10,327 - ultron - INFO - ExpendTime:6.150617,Generation:1,Tournament:20, Fitness Mean:0.817955,Fitness Max:4.658200,Fitness Min:-1.578795
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:    7.5s remaining:    7.5s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    7.9s finished
# 2023-01-25 22:06:18,204 - ultron - INFO - ExpendTime:7.875607,Generation:2,Tournament:20, Fitness Mean:1.421104,Fitness Max:4.658200,Fitness Min:-0.112409

# %%
for program in evolution_sets.values():
    print("eval:{0},metrics:{1}\n".format(program.transform(), program._retain_data))
# Out:
# eval:RSI(16,MQUANTILE(4,'VOL240')),metrics:long_evaluate:
# returns_mean:-0.38439546853007095
# returns_std:0.23678227072168428
# sharp:-1.6234132199107607
# turnover:0.055436095113253384
# maxdd:0.343392079266849
# returns_mdd:-1.1194069162887077
# win_rate:0.4657534246575342
# ic:-0.025975673642381316
# ir:-0.15658844978749398
# fitness:-4.274859960153135
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.669267173638939
# returns_std:0.2945694680037405
# sharp:-2.2720181360766163
# turnover:0.026143790849673203
# maxdd:0.5687907381611091
# returns_mdd:-1.176649211628636
# win_rate:0.2465753424657534
# ic:-0.0391304347826087
# ir:-0.052174371318405424
# fitness:-11.495484377684392
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.284871705108868
# returns_std:0.26891798330331435
# sharp:1.0593256040729688
# turnover:0.07076176561133768
# maxdd:0.260126883030277
# returns_mdd:1.095125970027907
# win_rate:0.547945205479452
# ic:-0.021398477713196692
# ir:-0.1321473058060626
# fitness:2.1254691048408465
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MARETURNLog(12,'hkHoldRatioB'),metrics:long_evaluate:
# returns_mean:-0.5232264780884084
# returns_std:0.2568158628174368
# sharp:-2.0373604354040835
# turnover:0.21104864848838242
# maxdd:0.3907788023712362
# returns_mdd:-1.3389326005235773
# win_rate:0.3904109589041096
# ic:0.0204683174953832
# ir:0.0978362222858269
# fitness:-3.2079045474043366
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.5905342193372822
# returns_std:0.26473505684567605
# sharp:-2.2306611990626033
# turnover:0.2149688404923607
# maxdd:0.39529314467664
# returns_mdd:-1.493914648634634
# win_rate:0.4246575342465753
# ic:0.018379444321293546
# ir:0.08404158672282816
# fitness:-3.6971612312121187
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.06730774124887388
# returns_std:0.1881889872783316
# sharp:0.3576603616519053
# turnover:0.4260174889807431
# maxdd:0.1364622616481032
# returns_mdd:0.4932333704276507
# win_rate:0.4589041095890411
# ic:-0.016779948635873614
# ir:-0.10909679918066408
# fitness:0.14216399050129225
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:DELTA(8,DELTA(18,MCORR(16,'RSI','CCI10'))),metrics:long_evaluate:
# returns_mean:-0.39682065209152756
# returns_std:0.2616379233339754
# sharp:-1.5166786490083635
# turnover:0.21159514536657725
# maxdd:0.31955330799704973
# returns_mdd:-1.2417979791189995
# win_rate:0.363013698630137
# ic:-0.0131352331035821
# ir:-0.058370889110157066
# fitness:-2.0770065042066035
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.6220617174841603
# returns_std:0.25438772958978934
# sharp:-2.4453290985664298
# turnover:0.21854966881958232
# maxdd:0.4332686142236787
# returns_mdd:-1.4357414709088887
# win_rate:0.363013698630137
# ic:-0.001007595836870094
# ir:-0.004146077668584224
# fitness:-4.1255226614492715
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.2252410653926328
# returns_std:0.21161162955377125
# sharp:1.0644077826327512
# turnover:0.4301448141861596
# maxdd:0.11126428501540411
# returns_mdd:2.024378850423108
# win_rate:0.4863013698630137
# ic:0.021115577719889003
# ir:0.12070839282428251
# fitness:0.7702371862089585
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MMAX(14,DELTA(20,'hkHoldRatioB')),metrics:long_evaluate:
# returns_mean:-0.20314127056310402
# returns_std:0.31012965025991857
# sharp:-0.6550204741560571
# turnover:0.047809814354708206
# maxdd:0.29863584009548677
# returns_mdd:-0.6802307134272664
# win_rate:0.4178082191780822
# ic:-0.0037955108015473066
# ir:-0.0167030242993937
# fitness:-1.3501916834988665
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.31123146892068543
# returns_std:0.29169998284251913
# sharp:-1.0669574467843244
# turnover:0.13493006623887438
# maxdd:0.33447126646577113
# returns_mdd:-0.9305178056379799
# win_rate:0.4315068493150685
# ic:-0.008627726747665097
# ir:-0.027443814439555497
# fitness:-1.6204457024458239
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.10809019835758121
# returns_std:0.25962529267397294
# sharp:0.41633154167809283
# turnover:0.1827398805935826
# maxdd:0.16577738529819097
# returns_mdd:0.652020166460912
# win_rate:0.4246575342465753
# ic:0.009657728081428953
# ir:0.04847384678877099
# fitness:0.32019592697530863
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:SHIFT(4,FLOOR(SHIFT(4,'CCI10'))),metrics:long_evaluate:
# returns_mean:-0.2530865685513474
# returns_std:0.3023257881377446
# sharp:-0.837131923513045
# turnover:0.32985599169028207
# maxdd:0.3827178274524898
# returns_mdd:-0.6612876390838244
# win_rate:0.4383561643835616
# ic:-0.0016948635159460426
# ir:-0.0058407705647027346
# fitness:-0.7332739622083291
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.46603056117686453
# returns_std:0.27100401229225934
# sharp:-1.7196445072343887
# turnover:0.268982016608957
# maxdd:0.3963606204963318
# returns_mdd:-1.1757741235577097
# win_rate:0.4520547945205479
# ic:0.01438873181627958
# ir:0.05524317218446018
# fitness:-2.2635195666232155
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.21294399262551722
# returns_std:0.28352921206504206
# sharp:0.7510478058841694
# turnover:0.5988380082992389
# maxdd:0.2670949841679986
# returns_mdd:0.7972594217328273
# win_rate:0.5068493150684932
# ic:-0.011244700260685905
# ir:-0.05152162356815555
# fitness:0.4478634274854702
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:DELTA(6,MSTD(16,MMIN(8,'hkHoldRatioAll'))),metrics:long_evaluate:
# returns_mean:-0.17852012999811012
# returns_std:0.31315526356827195
# sharp:-0.5700690704155781
# turnover:0.1586870927933101
# maxdd:0.2530941809593496
# returns_mdd:-0.7053505905249671
# win_rate:0.4726027397260274
# ic:-0.0023699251746517624
# ir:-0.010927151611296718
# fitness:-0.604644732746773
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.5386970473374394
# returns_std:0.3207826488079288
# sharp:-1.6793210273040318
# turnover:0.1654879641470992
# maxdd:0.4013636861210385
# returns_mdd:-1.3421668824692463
# win_rate:0.4041095890410959
# ic:0.0010006403632914012
# ir:0.004436652804045704
# fitness:-3.0298617808768964
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.36017691733932905
# returns_std:0.23601950443504904
# sharp:1.526047256990353
# turnover:0.3241750569404094
# maxdd:0.16360916711676382
# returns_mdd:2.201447044115075
# win_rate:0.4726027397260274
# ic:-0.002085787375460224
# ir:-0.015137934834766713
# fitness:1.6085557707541482
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:SHIFT(2,MARETURNLog(8,RSI(6,'RSI'))),metrics:long_evaluate:
# returns_mean:-0.06701751561824026
# returns_std:0.3016441614258317
# sharp:-0.22217408519182802
# turnover:0.3708546192259387
# maxdd:0.35654728907921607
# returns_mdd:-0.18796248820545824
# win_rate:0.4452054794520548
# ic:0.04315182563255617
# ir:0.164612745925088
# fitness:-0.09444646691786404
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.5200920773716068
# returns_std:0.29059964225405505
# sharp:-1.7897202946895554
# turnover:0.3681800616530392
# maxdd:0.35112974994727514
# returns_mdd:-1.4811962741684594
# win_rate:0.4383561643835616
# ic:0.021525021846025057
# ir:0.07906369174669188
# fitness:-2.127135466824449
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.4530745617533663
# returns_std:0.3153538729470967
# sharp:1.4367179242773194
# turnover:0.739034680878978
# maxdd:0.31794750285172646
# returns_mdd:1.424998019137316
# win_rate:0.4863013698630137
# ic:0.033534775241523505
# ir:0.15990670494112738
# fitness:1.1249259620884329
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:SHIFT(2,DELTA(2,MA(14,'hkHoldRatioB'))),metrics:long_evaluate:
# returns_mean:-0.012119198933223493
# returns_std:0.36281923894661566
# sharp:-0.03340285638768644
# turnover:0.15956617580079321
# maxdd:0.2659931706696328
# returns_mdd:-0.045562068013677334
# win_rate:0.4863013698630137
# ic:0.009972829296465644
# ir:0.038233912778056794
# fitness:-0.009205558561694454
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.5949149297593117
# returns_std:0.31069664993857604
# sharp:-1.914777419959066
# turnover:0.16214252703520166
# maxdd:0.5301838414915251
# returns_mdd:-1.12209177874166
# win_rate:0.4452054794520548
# ic:-0.01859766760156986
# ir:-0.07486008709557102
# fitness:-3.6677291989360383
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.5827957308260886
# returns_std:0.2620789057894608
# sharp:2.2237414685112937
# turnover:0.3217087028359949
# maxdd:0.16060178576355866
# returns_mdd:3.628824723556267
# win_rate:0.589041095890411
# ic:0.020928725120607405
# ir:0.13358729153071783
# fitness:2.9930300074655563
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:DELTA(18,'hkHoldRatioAll'),metrics:long_evaluate:
# returns_mean:0.13764982754975308
# returns_std:0.2879943277257981
# sharp:0.47796020371904924
# turnover:0.12896819360659595
# maxdd:0.25351674319015266
# returns_mdd:0.5429614857686441
# win_rate:0.4452054794520548
# ic:0.013804174511861613
# ir:0.05626648801075759
# fitness:0.49378542289170224
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.37031529650141837
# returns_std:0.31343134932491556
# sharp:-1.1814877398161427
# turnover:0.13159801332085586
# maxdd:0.3795769135126518
# returns_mdd:-0.9756001572236697
# win_rate:0.410958904109589
# ic:-0.01754598403864243
# ir:-0.06678064795755775
# fitness:-1.9819394337931588
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.5079651240511716
# returns_std:0.2718740733284854
# sharp:1.868383836061612
# turnover:0.2605662069274518
# maxdd:0.24865624081351662
# returns_mdd:2.0428408407900265
# win_rate:0.4315068493150685
# ic:0.017363514882314107
# ir:0.10001699481304042
# fitness:2.608699191911341
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MADecay(20,CSRes(MMAX(20,'aiDaPE60'),MMIN(14,'CCI10'))),metrics:long_evaluate:
# returns_mean:0.10693981385808393
# returns_std:0.2885100364111023
# sharp:0.37066236997628665
# turnover:0.031000268370283194
# maxdd:0.24099839857808517
# returns_mdd:0.4437366160482377
# win_rate:0.5136986301369864
# ic:0.037620887145756066
# ir:0.17617216997076354
# fitness:0.6884390289943013
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.7211167195144473
# returns_std:0.2842043630836657
# sharp:-2.537317554488637
# turnover:0.03448776353168708
# maxdd:0.5416631798077894
# returns_mdd:-1.3313009752118234
# win_rate:0.4246575342465753
# ic:-0.018912055795555063
# ir:-0.08423277524102425
# fitness:-11.60232671086663
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.8280565333725317
# returns_std:0.2711896894505672
# sharp:3.0534218872781698
# turnover:0.06548803190197025
# maxdd:0.3570305240544231
# returns_mdd:2.3192877851707405
# win_rate:0.6301369863013698
# ic:0.04261145554112056
# ir:0.21007005506342416
# fitness:10.857650026120975
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MMAX(2,MADecay(6,'hkHoldVolChgB120')),metrics:long_evaluate:
# returns_mean:0.17718202245713083
# returns_std:0.33625816163044764
# sharp:0.526922593039857
# turnover:0.06261991430475633
# maxdd:0.21297404002863793
# returns_mdd:0.8319418762648525
# win_rate:0.5273972602739726
# ic:0.04489152721423344
# ir:0.22078907802892034
# fitness:0.8863401306598653
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.6115217365031466
# returns_std:0.2569657417961412
# sharp:-2.379779235273648
# turnover:0.057285449602640544
# maxdd:0.48624390426561526
# returns_mdd:-1.2576440159733029
# win_rate:0.4794520547945205
# ic:0.00333849997294062
# ir:0.017442340425747993
# fitness:-7.775359123552506
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.7887037589602772
# returns_std:0.2731616862233058
# sharp:2.8873147250801607
# turnover:0.11990536390739687
# maxdd:0.11545646965454165
# returns_mdd:6.831178549977882
# win_rate:0.5684931506849316
# ic:0.027826863653008904
# ir:0.15012657302746396
# fitness:7.405114452792778
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MMAX(14,MMAX(12,'CCI10')),metrics:long_evaluate:
# returns_mean:0.6858294610903186
# returns_std:0.24961475437388636
# sharp:2.7475517735744357
# turnover:0.2386006622206159
# maxdd:0.12597059778708147
# returns_mdd:5.444361407647871
# win_rate:0.23972602739726026
# ic:0.1251872158848903
# ir:0.15339907153063673
# fitness:4.658199999729491
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.4057755232207141
# returns_std:0.2414047634955717
# sharp:-1.6808927767001483
# turnover:0.02541978269636106
# maxdd:0.38388108257572523
# returns_mdd:-1.0570344349820102
# win_rate:0.4589041095890411
# ic:-0.004250212937160038
# ir:-0.02348195768724757
# fitness:-6.715788605589702
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:1.0916049843110327
# returns_std:0.29038298921248024
# sharp:3.7591905340993614
# turnover:0.14145161158446878
# maxdd:0.13211464795969902
# returns_mdd:8.262558324675867
# win_rate:0.6027397260273972
# ic:0.008188919403377789
# ir:0.04568331938550048
# fitness:10.442948674725178
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:FLOOR(RSI(20,MADecay(6,'aiDaPE60'))),metrics:long_evaluate:
# returns_mean:-0.08811684192411684
# returns_std:0.03024837292272012
# sharp:-2.9131101414691507
# turnover:0.3
# maxdd:0.051051821114766104
# returns_mdd:-1.726027397260274
# win_rate:0.00684931506849315
# ic:nan
# ir:nan
# fitness:-1.5787949903468539
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.423155082332037
# returns_std:0.24133343425577275
# sharp:-1.7534043040367295
# turnover:0.0366834348979428
# maxdd:0.3875883579312937
# returns_mdd:-1.091764171118494
# win_rate:0.4520547945205479
# ic:-3.8440444039510197e-05
# ir:-0.00017762419144134103
# fitness:-5.955206859013665
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.33503824040792024
# returns_std:0.2375906664283538
# sharp:1.4101489988831362
# turnover:0.05723138010342225
# maxdd:0.10658028007074329
# returns_mdd:3.14352936758598
# win_rate:0.5342465753424658
# ic:3.387576612195335e-05
# ir:0.00015672204710666686
# fitness:3.411890491750867
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MMAX(12,'hkHoldVolChgB120'),metrics:long_evaluate:
# returns_mean:-0.0772618125408286
# returns_std:0.31140487445336024
# sharp:-0.24810726767348745
# turnover:0.04407515649564532
# maxdd:0.2189059195478579
# returns_mdd:-0.3529452867259598
# win_rate:0.5
# ic:0.006566963670949373
# ir:0.03403077117772908
# fitness:-0.3284921538100469
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.6778204999799765
# returns_std:0.2580730237153442
# sharp:-2.626467850927402
# turnover:0.057239435648015785
# maxdd:0.4920264097116309
# returns_mdd:-1.3776099953196346
# win_rate:0.4657534246575342
# ic:-0.008456758149692347
# ir:-0.033459126357807206
# fitness:-9.038196255559681
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.6005586874391481
# returns_std:0.2696478015272898
# sharp:2.22719667669298
# turnover:0.1013145921436611
# maxdd:0.16577410626756628
# returns_mdd:3.622753281322606
# win_rate:0.547945205479452
# ic:0.02046438598328219
# ir:0.10465688628815882
# fitness:5.422509187356091
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MMAX(12,MARETURNLog(12,'hkHoldRatioAll')),metrics:long_evaluate:
# returns_mean:-0.10927065695905269
# returns_std:0.3026632350250779
# sharp:-0.3610304930164339
# turnover:0.19080339555386547
# maxdd:0.25922404987594266
# returns_mdd:-0.4215297809418013
# win_rate:0.4246575342465753
# ic:-0.038819958116110956
# ir:-0.09650881304150853
# fitness:-0.2732137875329483
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.5699712954742693
# returns_std:0.2499903053260841
# sharp:-2.279973596299289
# turnover:0.05290571908352061
# maxdd:0.38101876858121264
# returns_mdd:-1.4959139613952697
# win_rate:0.410958904109589
# ic:0.032924097210756384
# ir:0.19408435263023735
# fitness:-7.483504067981688
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.4607006385152165
# returns_std:0.2600718576503547
# sharp:1.7714359511154443
# turnover:0.2437091146373861
# maxdd:0.2073386101463109
# returns_mdd:2.2219722520090097
# win_rate:0.4931506849315068
# ic:-0.0011982292551041707
# ir:-0.007099631635463095
# fitness:2.435560799838165
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:DIV('lpnpQ',MMAX(2,'lpnpQ')),metrics:long_evaluate:
# returns_mean:0.0916482173544973
# returns_std:0.23078493794177551
# sharp:0.3971152457861835
# turnover:0.6666666666666666
# maxdd:0.08566747092003685
# returns_mdd:1.0698135052923758
# win_rate:0.04794520547945205
# ic:-0.39999999999999997
# ir:-0.5529308131009096
# fitness:0.14723945492219312
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.3480938611290216
# returns_std:0.23944150001794098
# sharp:-1.4537741415040393
# turnover:0.024246948833093623
# maxdd:0.33499231480258784
# returns_mdd:-1.0391099907296515
# win_rate:0.4657534246575342
# ic:-0.006285674100865942
# ir:-0.04196627867364497
# fitness:-5.5082871713848
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.439742078483519
# returns_std:0.31270525874912386
# sharp:1.4062509861284866
# turnover:0.12013735979199773
# maxdd:0.17393183026199316
# returns_mdd:2.528243840251301
# win_rate:0.5273972602739726
# ic:0.00532708136695844
# ir:0.03512057132383462
# fitness:2.690436899404569
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:DELTA(18,MSTD(14,MMAX(12,'hkHoldVolChgB120'))),metrics:long_evaluate:
# returns_mean:0.1546566834908055
# returns_std:0.31287329943218856
# sharp:0.49431090403521455
# turnover:0.13367396481064975
# maxdd:0.1971959880550519
# returns_mdd:0.7842790566693956
# win_rate:0.4452054794520548
# ic:0.07830428864556362
# ir:0.411600630183206
# fitness:0.5316932199557286
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.004720431455128277
# returns_std:0.387199725034127
# sharp:-0.012191205597349606
# turnover:0.1304812005700811
# maxdd:0.26555905634688265
# returns_mdd:-0.017775448971931434
# win_rate:0.363013698630137
# ic:0.0061614680936993935
# ir:0.02542826608020815
# fitness:-0.0023188012790897445
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.15937711494593398
# returns_std:0.395027042011591
# sharp:0.4034587458477273
# turnover:0.26415516538073086
# maxdd:0.32026487425197103
# returns_mdd:0.49764157033513057
# win_rate:0.4383561643835616
# ic:0.020298221927866743
# ir:0.14772711924723872
# fitness:0.3133881429709009
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MADecay(6,'hkHoldVolChgB120'),metrics:long_evaluate:
# returns_mean:0.19261971637369268
# returns_std:0.3409978652656241
# sharp:0.5648707396559489
# turnover:0.06632925607904731
# maxdd:0.21758731896274147
# returns_mdd:0.8852524921577617
# win_rate:0.5136986301369864
# ic:0.05181414778477575
# ir:0.25464023170503036
# fitness:0.9626022780488993
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.6017342951108627
# returns_std:0.25610163212490805
# sharp:-2.349591801185319
# turnover:0.057785096030531787
# maxdd:0.4815676252546237
# returns_mdd:-1.249532284884604
# win_rate:0.4726027397260274
# ic:-0.006571489832389318
# ir:-0.03631706596850466
# fitness:-7.58205412826159
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.7943540114845556
# returns_std:0.27572655497286347
# sharp:2.8809485236659
# turnover:0.12411435210957908
# maxdd:0.1157678900291203
# returns_mdd:6.861609132590596
# win_rate:0.5684931506849316
# ic:0.028084992797490202
# ir:0.15275301745733144
# fitness:7.288388978306883
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MMAX(14,'CCI10'),metrics:long_evaluate:
# returns_mean:0.35213443173474024
# returns_std:0.30271646038029787
# sharp:1.1632483786721057
# turnover:0.22558253965148178
# maxdd:0.16205614384015815
# returns_mdd:2.1729162708083636
# win_rate:0.4863013698630137
# ic:0.05269019006883085
# ir:0.09816791161623507
# fitness:1.4533625369611531
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.3760919549001535
# returns_std:0.2473159872958044
# sharp:-1.5206940683956898
# turnover:0.05360329865350502
# maxdd:0.37608920373457794
# returns_mdd:-1.0000073151942366
# win_rate:0.4657534246575342
# ic:0.006912673570196169
# ir:0.0369251960978961
# fitness:-4.028033886939442
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.7282263866348938
# returns_std:0.29160074232590966
# sharp:2.497340647442476
# turnover:0.2621898935367245
# maxdd:0.18454057914471694
# returns_mdd:3.94615856311916
# win_rate:0.541095890410959
# ic:-0.0036379072176815925
# ir:-0.018267914540973904
# fitness:4.162009027795746
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MMAX(14,ROUND('CCI10')),metrics:long_evaluate:
# returns_mean:0.35333161880372504
# returns_std:0.30305875571635676
# sharp:1.16588487261665
# turnover:0.2256640976498315
# maxdd:0.16221060851168573
# returns_mdd:2.1782275650502285
# win_rate:0.4863013698630137
# ic:0.029916359597843396
# ir:0.05419324694966294
# fitness:1.4588669444512832
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.37580133841818253
# returns_std:0.24733077540320594
# sharp:-1.5194281334603026
# turnover:0.053612000869393814
# maxdd:0.3760082744166253
# returns_mdd:-0.999449650413242
# win_rate:0.4657534246575342
# ic:0.006334522550958174
# ir:0.033948851284156464
# fitness:-4.022798844735108
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.7291329572219076
# returns_std:0.2918223766149608
# sharp:2.4985505418727625
# turnover:0.26227400897026537
# maxdd:0.1847288815823036
# returns_mdd:3.947043640260723
# win_rate:0.541095890410959
# ic:-0.0024205066386760628
# ir:-0.012268285900063972
# fitness:4.165948301655253
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MADecay(6,MMAX(14,'CCI10')),metrics:long_evaluate:
# returns_mean:0.4420526292007372
# returns_std:0.33568888730242263
# sharp:1.316852138755762
# turnover:0.18392234366611288
# maxdd:0.1780208687115115
# returns_mdd:2.4831506126233864
# win_rate:0.4589041095890411
# ic:0.07341530523348705
# ir:0.11803714343158252
# fitness:2.0415346539387045
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.38354338217830947
# returns_std:0.2476121503636047
# sharp:-1.5489683426887464
# turnover:0.03990433135971457
# maxdd:0.3847145838193267
# returns_mdd:-0.9969556609229888
# win_rate:0.4520547945205479
# ic:0.007329130214919177
# ir:0.03593357601113685
# fitness:-4.802194761256894
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.8255960113790468
# returns_std:0.3026410493523721
# sharp:2.727971017632132
# turnover:0.20745002798706397
# maxdd:0.1742755067093932
# returns_mdd:4.737303749492115
# win_rate:0.5684931506849316
# ic:-0.006384581229752174
# ir:-0.030878792492059867
# fitness:5.442103488519915
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MMAX(14,MMAX(14,MMAX(12,'CCI10'))),metrics:long_evaluate:
# returns_mean:0.4838942809366895
# returns_std:0.1856995267116216
# sharp:2.605791675969878
# turnover:0.21746270126068296
# maxdd:0.1018414090592864
# returns_mdd:4.751449193470931
# win_rate:0.136986301369863
# ic:0.18450359164644878
# ir:0.2572085315380633
# fitness:3.8870716665424103
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.4025928000284349
# returns_std:0.2366660896068778
# sharp:-1.701100485908967
# turnover:0.017520055332650983
# maxdd:0.3720392321413409
# returns_mdd:-1.0821245859240094
# win_rate:0.4589041095890411
# ic:-0.007192303331747581
# ir:-0.04115533980999181
# fitness:-8.15446050755132
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.8864870809651244
# returns_std:0.27718610262874116
# sharp:3.198165682038077
# turnover:0.06518311314321162
# maxdd:0.11844751323283442
# returns_mdd:7.484218594125659
# win_rate:0.5684931506849316
# ic:0.009340722590406024
# ir:0.05404658125089935
# fitness:11.794230603438866
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MMAX(14,MMAX(14,'CCI10')),metrics:long_evaluate:
# returns_mean:0.5437043428512721
# returns_std:0.20502687073737372
# sharp:2.6518687082129957
# turnover:0.22501125947764758
# maxdd:0.12220603996091295
# returns_mdd:4.449079137374662
# win_rate:0.2191780821917808
# ic:0.18332568332568333
# ir:0.2222134065914917
# fitness:4.1222212181727045
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.3978740508144863
# returns_std:0.24078719766051737
# sharp:-1.6523887261458292
# turnover:0.023339014091825597
# maxdd:0.3783455406395733
# returns_mdd:-1.0516155420833058
# win_rate:0.4589041095890411
# ic:-0.0016269984348894384
# ir:-0.009291638059929542
# fitness:-6.822503668930244
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.9415783936657585
# returns_std:0.2712981766582403
# sharp:3.47064033110655
# turnover:0.11580939469907801
# maxdd:0.12331505010115057
# returns_mdd:7.6355513207302605
# win_rate:0.5958904109589042
# ic:0.005167656103537307
# ir:0.02999026332883895
# fitness:9.896142846709342
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:DELTA(10,MMAX(12,EMA(10,'hkHoldVolChgB120'))),metrics:long_evaluate:
# returns_mean:-0.05194162558017128
# returns_std:0.33159023630859336
# sharp:-0.1566440138841482
# turnover:0.10086531431491877
# maxdd:0.2260349709035276
# returns_mdd:-0.22979464360114488
# win_rate:0.4383561643835616
# ic:0.020179607577277648
# ir:0.09026884796823625
# fitness:-0.11240888723062571
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.5822157699085277
# returns_std:0.2555108062980696
# sharp:-2.2786346234974344
# turnover:0.10091398730458737
# maxdd:0.39840017557352286
# returns_mdd:-1.4613843206027468
# win_rate:0.4383561643835616
# ic:0.006743242998200966
# ir:0.02805587421845858
# fitness:-5.473195878587932
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.5302741443283565
# returns_std:0.26553786375796906
# sharp:1.9969812847921673
# turnover:0.20030610472454866
# maxdd:0.12701945696050854
# returns_mdd:4.174747373492735
# win_rate:0.5136986301369864
# ic:0.007260144107158373
# ir:0.04378341268841889
# fitness:3.2492051129786357
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MMAX(12,CSMean('aiDaPE60')),metrics:long_evaluate:
# returns_mean:-0.0024789806091020813
# returns_std:0.1318170374388502
# sharp:-0.018806223059383183
# turnover:0.05654657514705769
# maxdd:0.0870433668506018
# returns_mdd:-0.028479833659891825
# win_rate:0.1232876712328767
# ic:-0.08084520834544433
# ir:-0.6187184335382291
# fitness:-0.003937630811664866
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.40337162394410575
# returns_std:0.2033886514946158
# sharp:-1.983255314295567
# turnover:0.023364485981308428
# maxdd:0.3785438941211153
# returns_mdd:-1.065587452891386
# win_rate:0.3424657534246575
# ic:0.062366303580771346
# ir:0.43364104768699047
# fitness:-8.240492775590123
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.40089264333500374
# returns_std:0.24238536622975765
# sharp:1.6539473878757047
# turnover:0.03377741596796905
# maxdd:0.10614487262278272
# returns_mdd:3.7768441699458686
# win_rate:0.5
# ic:-0.06359823056508287
# ir:-0.4511937465606054
# fitness:5.698001021541329
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MMAX(12,CSMean('CCI10')),metrics:long_evaluate:
# returns_mean:0.11611775105223894
# returns_std:0.10881966042794539
# sharp:1.0670659198493453
# turnover:0.26315789473684226
# maxdd:0.061695762526639344
# returns_mdd:1.8821025350339249
# win_rate:0.0821917808219178
# ic:-0.17785945835997752
# ir:-3.0248456750757873
# fitness:0.7088141125552604
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.6198412040022077
# returns_std:0.2261384586519278
# sharp:-2.7409809357384316
# turnover:0.034306569343065724
# maxdd:0.5039588095516028
# returns_mdd:-1.2299441784809977
# win_rate:0.3835616438356164
# ic:0.015484637788915796
# ir:0.10241866361175975
# fitness:-11.650849461091543
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.7359589550544464
# returns_std:0.23825596946073657
# sharp:3.0889423535544567
# turnover:0.0664383561643836
# maxdd:0.11825146867232081
# returns_mdd:6.22367707832717
# win_rate:0.6027397260273972
# ic:-0.031568128972983035
# ir:-0.20805574949208314
# fitness:10.280805935161675
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MMAX(18,'CCI10'),metrics:long_evaluate:
# returns_mean:0.4669072355699953
# returns_std:0.3583411791218445
# sharp:1.3029684076895773
# turnover:0.20891401717839034
# maxdd:0.18652496969750754
# returns_mdd:2.503188909920163
# win_rate:0.3904109589041096
# ic:0.1112984062351151
# ir:0.1547192936574465
# fitness:1.9478943494340328
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.3995208666704102
# returns_std:0.2432378363485561
# sharp:-1.6425111843944495
# turnover:0.038037902363598435
# maxdd:0.3929071074485622
# returns_mdd:-1.016832882624079
# win_rate:0.4657534246575342
# ic:0.003556071613226638
# ir:0.019361531842496726
# fitness:-5.323163300527565
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.8664281022404056
# returns_std:0.3125819035664962
# sharp:2.7718434508032503
# turnover:0.21117897139500416
# maxdd:0.18097493926036143
# returns_mdd:4.787558464069492
# win_rate:0.5342465753424658
# ic:-0.004327648867766287
# ir:-0.02320887411026341
# fitness:5.614481152809043
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MMAX(20,MMAX(14,'CCI10')),metrics:long_evaluate:
# returns_mean:0.3675509039053526
# returns_std:0.20184648868774288
# sharp:1.8209427684122608
# turnover:0.23540012801567453
# maxdd:0.1302718660741802
# returns_mdd:2.8214142852307
# win_rate:0.1643835616438356
# ic:0.17062144205001345
# ir:0.20725540855959268
# fitness:2.275368264511554
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.3906283002370975
# returns_std:0.23788589994242676
# sharp:-1.6420826132681152
# turnover:0.019243502317318282
# maxdd:0.3715204431248589
# returns_mdd:-1.051431509263723
# win_rate:0.4657534246575342
# ic:-0.006008331472757003
# ir:-0.03428927386619316
# fitness:-7.398348695002604
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.7581792041424499
# returns_std:0.27911932963624186
# sharp:2.7163264010791934
# turnover:0.08696134736292328
# maxdd:0.13614799776240433
# returns_mdd:5.568787030313656
# win_rate:0.5616438356164384
# ic:0.0072291930470818454
# ir:0.04212389029442773
# fitness:8.020561233084331
# category:both
# freq:252
# hold:1,hold:1,freq:252
#
# eval:MMAX(14,MADecay(6,MMAX(14,'CCI10'))),metrics:long_evaluate:
# returns_mean:0.3769027084368898
# returns_std:0.21243514468597238
# sharp:1.7742012932654716
# turnover:0.20969049173851997
# maxdd:0.09800999208687364
# returns_mdd:3.845553911511517
# win_rate:0.21232876712328766
# ic:0.16581231268731264
# ir:0.2030604224836864
# fitness:2.378636898449745
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.3945678003910681
# returns_std:0.2411317588431521
# sharp:-1.6363161878138202
# turnover:0.019643557215802125
# maxdd:0.3783638717821443
# returns_mdd:-1.0428263103784225
# win_rate:0.4657534246575342
# ic:-0.003961238442684858
# ir:-0.0217949985451868
# fitness:-7.33361284659616
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.7714705088279579
# returns_std:0.27723384446882127
# sharp:2.782742887348735
# turnover:0.10294525941329634
# maxdd:0.11319981968038201
# returns_mdd:6.815121358021535
# win_rate:0.5753424657534246
# ic:0.008615172096235758
# ir:0.0486016764827067
# fitness:7.617800057063604
# category:both
# freq:252
# hold:1,hold:1,freq:252
