# %%
import os

# %%
os.environ['IGNORE_WARNINGS'] = '0'
os.environ['DB_URL'] = 'mysql+mysqlconnector://ultron:1234567@127.0.0.1/ultron'

# %%
from jdw import EntropyAPI
# Out:
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.0.3-py3.6.egg/jdw/__init__.py:11: UserWarning: if use distributed calculating, please configure MQ_URL
#   warnings.warn('if use distributed calculating, please configure MQ_URL')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.0.3-py3.6.egg/jdw/__init__.py:15: UserWarning: if use distributed calculating, please configure NTN_URL
#   warnings.warn('if use distributed calculating, please configure NTN_URL')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.0.3-py3.6.egg/jdw/__init__.py:19: UserWarning: if use memory database, please configure KN_MG
#   warnings.warn('if use memory database, please configure KN_MG')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.0.3-py3.6.egg/jdw/__init__.py:27: UserWarning: if use trader, please configure ATL_URL
#   warnings.warn('if use trader, please configure ATL_URL')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/Finance_Jindowin-1.0.3-py3.6.egg/jdw/__init__.py:31: UserWarning: if use trader, please configure IREY_URL
#   warnings.warn('if use trader, please configure IREY_URL')
# /home/kerry/work/workenv/ultron/lib/python3.6/site-packages/aliyunsdkcore/auth/algorithm/sha_hmac256.py:20: CryptographyDeprecationWarning: Python 3.6 is no longer supported by the Python core team. Therefore, support for it is deprecated in cryptography and will be removed in a future release.
#   from cryptography.hazmat.backends import default_backend
# /home/kerry/ultron/2023-01-25.log

# %% [markdown]
# #### 设置参数

# %%
#### 基础因子
factor_columns = [
    'Alpha191_20_10', 'Alpha191_66_6', 'Alpha191_41_10_10', 'Alpha101_53_9',
    'Alpha101_11_3'
]

#### 运算符
operators_sets = [
    'AVG', 'DIFF', 'LOG', 'SQRT', 'ABS', 'ACOSH', 'ASINH', 'CEIL', 'FLOOR',
    'ROUND', 'RETURNSimple', 'RETURNLog', 'ADDED', 'SUBBED', 'MUL', 'DIV',
    'MINIMUM', 'MAXIMUM', 'CSMean', 'CSRes', 'EMA', 'MA', 'MADecay', 'MMAX',
    'MMIN', 'MRANK', 'MQUANTILE', 'MSUM', 'MVARIANCE', 'MSTD', 'MNPOSITIVE',
    'MAPOSITIVE', 'RSI', 'MARETURNLog', 'DELTA', 'SHIFT', 'MCORR'
]

#### 配置参数
configure = {'evaluate': 'both_evaluate', 'method': 'fitness', 'generations':3} # 评估函数

offset = 0
horizon = 1
industry_level = 1
industry_name = 'kh'
universe = 'enliven_fst'
begin_date = '2021-01-01'
end_date = '2021-08-10'

# %%
#### 回调函数
def callback_save(gen, rootid, best_programs, custom_params):
    print(best_programs)

# %%
### 若设置callback_save回调 保存每一代最优因子回调函数。 如果不设置默认为None，通过阻塞方式即run函数返回所有进化代数最优因子。
gentic = EntropyAPI.FuturesGeneticist(offset=0,
                                      horizon=1,
                                      factor_columns=factor_columns,
                                      universe=universe,
                                      industry_name=industry_name,
                                      industry_level=industry_level,
                                      operators=operators_sets,
                                      callback_save=None)

# %%
evolution_sets = gentic.run(begin_date=begin_date,
                   end_date=end_date,
                   configure=configure)
# Out:
# 2023-01-25 07:42:21,525 - ultron - INFO - start fetch industry data
# 2023-01-25 07:42:22,799 - ultron - INFO - start industry median data ...
# 2023-01-25 07:42:22,913 - ultron - INFO - start create yields data
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:    8.4s remaining:    8.4s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    9.4s finished
# 2023-01-25 07:42:38,793 - ultron - INFO - name:ultron_1674603757844794,method:gen,gen:0,formual:MMIN(18,MAPOSITIVE(2,MVARIANCE(20,'Alpha191_41_10_10'))),fitness:3.901222,identification:7583f3a665f3204fddeeca95dd33e67b
# 2023-01-25 07:42:38,795 - ultron - INFO - name:ultron_1674603752409946,method:gen,gen:0,formual:MSTD(8,MQUANTILE(6,MVARIANCE(6,'Alpha191_41_10_10'))),fitness:4.023990,identification:dd51cf2e84bb455134b1814607bafd4d
# 2023-01-25 07:42:38,796 - ultron - INFO - name:ultron_1674603753419331,method:gen,gen:0,formual:MMIN(14,RSI(8,'Alpha191_20_10')),fitness:4.201701,identification:9bce164fd1ed8559b77dcdc60d5f4d60
# 2023-01-25 07:42:38,798 - ultron - INFO - name:ultron_1674603752500082,method:gen,gen:0,formual:MMIN(14,RSI(14,'Alpha191_41_10_10')),fitness:4.329466,identification:cc0f50b9a24f8968f6acafbde35cb137
# 2023-01-25 07:42:38,798 - ultron - INFO - name:ultron_1674603753009443,method:gen,gen:0,formual:MSTD(8,EMA(18,RSI(14,'Alpha191_41_10_10'))),fitness:4.655669,identification:1a32c297f49aea6bed06ec76a4150248
# 2023-01-25 07:42:38,799 - ultron - INFO - name:ultron_1674603754653454,method:gen,gen:0,formual:RSI(16,'Alpha191_66_6'),fitness:4.663941,identification:87390d81322f773f20a21cc38ac1fbf2
# 2023-01-25 07:42:38,803 - ultron - INFO - name:ultron_1674603755228491,method:gen,gen:0,formual:RSI(16,'Alpha101_53_9'),fitness:4.796231,identification:e4b290c5e462a98f994277cfbbe9423a
# 2023-01-25 07:42:38,803 - ultron - INFO - name:ultron_1674603756943547,method:gen,gen:0,formual:MMIN(18,MSTD(4,MCORR(16,'Alpha191_20_10','Alpha101_53_9'))),fitness:4.832023,identification:f3e273cb8801f4f914ad79208450d755
# 2023-01-25 07:42:38,804 - ultron - INFO - name:ultron_1674603755647544,method:gen,gen:0,formual:DELTA(4,DELTA(2,MAPOSITIVE(4,'Alpha191_20_10'))),fitness:4.835558,identification:f3ed69d82d7b7a7ed4a03c7871dabf46
# 2023-01-25 07:42:38,804 - ultron - INFO - name:ultron_1674603751502371,method:gen,gen:0,formual:RSI(12,SHIFT(18,'Alpha191_66_6')),fitness:5.210239,identification:674f29c89f51657d5c57ca9a56983384
# 2023-01-25 07:42:38,805 - ultron - INFO - name:ultron_1674603753583637,method:gen,gen:0,formual:MSUM(16,MSUM(4,'Alpha191_41_10_10')),fitness:5.433562,identification:5608697582f192427194d07dc038a2cf
# 2023-01-25 07:42:38,805 - ultron - INFO - name:ultron_1674603752007521,method:gen,gen:0,formual:MADecay(20,MQUANTILE(16,'Alpha191_41_10_10')),fitness:5.449768,identification:91cedd963625a25dd2fe66ba8de050d7
# 2023-01-25 07:42:38,806 - ultron - INFO - name:ultron_1674603753106925,method:gen,gen:0,formual:EMA(2,RSI(16,'Alpha191_66_6')),fitness:5.483621,identification:02e2e8c316f1823db84aced74e4aee88
# 2023-01-25 07:42:38,807 - ultron - INFO - name:ultron_1674603751933618,method:gen,gen:0,formual:MADecay(20,MAPOSITIVE(18,'Alpha191_41_10_10')),fitness:5.556265,identification:9fe3685f7703e035fc9758fe4958e440
# 2023-01-25 07:42:38,808 - ultron - INFO - name:ultron_1674603751940474,method:gen,gen:0,formual:MADecay(20,EMA(14,'Alpha191_41_10_10')),fitness:5.765790,identification:3c0b5b033943311af7fc6ced6d043dea
# 2023-01-25 07:42:38,811 - ultron - INFO - name:ultron_1674603752662057,method:gen,gen:0,formual:RSI(6,MARETURNLog(10,'Alpha101_53_9')),fitness:7.081835,identification:bb0477561966aa89547dc885b1c4f589
# 2023-01-25 07:42:38,812 - ultron - INFO - name:ultron_1674603755740762,method:gen,gen:0,formual:LOG('Alpha191_41_10_10'),fitness:7.196366,identification:67901ba05249914db9945afb3d4c8a3b
# 2023-01-25 07:42:38,812 - ultron - INFO - name:ultron_1674603753757323,method:gen,gen:0,formual:SHIFT(4,MMAX(14,'Alpha191_66_6')),fitness:10.852764,identification:05869ea2b621ac93c21ed831a109f143
# 2023-01-25 07:42:38,813 - ultron - INFO - name:ultron_1674603752733772,method:gen,gen:0,formual:RSI(6,MNPOSITIVE(8,'Alpha191_41_10_10')),fitness:17.925043,identification:64be5eafb242d13923d50d71bc908b65
# 2023-01-25 07:42:38,813 - ultron - INFO - name:ultron_1674603751610395,method:gen,gen:0,formual:MNPOSITIVE(2,MMAX(12,'Alpha191_41_10_10')),fitness:18.518876,identification:7d48ecdec55f7c9b03a2a937b04679ab
# 2023-01-25 07:42:38,814 - ultron - INFO - ExpendTime:9.429357,Generation:0,Tournament:20, Fitness Mean:6.735696,Fitness Max:18.518876,Fitness Min:3.901222
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:   11.6s remaining:   11.6s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   12.6s finished
# 2023-01-25 07:42:51,418 - ultron - INFO - name:ultron_1674603752007521,method:gen,gen:0,formual:MADecay(20,MQUANTILE(16,'Alpha191_41_10_10')),fitness:5.449768,identification:91cedd963625a25dd2fe66ba8de050d7
# 2023-01-25 07:42:51,420 - ultron - INFO - name:ultron_1674603753106925,method:gen,gen:0,formual:EMA(2,RSI(16,'Alpha191_66_6')),fitness:5.483621,identification:02e2e8c316f1823db84aced74e4aee88
# 2023-01-25 07:42:51,421 - ultron - INFO - name:ultron_1674603767095636,method:Hoist Mutation,gen:1,formual:MSUM(16,MSTD(2,LOG('Alpha191_41_10_10'))),fitness:5.544671,identification:36bd3936a1016418aaf4640c4c992500
# 2023-01-25 07:42:51,423 - ultron - INFO - name:ultron_1674603751933618,method:gen,gen:0,formual:MADecay(20,MAPOSITIVE(18,'Alpha191_41_10_10')),fitness:5.556265,identification:9fe3685f7703e035fc9758fe4958e440
# 2023-01-25 07:42:51,423 - ultron - INFO - name:ultron_1674603751940474,method:gen,gen:0,formual:MADecay(20,EMA(14,'Alpha191_41_10_10')),fitness:5.765790,identification:3c0b5b033943311af7fc6ced6d043dea
# 2023-01-25 07:42:51,426 - ultron - INFO - name:ultron_1674603771248598,method:Crossover,gen:1,formual:MADecay(20,MRANK(18,EMA(14,'Alpha191_41_10_10'))),fitness:5.821039,identification:878679ab0db20daa811891a94fae0743
# 2023-01-25 07:42:51,427 - ultron - INFO - name:ultron_1674603766894058,method:Crossover,gen:1,formual:LOG(MVARIANCE(10,MADecay(20,'Alpha191_41_10_10'))),fitness:6.047778,identification:1b74ec320d02169d1bc6bc285bd7962d
# 2023-01-25 07:42:51,427 - ultron - INFO - name:ultron_1674603760258268,method:Crossover,gen:1,formual:MSTD(16,'Alpha191_66_6'),fitness:6.343498,identification:b6bc31984849fa73dedb6b46338923a6
# 2023-01-25 07:42:51,428 - ultron - INFO - name:ultron_1674603770659764,method:Crossover,gen:1,formual:MADecay(20,MRANK(18,EMA(14,'Alpha191_20_10'))),fitness:6.495663,identification:47b1a569d2f6a25cafd972cb5b1bc9ba
# 2023-01-25 07:42:51,429 - ultron - INFO - name:ultron_1674603761766446,method:Subtree Mutation,gen:1,formual:MA(14,MNPOSITIVE(8,'Alpha191_20_10')),fitness:6.727486,identification:c03121eac150c41ee5e336d09e6671df
# 2023-01-25 07:42:51,431 - ultron - INFO - name:ultron_1674603752662057,method:gen,gen:0,formual:RSI(6,MARETURNLog(10,'Alpha101_53_9')),fitness:7.081835,identification:bb0477561966aa89547dc885b1c4f589
# 2023-01-25 07:42:51,432 - ultron - INFO - name:ultron_1674603755740762,method:gen,gen:0,formual:LOG('Alpha191_41_10_10'),fitness:7.196366,identification:67901ba05249914db9945afb3d4c8a3b
# 2023-01-25 07:42:51,433 - ultron - INFO - name:ultron_1674603762982182,method:Reproduction,gen:1,formual:MMIN(14,MVARIANCE(20,MMIN(6,MMAX(12,'Alpha191_66_6')))),fitness:7.683622,identification:8ae2ccc567468b3bc46925d6eb8673b8
# 2023-01-25 07:42:51,433 - ultron - INFO - name:ultron_1674603761215612,method:Subtree Mutation,gen:1,formual:MA(14,MNPOSITIVE(8,'Alpha101_53_9')),fitness:8.285532,identification:7956a344a78a63da51d9af0701f852fa
# 2023-01-25 07:42:51,435 - ultron - INFO - name:ultron_1674603753757323,method:gen,gen:0,formual:SHIFT(4,MMAX(14,'Alpha191_66_6')),fitness:10.852764,identification:05869ea2b621ac93c21ed831a109f143
# 2023-01-25 07:42:51,436 - ultron - INFO - name:ultron_1674603770457621,method:Point Mutation,gen:1,formual:MNPOSITIVE(2,MSUM(4,SHIFT(2,'Alpha191_41_10_10'))),fitness:16.277929,identification:d68a15f47639701829b4d3ba8e6e0a4a
# 2023-01-25 07:42:51,436 - ultron - INFO - name:ultron_1674603752733772,method:gen,gen:0,formual:RSI(6,MNPOSITIVE(8,'Alpha191_41_10_10')),fitness:17.925043,identification:64be5eafb242d13923d50d71bc908b65
# 2023-01-25 07:42:51,436 - ultron - INFO - name:ultron_1674603751610395,method:gen,gen:0,formual:MNPOSITIVE(2,MMAX(12,'Alpha191_41_10_10')),fitness:18.518876,identification:7d48ecdec55f7c9b03a2a937b04679ab
# 2023-01-25 07:42:51,437 - ultron - INFO - name:ultron_1674603761437468,method:Point Mutation,gen:1,formual:MNPOSITIVE(2,'Alpha191_41_10_10'),fitness:18.518876,identification:b81723a9c5cdb863d818a0023941d4de
# 2023-01-25 07:42:51,439 - ultron - INFO - name:ultron_1674603761512010,method:Subtree Mutation,gen:1,formual:MA(14,MNPOSITIVE(8,'Alpha191_41_10_10')),fitness:18.532822,identification:6650d35da2b74b80a7679a80c790621d
# 2023-01-25 07:42:51,440 - ultron - INFO - ExpendTime:12.625322,Generation:1,Tournament:20, Fitness Mean:9.505462,Fitness Max:18.532822,Fitness Min:5.449768
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:   12.8s remaining:   12.8s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   13.0s finished
# 2023-01-25 07:43:04,398 - ultron - INFO - name:ultron_1674603784222197,method:Crossover,gen:2,formual:MADecay(10,MNPOSITIVE(8,'Alpha101_53_9')),fitness:6.048701,identification:e39f77e9b96e7c64dcc521a0b83cfa1e
# 2023-01-25 07:43:04,398 - ultron - INFO - name:ultron_1674603760258268,method:Crossover,gen:1,formual:MSTD(16,'Alpha191_66_6'),fitness:6.343498,identification:b6bc31984849fa73dedb6b46338923a6
# 2023-01-25 07:43:04,399 - ultron - INFO - name:ultron_1674603770659764,method:Crossover,gen:1,formual:MADecay(20,MRANK(18,EMA(14,'Alpha191_20_10'))),fitness:6.495663,identification:47b1a569d2f6a25cafd972cb5b1bc9ba
# 2023-01-25 07:43:04,399 - ultron - INFO - name:ultron_1674603761766446,method:Subtree Mutation,gen:1,formual:MA(14,MNPOSITIVE(8,'Alpha191_20_10')),fitness:6.727486,identification:c03121eac150c41ee5e336d09e6671df
# 2023-01-25 07:43:04,400 - ultron - INFO - name:ultron_1674603752662057,method:gen,gen:0,formual:RSI(6,MARETURNLog(10,'Alpha101_53_9')),fitness:7.081835,identification:bb0477561966aa89547dc885b1c4f589
# 2023-01-25 07:43:04,401 - ultron - INFO - name:ultron_1674603784956391,method:Crossover,gen:2,formual:MAPOSITIVE(14,MNPOSITIVE(8,'Alpha191_66_6')),fitness:7.151290,identification:b6911fabdcffed9192b3e5b1388d8851
# 2023-01-25 07:43:04,401 - ultron - INFO - name:ultron_1674603755740762,method:gen,gen:0,formual:LOG('Alpha191_41_10_10'),fitness:7.196366,identification:67901ba05249914db9945afb3d4c8a3b
# 2023-01-25 07:43:04,402 - ultron - INFO - name:ultron_1674603762982182,method:Reproduction,gen:1,formual:MMIN(14,MVARIANCE(20,MMIN(6,MMAX(12,'Alpha191_66_6')))),fitness:7.683622,identification:8ae2ccc567468b3bc46925d6eb8673b8
# 2023-01-25 07:43:04,402 - ultron - INFO - name:ultron_1674603761215612,method:Subtree Mutation,gen:1,formual:MA(14,MNPOSITIVE(8,'Alpha101_53_9')),fitness:8.285532,identification:7956a344a78a63da51d9af0701f852fa
# 2023-01-25 07:43:04,403 - ultron - INFO - name:ultron_1674603753757323,method:gen,gen:0,formual:SHIFT(4,MMAX(14,'Alpha191_66_6')),fitness:10.852764,identification:05869ea2b621ac93c21ed831a109f143
# 2023-01-25 07:43:04,405 - ultron - INFO - name:ultron_1674603778680968,method:Point Mutation,gen:2,formual:MNPOSITIVE(2,MNPOSITIVE(8,MA(14,MNPOSITIVE(8,RSI(16,MCORR(20,DIFF('Alpha191_66_6'),DELTA(20,'Alpha101_53_9'))))))),fitness:12.748926,identification:919650a1b1f4a28fb301cdd6dea511ff
# 2023-01-25 07:43:04,405 - ultron - INFO - name:ultron_1674603778678738,method:Point Mutation,gen:2,formual:MNPOSITIVE(2,MA(14,MNPOSITIVE(8,RSI(16,MRANK(20,MADecay(20,'Alpha191_41_10_10')))))),fitness:16.073836,identification:7cda47530a3fba59deda5b78d365f761
# 2023-01-25 07:43:04,406 - ultron - INFO - name:ultron_1674603770457621,method:Point Mutation,gen:1,formual:MNPOSITIVE(2,MSUM(4,SHIFT(2,'Alpha191_41_10_10'))),fitness:16.277929,identification:d68a15f47639701829b4d3ba8e6e0a4a
# 2023-01-25 07:43:04,406 - ultron - INFO - name:ultron_1674603778853548,method:Point Mutation,gen:2,formual:MNPOSITIVE(2,MA(14,MNPOSITIVE(8,RSI(16,MNPOSITIVE(20,MSUM(6,'Alpha101_53_9')))))),fitness:17.074249,identification:1e57ee537b7ef5e1db3c3a141d20d3f7
# 2023-01-25 07:43:04,407 - ultron - INFO - name:ultron_1674603752733772,method:gen,gen:0,formual:RSI(6,MNPOSITIVE(8,'Alpha191_41_10_10')),fitness:17.925043,identification:64be5eafb242d13923d50d71bc908b65
# 2023-01-25 07:43:04,407 - ultron - INFO - name:ultron_1674603751610395,method:gen,gen:0,formual:MNPOSITIVE(2,MMAX(12,'Alpha191_41_10_10')),fitness:18.518876,identification:7d48ecdec55f7c9b03a2a937b04679ab
# 2023-01-25 07:43:04,409 - ultron - INFO - name:ultron_1674603761437468,method:Point Mutation,gen:1,formual:MNPOSITIVE(2,'Alpha191_41_10_10'),fitness:18.518876,identification:b81723a9c5cdb863d818a0023941d4de
# 2023-01-25 07:43:04,409 - ultron - INFO - name:ultron_1674603761512010,method:Subtree Mutation,gen:1,formual:MA(14,MNPOSITIVE(8,'Alpha191_41_10_10')),fitness:18.532822,identification:6650d35da2b74b80a7679a80c790621d
# 2023-01-25 07:43:04,409 - ultron - INFO - name:ultron_1674603782780008,method:Crossover,gen:2,formual:MNPOSITIVE(14,'Alpha191_41_10_10'),fitness:18.592322,identification:844a799b2cf4240f6c319f7065c65c4e
# 2023-01-25 07:43:04,410 - ultron - INFO - name:ultron_1674603777060790,method:Point Mutation,gen:2,formual:MNPOSITIVE(10,'Alpha191_41_10_10'),fitness:18.667976,identification:384d4e586cd7b99b7946fcd5c16c3eff
# 2023-01-25 07:43:04,411 - ultron - INFO - ExpendTime:12.970221,Generation:2,Tournament:20, Fitness Mean:12.339881,Fitness Max:18.667976,Fitness Min:6.048701

# %%
for program in evolution_sets.values():
    print("eval:{0},metrics:{1}".format(program.transform(), program._retain_data))
# Out:
# eval:MMIN(18,MAPOSITIVE(2,MVARIANCE(20,'Alpha191_41_10_10'))),metrics:long_evaluate:
# returns_mean:0.36968088865392734
# returns_std:0.21405667867452344
# sharp:1.727023379709787
# turnover:0.07244728367956604
# maxdd:0.18805644686556042
# returns_mdd:1.9657974763194814
# win_rate:0.5342465753424658
# ic:-0.015523149731758277
# ir:-0.07668053202143352
# fitness:3.9012219874583645
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.36968088865392734
# returns_std:0.21405667867452344
# sharp:1.727023379709787
# turnover:0.07244728367956604
# maxdd:0.18805644686556042
# returns_mdd:1.9657974763194814
# win_rate:0.5342465753424658
# ic:-0.015523149731758277
# ir:-0.07668053202143352
# fitness:3.9012219874583645
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MSTD(8,MQUANTILE(6,MVARIANCE(6,'Alpha191_41_10_10'))),metrics:long_evaluate:
# returns_mean:0.3687971081595577
# returns_std:0.2099460296892036
# sharp:1.7566281615590036
# turnover:0.07028028426620551
# maxdd:0.15663554571938376
# returns_mdd:2.3544918011156057
# win_rate:0.5616438356164384
# ic:0.008867707000997094
# ir:0.04708335818049892
# fitness:4.023989507878388
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.3687971081595577
# returns_std:0.2099460296892036
# sharp:1.7566281615590036
# turnover:0.07028028426620551
# maxdd:0.15663554571938376
# returns_mdd:2.3544918011156057
# win_rate:0.5616438356164384
# ic:0.008867707000997094
# ir:0.04708335818049892
# fitness:4.023989507878388
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MMIN(14,RSI(8,'Alpha191_20_10')),metrics:long_evaluate:
# returns_mean:0.3580396835657029
# returns_std:0.21886526669166506
# sharp:1.6358908335606546
# turnover:0.0542737189540092
# maxdd:0.18028170117683545
# returns_mdd:1.9860012482049274
# win_rate:0.5547945205479452
# ic:-0.011359818521559753
# ir:-0.053984636320588135
# fitness:4.201700675629286
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.3580396835657029
# returns_std:0.21886526669166506
# sharp:1.6358908335606546
# turnover:0.0542737189540092
# maxdd:0.18028170117683545
# returns_mdd:1.9860012482049274
# win_rate:0.5547945205479452
# ic:-0.011359818521559753
# ir:-0.053984636320588135
# fitness:4.201700675629286
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MMIN(14,RSI(14,'Alpha191_41_10_10')),metrics:long_evaluate:
# returns_mean:0.3926219221582732
# returns_std:0.22360597840309665
# sharp:1.755865048699592
# turnover:0.06457853611136219
# maxdd:0.18552354898585116
# returns_mdd:2.1162915667822646
# win_rate:0.5821917808219178
# ic:-0.015508270894923286
# ir:-0.06711819185377198
# fitness:4.329465751802114
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.3926219221582732
# returns_std:0.22360597840309665
# sharp:1.755865048699592
# turnover:0.06457853611136219
# maxdd:0.18552354898585116
# returns_mdd:2.1162915667822646
# win_rate:0.5821917808219178
# ic:-0.015508270894923286
# ir:-0.06711819185377198
# fitness:4.329465751802114
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MSTD(8,EMA(18,RSI(14,'Alpha191_41_10_10'))),metrics:long_evaluate:
# returns_mean:0.42451775116079776
# returns_std:0.21130291854222885
# sharp:2.009048214239208
# turnover:0.07905190143287599
# maxdd:0.16259698355937605
# returns_mdd:2.610858712552778
# win_rate:0.6027397260273972
# ic:0.0043981517978137945
# ir:0.025229896685849653
# fitness:4.655669326503326
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.42451775116079776
# returns_std:0.21130291854222885
# sharp:2.009048214239208
# turnover:0.07905190143287599
# maxdd:0.16259698355937605
# returns_mdd:2.610858712552778
# win_rate:0.6027397260273972
# ic:0.0043981517978137945
# ir:0.025229896685849653
# fitness:4.655669326503326
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:RSI(16,'Alpha191_66_6'),metrics:long_evaluate:
# returns_mean:0.3567901603018364
# returns_std:0.21226306513558146
# sharp:1.6808866868757375
# turnover:0.046342950631154456
# maxdd:0.17572582534292594
# returns_mdd:2.030379766921376
# win_rate:0.5684931506849316
# ic:-0.04312552909779264
# ir:-0.1894306782152527
# fitness:4.663940819060758
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.3567901603018364
# returns_std:0.21226306513558146
# sharp:1.6808866868757375
# turnover:0.046342950631154456
# maxdd:0.17572582534292594
# returns_mdd:2.030379766921376
# win_rate:0.5684931506849316
# ic:-0.04312552909779264
# ir:-0.1894306782152527
# fitness:4.663940819060758
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:RSI(16,'Alpha101_53_9'),metrics:long_evaluate:
# returns_mean:0.4122228097111637
# returns_std:0.212990626166022
# sharp:1.9354035298710477
# turnover:0.06712354370421558
# maxdd:0.17154025544702536
# returns_mdd:2.4030674819559503
# win_rate:0.5616438356164384
# ic:0.013337752005203008
# ir:0.0630385953258471
# fitness:4.796231092229616
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.4122228097111637
# returns_std:0.212990626166022
# sharp:1.9354035298710477
# turnover:0.06712354370421558
# maxdd:0.17154025544702536
# returns_mdd:2.4030674819559503
# win_rate:0.5616438356164384
# ic:0.013337752005203008
# ir:0.0630385953258471
# fitness:4.796231092229616
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MMIN(18,MSTD(4,MCORR(16,'Alpha191_20_10','Alpha101_53_9'))),metrics:long_evaluate:
# returns_mean:0.4072945923216967
# returns_std:0.22169363063318112
# sharp:1.8371957334020785
# turnover:0.0588791504120778
# maxdd:0.18760179674651511
# returns_mdd:2.171059123021233
# win_rate:0.5684931506849316
# ic:0.03285617624539956
# ir:0.1765596903312293
# fitness:4.832022888015954
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.4072945923216967
# returns_std:0.22169363063318112
# sharp:1.8371957334020785
# turnover:0.0588791504120778
# maxdd:0.18760179674651511
# returns_mdd:2.171059123021233
# win_rate:0.5684931506849316
# ic:0.03285617624539956
# ir:0.1765596903312293
# fitness:4.832022888015954
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:DELTA(4,DELTA(2,MAPOSITIVE(4,'Alpha191_20_10'))),metrics:long_evaluate:
# returns_mean:0.8761959769018861
# returns_std:0.30777488199122893
# sharp:2.8468729196908806
# turnover:0.46001747633856543
# maxdd:0.18268608919127738
# returns_mdd:4.796183337114873
# win_rate:0.5616438356164384
# ic:0.030397525816004654
# ir:0.07555805594182383
# fitness:3.9289956061008433
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.1764201404280742
# returns_std:0.25033862298098747
# sharp:-0.7047260160150071
# turnover:0.45552558843011903
# maxdd:0.2641084061277393
# returns_mdd:-0.6679838139750327
# win_rate:0.5068493150684932
# ic:-0.029052579356019754
# ir:-0.08249567652079681
# fitness:-0.43856906732862005
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:1.0526161173299602
# returns_std:0.23340977021750256
# sharp:4.509734602579324
# turnover:0.9155430647686844
# maxdd:0.06986929111480449
# returns_mdd:15.065504466051799
# win_rate:0.5753424657534246
# ic:0.058738263735045815
# ir:0.23629011635644487
# fitness:4.835558075786107
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:RSI(12,SHIFT(18,'Alpha191_66_6')),metrics:long_evaluate:
# returns_mean:0.40946845950862804
# returns_std:0.2066849745262259
# sharp:1.981123496989721
# turnover:0.0592008852274198
# maxdd:0.17417021893964507
# returns_mdd:2.3509671286026257
# win_rate:0.5273972602739726
# ic:-0.01899104970787495
# ir:-0.08229834080497725
# fitness:5.2102393656772765
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.40946845950862804
# returns_std:0.2066849745262259
# sharp:1.981123496989721
# turnover:0.0592008852274198
# maxdd:0.17417021893964507
# returns_mdd:2.3509671286026257
# win_rate:0.5273972602739726
# ic:-0.01899104970787495
# ir:-0.08229834080497725
# fitness:5.2102393656772765
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MSUM(16,MSUM(4,'Alpha191_41_10_10')),metrics:long_evaluate:
# returns_mean:0.31239744075468356
# returns_std:0.24142817050870075
# sharp:1.2939560453796555
# turnover:0.017716475480849297
# maxdd:0.20209335996873834
# returns_mdd:1.545807545596788
# win_rate:0.541095890410959
# ic:-0.002452738450505909
# ir:-0.009600615618033818
# fitness:5.433561586027033
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.31239744075468356
# returns_std:0.24142817050870075
# sharp:1.2939560453796555
# turnover:0.017716475480849297
# maxdd:0.20209335996873834
# returns_mdd:1.545807545596788
# win_rate:0.541095890410959
# ic:-0.002452738450505909
# ir:-0.009600615618033818
# fitness:5.433561586027033
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MADecay(20,MQUANTILE(16,'Alpha191_41_10_10')),metrics:long_evaluate:
# returns_mean:0.38345014108143943
# returns_std:0.21846204479995007
# sharp:1.7552254508675507
# turnover:0.03977577755305055
# maxdd:0.18618537185514772
# returns_mdd:2.0595073461505007
# win_rate:0.5958904109589042
# ic:-0.00561549683027586
# ir:-0.025166777067549176
# fitness:5.449768062108495
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.38345014108143943
# returns_std:0.21846204479995007
# sharp:1.7552254508675507
# turnover:0.03977577755305055
# maxdd:0.18618537185514772
# returns_mdd:2.0595073461505007
# win_rate:0.5958904109589042
# ic:-0.00561549683027586
# ir:-0.025166777067549176
# fitness:5.449768062108495
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:EMA(2,RSI(16,'Alpha191_66_6')),metrics:long_evaluate:
# returns_mean:0.3579883837848865
# returns_std:0.21244726985583365
# sharp:1.6850693540463797
# turnover:0.03380412037590258
# maxdd:0.17685543116300148
# returns_mdd:2.024186542820622
# win_rate:0.5684931506849316
# ic:-0.052956938231516065
# ir:-0.2341336349188961
# fitness:5.483620960477441
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.3579883837848865
# returns_std:0.21244726985583365
# sharp:1.6850693540463797
# turnover:0.03380412037590258
# maxdd:0.17685543116300148
# returns_mdd:2.024186542820622
# win_rate:0.5684931506849316
# ic:-0.052956938231516065
# ir:-0.2341336349188961
# fitness:5.483620960477441
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MADecay(20,MAPOSITIVE(18,'Alpha191_41_10_10')),metrics:long_evaluate:
# returns_mean:0.28731706954285957
# returns_std:0.24016954626250314
# sharp:1.1963093323615002
# turnover:0.013319335821254694
# maxdd:0.20331318723893113
# returns_mdd:1.4131747844039655
# win_rate:0.541095890410959
# ic:-0.006259483868267106
# ir:-0.024239644060518293
# fitness:5.556264610415421
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.28731706954285957
# returns_std:0.24016954626250314
# sharp:1.1963093323615002
# turnover:0.013319335821254694
# maxdd:0.20331318723893113
# returns_mdd:1.4131747844039655
# win_rate:0.541095890410959
# ic:-0.006259483868267106
# ir:-0.024239644060518293
# fitness:5.556264610415421
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MADecay(20,EMA(14,'Alpha191_41_10_10')),metrics:long_evaluate:
# returns_mean:0.2952522874799661
# returns_std:0.24020692958935977
# sharp:1.2291580762666086
# turnover:0.013418103842572774
# maxdd:0.2019146046173679
# returns_mdd:1.4622631584251913
# win_rate:0.541095890410959
# ic:-0.008608932364975877
# ir:-0.033591952651681925
# fitness:5.765789730512596
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.2952522874799661
# returns_std:0.24020692958935977
# sharp:1.2291580762666086
# turnover:0.013418103842572774
# maxdd:0.2019146046173679
# returns_mdd:1.4622631584251913
# win_rate:0.541095890410959
# ic:-0.008608932364975877
# ir:-0.033591952651681925
# fitness:5.765789730512596
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:RSI(6,MARETURNLog(10,'Alpha101_53_9')),metrics:long_evaluate:
# returns_mean:0.4841375032652377
# returns_std:0.21230662940666403
# sharp:2.280369221716075
# turnover:0.050198118216362934
# maxdd:0.16857113728938672
# returns_mdd:2.8720071006824672
# win_rate:0.547945205479452
# ic:0.008790195932195183
# ir:0.04064754699712996
# fitness:7.081835185324963
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.4841375032652377
# returns_std:0.21230662940666403
# sharp:2.280369221716075
# turnover:0.050198118216362934
# maxdd:0.16857113728938672
# returns_mdd:2.8720071006824672
# win_rate:0.547945205479452
# ic:0.008790195932195183
# ir:0.04064754699712996
# fitness:7.081835185324963
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:LOG('Alpha191_41_10_10'),metrics:long_evaluate:
# returns_mean:0.53367818147203
# returns_std:0.192784621123632
# sharp:2.7682611733317897
# turnover:0.07897090970122657
# maxdd:0.15432960167048637
# returns_mdd:3.4580415921211403
# win_rate:0.589041095890411
# ic:0.037295743428934665
# ir:0.15676076026711386
# fitness:7.19636553490401
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.53367818147203
# returns_std:0.192784621123632
# sharp:2.7682611733317897
# turnover:0.07897090970122657
# maxdd:0.15432960167048637
# returns_mdd:3.4580415921211403
# win_rate:0.589041095890411
# ic:0.037295743428934665
# ir:0.15676076026711386
# fitness:7.19636553490401
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:SHIFT(4,MMAX(14,'Alpha191_66_6')),metrics:long_evaluate:
# returns_mean:0.3430430094448844
# returns_std:0.24796894275985223
# sharp:1.3834111870094454
# turnover:0.0410478814394762
# maxdd:0.2044666494171313
# returns_mdd:1.6777455414992606
# win_rate:0.541095890410959
# ic:0.021809477997876237
# ir:0.08363620300949613
# fitness:3.999265130011299
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:-0.6294130893268901
# returns_std:0.2647138432087253
# sharp:-2.3777112737946293
# turnover:0.1293237338826779
# maxdd:0.5850454503485076
# returns_mdd:-1.0758362259751837
# win_rate:0.0684931506849315
# ic:-0.035714285714285775
# ir:-0.03564615028997602
# fitness:-5.245511995365507
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.9724560987717743
# returns_std:0.3361853087769361
# sharp:2.892619259031968
# turnover:0.06908309647697981
# maxdd:0.1971756687952954
# returns_mdd:4.931927477225207
# win_rate:0.5547945205479452
# ic:0.024127209688707015
# ir:0.09196048582632103
# fitness:10.852764467786654
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:RSI(6,MNPOSITIVE(8,'Alpha191_41_10_10')),metrics:long_evaluate:
# returns_mean:0.3873723103069475
# returns_std:0.21250929800648533
# sharp:1.822848759752271
# turnover:0.004005985956026248
# maxdd:0.17207158823529306
# returns_mdd:2.2512276098553197
# win_rate:0.5753424657534246
# ic:-0.04018412065082195
# ir:-0.21221623601356276
# fitness:17.925043272473662
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.3873723103069475
# returns_std:0.21250929800648533
# sharp:1.822848759752271
# turnover:0.004005985956026248
# maxdd:0.17207158823529306
# returns_mdd:2.2512276098553197
# win_rate:0.5753424657534246
# ic:-0.04018412065082195
# ir:-0.21221623601356276
# fitness:17.925043272473662
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MNPOSITIVE(2,MMAX(12,'Alpha191_41_10_10')),metrics:long_evaluate:
# returns_mean:0.38317921085766987
# returns_std:0.21270020908417386
# sharp:1.8014989853913626
# turnover:0.0036261079774375505
# maxdd:0.172071588235293
# returns_mdd:2.2268592670493947
# win_rate:0.5753424657534246
# ic:0.13307728267479998
# ir:1.3258252147247767
# fitness:18.518876057411592
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.38317921085766987
# returns_std:0.21270020908417386
# sharp:1.8014989853913626
# turnover:0.0036261079774375505
# maxdd:0.172071588235293
# returns_mdd:2.2268592670493947
# win_rate:0.5753424657534246
# ic:0.13307728267479998
# ir:1.3258252147247767
# fitness:18.518876057411592
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MSUM(16,MSTD(2,LOG('Alpha191_41_10_10'))),metrics:long_evaluate:
# returns_mean:0.37217821164393056
# returns_std:0.19595036496483828
# sharp:1.899349417954465
# turnover:0.04367260694136321
# maxdd:0.1301205647107307
# returns_mdd:2.860256658671249
# win_rate:0.5753424657534246
# ic:-0.0072136456676152325
# ir:-0.030986190297622774
# fitness:5.544671000716718
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.37217821164393056
# returns_std:0.19595036496483828
# sharp:1.899349417954465
# turnover:0.04367260694136321
# maxdd:0.1301205647107307
# returns_mdd:2.860256658671249
# win_rate:0.5753424657534246
# ic:-0.0072136456676152325
# ir:-0.030986190297622774
# fitness:5.544671000716718
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MADecay(20,MRANK(18,EMA(14,'Alpha191_41_10_10'))),metrics:long_evaluate:
# returns_mean:0.400916125147894
# returns_std:0.22850378434357554
# sharp:1.754527288463115
# turnover:0.03642274942280751
# maxdd:0.18472407538827018
# returns_mdd:2.1703512349714638
# win_rate:0.5821917808219178
# ic:0.007773540476023284
# ir:0.035612759809479505
# fitness:5.821039232891128
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.400916125147894
# returns_std:0.22850378434357554
# sharp:1.754527288463115
# turnover:0.03642274942280751
# maxdd:0.18472407538827018
# returns_mdd:2.1703512349714638
# win_rate:0.5821917808219178
# ic:0.007773540476023284
# ir:0.035612759809479505
# fitness:5.821039232891128
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:LOG(MVARIANCE(10,MADecay(20,'Alpha191_41_10_10'))),metrics:long_evaluate:
# returns_mean:0.3700659978118951
# returns_std:0.2158355991389631
# sharp:1.714573496161922
# turnover:0.02974402055102656
# maxdd:0.17522275256547165
# returns_mdd:2.1119745717589993
# win_rate:0.547945205479452
# ic:-0.006329200359864829
# ir:-0.032276183286831094
# fitness:6.047778288443375
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.3700659978118951
# returns_std:0.2158355991389631
# sharp:1.714573496161922
# turnover:0.02974402055102656
# maxdd:0.17522275256547165
# returns_mdd:2.1119745717589993
# win_rate:0.547945205479452
# ic:-0.006329200359864829
# ir:-0.032276183286831094
# fitness:6.047778288443375
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MSTD(16,'Alpha191_66_6'),metrics:long_evaluate:
# returns_mean:0.42890656771302915
# returns_std:0.2417499083576115
# sharp:1.7741746858433711
# turnover:0.033550408435169314
# maxdd:0.20608011740380366
# returns_mdd:2.0812612740927756
# win_rate:0.5547945205479452
# ic:0.03263968102807748
# ir:0.13242443843667953
# fitness:6.343498198492998
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.42890656771302915
# returns_std:0.2417499083576115
# sharp:1.7741746858433711
# turnover:0.033550408435169314
# maxdd:0.20608011740380366
# returns_mdd:2.0812612740927756
# win_rate:0.5547945205479452
# ic:0.03263968102807748
# ir:0.13242443843667953
# fitness:6.343498198492998
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MADecay(20,MRANK(18,EMA(14,'Alpha191_20_10'))),metrics:long_evaluate:
# returns_mean:0.4218453182931341
# returns_std:0.2240067648031155
# sharp:1.8831811559972453
# turnover:0.03545605748918594
# maxdd:0.1729002710124251
# returns_mdd:2.439818722220621
# win_rate:0.589041095890411
# ic:0.0034976643584150786
# ir:0.01636001130517677
# fitness:6.495663147117189
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.4218453182931341
# returns_std:0.2240067648031155
# sharp:1.8831811559972453
# turnover:0.03545605748918594
# maxdd:0.1729002710124251
# returns_mdd:2.439818722220621
# win_rate:0.589041095890411
# ic:0.0034976643584150786
# ir:0.01636001130517677
# fitness:6.495663147117189
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MA(14,MNPOSITIVE(8,'Alpha191_20_10')),metrics:long_evaluate:
# returns_mean:0.41786190960938585
# returns_std:0.23352398994209067
# sharp:1.789374657879935
# turnover:0.029561725769609384
# maxdd:0.17382409379326424
# returns_mdd:2.4039354987598283
# win_rate:0.5684931506849316
# ic:-0.007915772096917024
# ir:-0.029226987138359837
# fitness:6.727485690528988
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.41786190960938585
# returns_std:0.23352398994209067
# sharp:1.789374657879935
# turnover:0.029561725769609384
# maxdd:0.17382409379326424
# returns_mdd:2.4039354987598283
# win_rate:0.5684931506849316
# ic:-0.007915772096917024
# ir:-0.029226987138359837
# fitness:6.727485690528988
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MMIN(14,MVARIANCE(20,MMIN(6,MMAX(12,'Alpha191_66_6')))),metrics:long_evaluate:
# returns_mean:0.6737545190810688
# returns_std:0.2855179172338975
# sharp:2.3597626573085644
# turnover:0.06354864748625677
# maxdd:0.17203570968067497
# returns_mdd:3.916364342796399
# win_rate:0.5136986301369864
# ic:0.04223129202821073
# ir:0.17454676280627776
# fitness:7.683622398662527
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.6737545190810688
# returns_std:0.2855179172338975
# sharp:2.3597626573085644
# turnover:0.06354864748625677
# maxdd:0.17203570968067497
# returns_mdd:3.916364342796399
# win_rate:0.5136986301369864
# ic:0.04223129202821073
# ir:0.17454676280627776
# fitness:7.683622398662527
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MA(14,MNPOSITIVE(8,'Alpha101_53_9')),metrics:long_evaluate:
# returns_mean:0.3830538005868543
# returns_std:0.21470382178558023
# sharp:1.7841033168445475
# turnover:0.01776065695757943
# maxdd:0.1775804269754569
# returns_mdd:2.1570721903928947
# win_rate:0.5684931506849316
# ic:0.00298719410715306
# ir:0.014714302662735466
# fitness:8.285531550963817
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.3830538005868543
# returns_std:0.21470382178558023
# sharp:1.7841033168445475
# turnover:0.01776065695757943
# maxdd:0.1775804269754569
# returns_mdd:2.1570721903928947
# win_rate:0.5684931506849316
# ic:0.00298719410715306
# ir:0.014714302662735466
# fitness:8.285531550963817
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MNPOSITIVE(2,MSUM(4,SHIFT(2,'Alpha191_41_10_10'))),metrics:long_evaluate:
# returns_mean:0.3507427794147817
# returns_std:0.21118894182320574
# sharp:1.6608008752106054
# turnover:0.0036511156186612584
# maxdd:0.17207158823529306
# returns_mdd:2.038353821289609
# win_rate:0.5684931506849316
# ic:0.13307728267479998
# ir:0.7576144084141581
# fitness:16.2779286938101
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.3507427794147817
# returns_std:0.21118894182320574
# sharp:1.6608008752106054
# turnover:0.0036511156186612584
# maxdd:0.17207158823529306
# returns_mdd:2.038353821289609
# win_rate:0.5684931506849316
# ic:0.13307728267479998
# ir:0.7576144084141581
# fitness:16.2779286938101
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MNPOSITIVE(2,'Alpha191_41_10_10'),metrics:long_evaluate:
# returns_mean:0.38317921085766987
# returns_std:0.21270020908417386
# sharp:1.8014989853913626
# turnover:0.0036261079774375505
# maxdd:0.172071588235293
# returns_mdd:2.2268592670493947
# win_rate:0.5753424657534246
# ic:0.13307728267479998
# ir:1.3258252147247767
# fitness:18.518876057411592
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.38317921085766987
# returns_std:0.21270020908417386
# sharp:1.8014989853913626
# turnover:0.0036261079774375505
# maxdd:0.172071588235293
# returns_mdd:2.2268592670493947
# win_rate:0.5753424657534246
# ic:0.13307728267479998
# ir:1.3258252147247767
# fitness:18.518876057411592
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MA(14,MNPOSITIVE(8,'Alpha191_41_10_10')),metrics:long_evaluate:
# returns_mean:0.3839842949527996
# returns_std:0.212698110548603
# sharp:1.80530186169687
# turnover:0.003643594273897801
# maxdd:0.17207158823529306
# returns_mdd:2.2315380411769907
# win_rate:0.5684931506849316
# ic:-0.0533558682649198
# ir:-0.28890261295932007
# fitness:18.53282204349621
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.3839842949527996
# returns_std:0.212698110548603
# sharp:1.80530186169687
# turnover:0.003643594273897801
# maxdd:0.17207158823529306
# returns_mdd:2.2315380411769907
# win_rate:0.5684931506849316
# ic:-0.0533558682649198
# ir:-0.28890261295932007
# fitness:18.53282204349621
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MADecay(10,MNPOSITIVE(8,'Alpha101_53_9')),metrics:long_evaluate:
# returns_mean:0.3676501868536703
# returns_std:0.2144343783185258
# sharp:1.7145114031461606
# turnover:0.029538700080784037
# maxdd:0.18420494240136415
# returns_mdd:1.9958758004038637
# win_rate:0.5616438356164384
# ic:-0.016096266024831038
# ir:-0.08289001762933017
# fitness:6.048700538633869
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.3676501868536703
# returns_std:0.2144343783185258
# sharp:1.7145114031461606
# turnover:0.029538700080784037
# maxdd:0.18420494240136415
# returns_mdd:1.9958758004038637
# win_rate:0.5616438356164384
# ic:-0.016096266024831038
# ir:-0.08289001762933017
# fitness:6.048700538633869
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MAPOSITIVE(14,MNPOSITIVE(8,'Alpha191_66_6')),metrics:long_evaluate:
# returns_mean:0.3739714206234417
# returns_std:0.2235049152007379
# sharp:1.673213406906798
# turnover:0.020472566347605938
# maxdd:0.1682639913850725
# returns_mdd:2.222527930932099
# win_rate:0.5684931506849316
# ic:-0.03244106491680991
# ir:-0.12066248936151168
# fitness:7.1512901524189365
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.3739714206234417
# returns_std:0.2235049152007379
# sharp:1.673213406906798
# turnover:0.020472566347605938
# maxdd:0.1682639913850725
# returns_mdd:2.222527930932099
# win_rate:0.5684931506849316
# ic:-0.03244106491680991
# ir:-0.12066248936151168
# fitness:7.1512901524189365
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MNPOSITIVE(2,MNPOSITIVE(8,MA(14,MNPOSITIVE(8,RSI(16,MCORR(20,DIFF('Alpha191_66_6'),DELTA(20,'Alpha101_53_9'))))))),metrics:long_evaluate:
# returns_mean:0.4555084918226332
# returns_std:0.20522918784136657
# sharp:2.219511252827848
# turnover:0.01380587642021159
# maxdd:0.172071588235293
# returns_mdd:2.6472033907176167
# win_rate:0.5136986301369864
# ic:0.01695542892116898
# ir:0.09035973437879942
# fitness:12.748925970105008
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.4555084918226332
# returns_std:0.20522918784136657
# sharp:2.219511252827848
# turnover:0.01380587642021159
# maxdd:0.172071588235293
# returns_mdd:2.6472033907176167
# win_rate:0.5136986301369864
# ic:0.01695542892116898
# ir:0.09035973437879942
# fitness:12.748925970105008
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MNPOSITIVE(2,MA(14,MNPOSITIVE(8,RSI(16,MRANK(20,MADecay(20,'Alpha191_41_10_10')))))),metrics:long_evaluate:
# returns_mean:0.3862952987611311
# returns_std:0.212711504069633
# sharp:1.816052688126703
# turnover:0.004931025773629838
# maxdd:0.17192899429323855
# returns_mdd:2.246830445028218
# win_rate:0.5753424657534246
# ic:0.006957798903083502
# ir:0.053147643313612734
# fitness:16.073835500354313
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.3862952987611311
# returns_std:0.212711504069633
# sharp:1.816052688126703
# turnover:0.004931025773629838
# maxdd:0.17192899429323855
# returns_mdd:2.246830445028218
# win_rate:0.5753424657534246
# ic:0.006957798903083502
# ir:0.053147643313612734
# fitness:16.073835500354313
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MNPOSITIVE(2,MA(14,MNPOSITIVE(8,RSI(16,MNPOSITIVE(20,MSUM(6,'Alpha101_53_9')))))),metrics:long_evaluate:
# returns_mean:0.3819066336390089
# returns_std:0.21259586818239193
# sharp:1.796397253174086
# turnover:0.004227452583977775
# maxdd:0.1734349632851773
# returns_mdd:2.2020164008743945
# win_rate:0.5684931506849316
# ic:0.011089773556233327
# ir:0.0601058796042931
# fitness:17.07424900627307
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.3819066336390089
# returns_std:0.21259586818239193
# sharp:1.796397253174086
# turnover:0.004227452583977775
# maxdd:0.1734349632851773
# returns_mdd:2.2020164008743945
# win_rate:0.5684931506849316
# ic:0.011089773556233327
# ir:0.0601058796042931
# fitness:17.07424900627307
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MNPOSITIVE(14,'Alpha191_41_10_10'),metrics:long_evaluate:
# returns_mean:0.38420273110714187
# returns_std:0.21270939261428834
# sharp:1.8062330317675581
# turnover:0.0036261079774375505
# maxdd:0.172071588235293
# returns_mdd:2.2328074904601793
# win_rate:0.5753424657534246
# ic:-0.02281324845853713
# ir:-0.12450264657397069
# fitness:18.59232224200352
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.38420273110714187
# returns_std:0.21270939261428834
# sharp:1.8062330317675581
# turnover:0.0036261079774375505
# maxdd:0.172071588235293
# returns_mdd:2.2328074904601793
# win_rate:0.5753424657534246
# ic:-0.02281324845853713
# ir:-0.12450264657397069
# fitness:18.59232224200352
# category:both
# freq:252
# hold:1,hold:1,freq:252
# eval:MNPOSITIVE(10,'Alpha191_41_10_10'),metrics:long_evaluate:
# returns_mean:0.38518438689979706
# returns_std:0.21265980946523885
# sharp:1.8112702530317977
# turnover:0.0036261079774375505
# maxdd:0.172071588235293
# returns_mdd:2.2385124171289146
# win_rate:0.5753424657534246
# ic:0.04260972149493595
# ir:0.22728180906807252
# fitness:18.667975663468617
# category:long
# freq:252
# hold:1
# short_evaluate:
# returns_mean:0.0
# returns_std:0.0
# sharp:nan
# turnover:nan
# maxdd:0.0
# returns_mdd:nan
# win_rate:0.0
# ic:nan
# ir:nan
# fitness:nan
# category:short
# freq:252
# hold:1
# both_evaluate:
# returns_mean:0.38518438689979706
# returns_std:0.21265980946523885
# sharp:1.8112702530317977
# turnover:0.0036261079774375505
# maxdd:0.172071588235293
# returns_mdd:2.2385124171289146
# win_rate:0.5753424657534246
# ic:0.04260972149493595
# ir:0.22728180906807252
# fitness:18.667975663468617
# category:both
# freq:252
# hold:1,hold:1,freq:252
